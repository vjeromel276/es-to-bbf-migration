# %% [markdown]
# # ES → BBF Salesforce Account Migration
#
# This notebook migrates Account records from ES Salesforce to BBF Salesforce.
#
# ## Process Overview
# 1. Connect to both ES (source) and BBF (target) Salesforce orgs
# 2. Query Accounts from ES Salesforce
# 3. Transform ES Accounts for BBF schema:
#    - Map standard fields
#    - Set BBF required custom fields (12 booleans)
#    - Add `ES_Legacy_ID__c` = ES Account.Id (for tracking)
# 4. Insert Accounts to BBF Salesforce
# 5. Update ES Accounts with `BBF_New_Id__c` = BBF Account.Id
# 6. Create ID mapping CSV: ES ID → BBF ID
# 7. Output results to Excel with color-coded status
#
# ## Field Tracking Strategy
# **In BBF:** `ES_Legacy_ID__c` stores original ES Account ID
# - Text(18), External ID, Unique
# - Used for troubleshooting, validation, future updates
#
# **In ES:** `BBF_New_Id__c` stores new BBF Account ID
# - Text(18)
# - Allows ES org to stay operational during transition
#
# ## Safety
# - `TEST_MODE = True` by default (limits to 10 Accounts)
# - All inserts use bulk API for performance
# - Verification queries after migration
# - Excel output shows all successes and failures

# %%
# === SETUP & IMPORTS ===

import sys
import pandas as pd
from simple_salesforce import Salesforce
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
from datetime import datetime
import os

print(f"Python: {sys.executable}")
print(f"Pandas: {pd.__version__}")
print("✅ Imports successful")
# Out:
# Python: C:\Users\vjero\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe
# Pandas: 2.2.3
# ✅ Imports successful

# %%
# === CONFIGURATION ===

# ES (Source) Credentials
ES_USERNAME = "vlettau@everstream.net.uat"
ES_PASSWORD = "MNlkpo0987)(*&"
ES_TOKEN = "nSBoNS97wYLCRW2JP2JARR12"
ES_DOMAIN = "test"  # or 'test' for sandbox

# BBF (Target) Credentials
BBF_USERNAME = "vlettau@everstream.net"
BBF_PASSWORD = "MNlkpo0987)(*&"
BBF_TOKEN = "I4xmQLmm03cXl1O9qI2Z3XAAX"
BBF_DOMAIN = "test"  # or 'test' for sandbox

# Migration Options
TEST_MODE = False  # ⚠️ Set to False to migrate ALL accounts
TEST_LIMIT = 10  # Only used when TEST_MODE = True
ACCOUNT_FILTER = ""  # e.g., "Type = 'Customer' AND BillingCountry = 'USA'"

# 👤 Account Owner - Set all migrated accounts to this user
OWNER_ID = "005Ea00000ZOGFZIA5"

# Output Configuration
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_file = f"es_bbf_account_migration_{timestamp}.xlsx"

print("📋 Configuration loaded")
print(f"   TEST_MODE: {TEST_MODE}")
print(f"   Owner ID: {OWNER_ID}")
print(f"   Output: {output_file}")
print("\n⚠️  Note: Bulk API automatically handles batching (200 records/batch)")
# Out:
# 📋 Configuration loaded
#    TEST_MODE: False
#    Owner ID: 005Ea00000ZOGFZIA5
#    Output: es_bbf_account_migration_20251210_185012.xlsx
#
# ⚠️  Note: Bulk API automatically handles batching (200 records/batch)

# %%
# === CONNECT TO SALESFORCE ORGS ===

print("=" * 80)
print("CONNECTING TO SALESFORCE ORGS")
print("=" * 80)

# Connect to ES (source)
print("\n🔌 Connecting to ES (source)...")
es_sf = Salesforce(
    username=ES_USERNAME,
    password=ES_PASSWORD,
    security_token=ES_TOKEN,
    domain=ES_DOMAIN,
)
print(f"✅ Connected to ES: {es_sf.sf_instance}")

# Connect to BBF (target)
print("\n🔌 Connecting to BBF (target)...")
bbf_sf = Salesforce(
    username=BBF_USERNAME,
    password=BBF_PASSWORD,
    security_token=BBF_TOKEN,
    domain=BBF_DOMAIN,
)
print(f"✅ Connected to BBF: {bbf_sf.sf_instance}")
# Out:
# ================================================================================
# CONNECTING TO SALESFORCE ORGS
# ================================================================================
#
# 🔌 Connecting to ES (source)...
# ✅ Connected to ES: everstream--uat.sandbox.my.salesforce.com
#
# 🔌 Connecting to BBF (target)...
# ✅ Connected to BBF: bluebirdnetwork--full.sandbox.my.salesforce.com

# %%
# === QUERY ES ACCOUNTS ===

print("\n" + "=" * 80)
print("QUERYING ES ACCOUNTS")
print("=" * 80)

# Build query - exclude already-migrated accounts
query = """
    SELECT Id, Name, Type, BillingStreet, BillingCity, BillingState, 
           BillingPostalCode, BillingCountry, Phone, Website, Industry,
           AnnualRevenue, NumberOfEmployees, Description,
           ShippingStreet, ShippingCity, ShippingState, ShippingPostalCode,
           ShippingCountry, AccountNumber, Site, TickerSymbol, Ownership,
           Rating, Sic, SicDesc
    FROM Account
    WHERE (BBF_New_Id__c = null OR BBF_New_Id__c = '') AND Type = 'Customer'
"""

# Add custom filter if specified
if ACCOUNT_FILTER:
    query += f" AND ({ACCOUNT_FILTER})"

# Add limit for test mode
if TEST_MODE:
    query += f" LIMIT {TEST_LIMIT}"

print(f"Query: {query}")
print("\nExecuting query...")

result = es_sf.query_all(query)
es_accounts = result["records"]

print(f"✅ Found {len(es_accounts)} accounts to migrate")

if len(es_accounts) > 0:
    sample = es_accounts[0]
    print(f"\nSample Account:")
    print(f"  ID:   {sample['Id']}")
    print(f"  Name: {sample['Name']}")
    print(f"  Type: {sample.get('Type', 'N/A')}")
    print(f"  City: {sample.get('BillingCity', 'N/A')}")
elif TEST_MODE:
    print("\n⚠️  No unmigrated accounts found in test set")
else:
    print("\n✅ All accounts have been migrated!")
# Out:
# ================================================================================
# QUERYING ES ACCOUNTS
# ================================================================================
# Query:
#     SELECT Id, Name, Type, BillingStreet, BillingCity, BillingState,
#            BillingPostalCode, BillingCountry, Phone, Website, Industry,
#            AnnualRevenue, NumberOfEmployees, Description,
#            ShippingStreet, ShippingCity, ShippingState, ShippingPostalCode,
#            ShippingCountry, AccountNumber, Site, TickerSymbol, Ownership,
#            Rating, Sic, SicDesc
#     FROM Account
#     WHERE (BBF_New_Id__c = null OR BBF_New_Id__c = '') AND Type = 'Customer'
#
#
# Executing query...
# ✅ Found 4013 accounts to migrate
#
# Sample Account:
#   ID:   0010B00001jOjnlQAC
#   Name: Vista Springs Quail Highlands
#   Type: Customer
#   City: Grand Rapids

# %%
# === TRANSFORM FOR BBF ===

print("\n" + "=" * 80)
print("TRANSFORMING ACCOUNTS FOR BBF")
print("=" * 80)

bbf_accounts = []

for es_account in es_accounts:
    bbf_account = {
        # Standard fields
        "Name": es_account.get("Name"),
        "Type": es_account.get("Type"),
        "BillingStreet": es_account.get("BillingStreet"),
        "BillingCity": es_account.get("BillingCity"),
        "BillingState": es_account.get("BillingState"),
        "BillingPostalCode": es_account.get("BillingPostalCode"),
        "BillingCountry": es_account.get("BillingCountry"),
        "ShippingStreet": es_account.get("ShippingStreet"),
        "ShippingCity": es_account.get("ShippingCity"),
        "ShippingState": es_account.get("ShippingState"),
        "ShippingPostalCode": es_account.get("ShippingPostalCode"),
        "ShippingCountry": es_account.get("ShippingCountry"),
        "Phone": es_account.get("Phone"),
        "Website": es_account.get("Website"),
        "Industry": es_account.get("Industry"),
        "AnnualRevenue": es_account.get("AnnualRevenue"),
        "NumberOfEmployees": es_account.get("NumberOfEmployees"),
        "Description": es_account.get("Description"),
        "AccountNumber": es_account.get("AccountNumber"),
        "Site": es_account.get("Site"),
        "TickerSymbol": es_account.get("TickerSymbol"),
        "Ownership": es_account.get("Ownership"),
        "Rating": es_account.get("Rating"),
        "Sic": es_account.get("Sic"),
        "SicDesc": es_account.get("SicDesc"),
        # 👤 Set account owner
        "OwnerId": OWNER_ID,
        # BBF Required boolean fields (fields without write permission removed)
        # "Agent__c": False,
        # "proposalmanager__Quote_Provider__c": False,
        # "proposalmanager__Org_Account_For_PMT_Quotes__c": False,
        # "Quote_Provider__c": False,
        # "Business_Partner__c": False,
        # "Master_Agent__c": False,
        # "New_Transition__c": False,
        # "Strategic_Account__c": False,
        # "Protected_Account__c": False,
        # 🔗 Store ES Account ID for tracking
        "ES_Legacy_ID__c": es_account["Id"],
    }

    bbf_accounts.append(bbf_account)

print(f"✅ Transformed {len(bbf_accounts)} accounts")
print(
    f"   - Mapped {len([k for k in bbf_accounts[0].keys() if not k.startswith('_')])} fields per account"
)
print(f"   - Set OwnerId to {OWNER_ID}")
print(f"   - Set ES_Legacy_ID__c for tracking")
# Out:
# ================================================================================
# TRANSFORMING ACCOUNTS FOR BBF
# ================================================================================
# ✅ Transformed 4013 accounts
#    - Mapped 27 fields per account
#    - Set OwnerId to 005Ea00000ZOGFZIA5
#    - Set ES_Legacy_ID__c for tracking

# %%
# === INSERT TO BBF ===

print("\n" + "=" * 80)
print("INSERTING ACCOUNTS TO BBF")
print("=" * 80)

if len(bbf_accounts) == 0:
    print("⚠️  No accounts to insert")
    successful_inserts = []
    failed_inserts = []
else:
    print(f"Inserting {len(bbf_accounts)} accounts using bulk API...")
    print("(Bulk API automatically batches in 200-record chunks)\n")

    try:
        results = bbf_sf.bulk.Account.insert(bbf_accounts)

        successful_inserts = []
        failed_inserts = []

        for i, result in enumerate(results):
            if result["success"]:
                successful_inserts.append(
                    {
                        "es_id": bbf_accounts[i]["ES_Legacy_ID__c"],
                        "bbf_id": result["id"],
                        "name": bbf_accounts[i]["Name"],
                    }
                )
            else:
                failed_inserts.append(
                    {
                        "es_id": bbf_accounts[i]["ES_Legacy_ID__c"],
                        "name": bbf_accounts[i]["Name"],
                        "errors": result["errors"],
                    }
                )

        print(f"✅ Successfully inserted: {len(successful_inserts)} accounts")
        print(f"❌ Failed to insert: {len(failed_inserts)} accounts")

        if len(failed_inserts) > 0:
            print(f"\nFailed Accounts (first 5):")
            for item in failed_inserts[:5]:
                print(f"  - {item['name']} (ES ID: {item['es_id']})")
                print(f"    Errors: {item['errors']}")

        if len(successful_inserts) > 0:
            print(f"\nSample successful insert:")
            sample = successful_inserts[0]
            print(f"  ES ID:  {sample['es_id']}")
            print(f"  BBF ID: {sample['bbf_id']}")
            print(f"  Name:   {sample['name']}")

    except Exception as e:
        print(f"❌ Error during bulk insert: {e}")
        successful_inserts = []
        failed_inserts = []
# Out:
# ================================================================================
# INSERTING ACCOUNTS TO BBF
# ================================================================================
# Inserting 4013 accounts using bulk API...
# (Bulk API automatically batches in 200-record chunks)
#
# ✅ Successfully inserted: 3746 accounts
# ❌ Failed to insert: 267 accounts
#
# Failed Accounts (first 5):
#   - city of East Lansing (ES ID: 0010B00001lcQHmQAM)
#     Errors: [{'statusCode': 'DUPLICATES_DETECTED', 'message': 'You are creating a duplicate record. We recommend you use an existing record instead.', 'fields': []}]
#   - Mosaic Networx (ES ID: 0010B00001oCBMHQA4)
#     Errors: [{'statusCode': 'DUPLICATES_DETECTED', 'message': 'You are creating a duplicate record. We recommend you use an existing record instead.', 'fields': []}]
#   - St Ambrose (ES ID: 0010B00001p1SNtQAM)
#     Errors: [{'statusCode': 'DUPLICATES_DETECTED', 'message': 'You are creating a duplicate record. We recommend you use an existing record instead.', 'fields': []}]
#   - Switch (ES ID: 0010B00001p6PV7QAM)
#     Errors: [{'statusCode': 'DUPLICATES_DETECTED', 'message': 'You are creating a duplicate record. We recommend you use an existing record instead.', 'fields': []}]
#   - Advanced Radiology Services (ES ID: 0010B00001p6Z1EQAU)
#     Errors: [{'statusCode': 'DUPLICATES_DETECTED', 'message': 'You are creating a duplicate record. We recommend you use an existing record instead.', 'fields': []}]
#
# Sample successful insert:
#   ES ID:  0010B00001jOjnlQAC
#   BBF ID: 001Ea00001IaGKyIAN
#   Name:   Vista Springs Quail Highlands

# %%
# === UPDATE ES WITH BBF IDS ===

print("\n" + "=" * 80)
print("UPDATING ES WITH BBF IDS")
print("=" * 80)

if len(successful_inserts) == 0:
    print("⚠️  No successful inserts to update in ES")
else:
    es_updates = []
    for item in successful_inserts:
        es_updates.append({"Id": item["es_id"], "BBF_New_Id__c": item["bbf_id"]})

    print(f"Updating {len(es_updates)} ES accounts with BBF IDs...")
    print("(Processing in batches of 10 to avoid CPQ trigger governor limits)\n")

    # Process in small batches to avoid CPQ trigger SOQL limit
    BATCH_SIZE = 10
    total_success = 0
    total_errors = 0

    try:
        for i in range(0, len(es_updates), BATCH_SIZE):
            batch = es_updates[i : i + BATCH_SIZE]
            batch_num = (i // BATCH_SIZE) + 1
            total_batches = (len(es_updates) + BATCH_SIZE - 1) // BATCH_SIZE

            print(
                f"  Processing batch {batch_num}/{total_batches} ({len(batch)} records)...",
                end=" ",
            )

            results = es_sf.bulk.Account.update(batch)

            success_count = sum(1 for r in results if r["success"])
            error_count = sum(1 for r in results if not r["success"])

            total_success += success_count
            total_errors += error_count

            if error_count > 0:
                print(f"⚠️  {success_count} OK, {error_count} failed")
                for j, result in enumerate(results):
                    if not result["success"]:
                        print(f"    Error on {batch[j]['Id']}: {result['errors']}")
            else:
                print(f"✅ {success_count} OK")

        print(f"\n✅ Successfully updated: {total_success} ES accounts")
        if total_errors > 0:
            print(f"❌ Failed to update: {total_errors} ES accounts")

        print("\n🔄 Bidirectional tracking complete:")
        print("   BBF → ES_Legacy_ID__c (original ES ID)")
        print("   ES → BBF_New_Id__c (new BBF ID)")

    except Exception as e:
        print(f"⚠️  Could not update ES accounts: {e}")
        print("(Migration can continue - ES tracking is optional)")
# Out:
# ================================================================================
# UPDATING ES WITH BBF IDS
# ================================================================================
# Updating 3746 ES accounts with BBF IDs...
# (Processing in batches of 10 to avoid CPQ trigger governor limits)
#
#   Processing batch 1/375 (10 records)... ✅ 10 OK
#   Processing batch 2/375 (10 records)... ✅ 10 OK
#   Processing batch 3/375 (10 records)... ✅ 10 OK
#   Processing batch 4/375 (10 records)... ✅ 10 OK
#   Processing batch 5/375 (10 records)... ✅ 10 OK
#   Processing batch 6/375 (10 records)... ✅ 10 OK
#   Processing batch 7/375 (10 records)... ✅ 10 OK
#   Processing batch 8/375 (10 records)... ✅ 10 OK
#   Processing batch 9/375 (10 records)... ✅ 10 OK
#   Processing batch 10/375 (10 records)... ✅ 10 OK
#   Processing batch 11/375 (10 records)... ✅ 10 OK
#   Processing batch 12/375 (10 records)... ✅ 10 OK
#   Processing batch 13/375 (10 records)... ✅ 10 OK
#   Processing batch 14/375 (10 records)... ✅ 10 OK
#   Processing batch 15/375 (10 records)... ✅ 10 OK
#   Processing batch 16/375 (10 records)... ✅ 10 OK
#   Processing batch 17/375 (10 records)... ✅ 10 OK
#   Processing batch 18/375 (10 records)... ✅ 10 OK
#   Processing batch 19/375 (10 records)... ✅ 10 OK
#   Processing batch 20/375 (10 records)... ✅ 10 OK
#   Processing batch 21/375 (10 records)... ✅ 10 OK
#   Processing batch 22/375 (10 records)... ✅ 10 OK
#   Processing batch 23/375 (10 records)... ✅ 10 OK
#   Processing batch 24/375 (10 records)... ✅ 10 OK
#   Processing batch 25/375 (10 records)... ✅ 10 OK
#   Processing batch 26/375 (10 records)... ✅ 10 OK
#   Processing batch 27/375 (10 records)... ✅ 10 OK
#   Processing batch 28/375 (10 records)... ✅ 10 OK
#   Processing batch 29/375 (10 records)... ✅ 10 OK
#   Processing batch 30/375 (10 records)... ✅ 10 OK
#   Processing batch 31/375 (10 records)... ✅ 10 OK
#   Processing batch 32/375 (10 records)... ✅ 10 OK
#   Processing batch 33/375 (10 records)... ✅ 10 OK
#   Processing batch 34/375 (10 records)... ✅ 10 OK
#   Processing batch 35/375 (10 records)... ✅ 10 OK
#   Processing batch 36/375 (10 records)... ✅ 10 OK
#   Processing batch 37/375 (10 records)... ✅ 10 OK
#   Processing batch 38/375 (10 records)... ✅ 10 OK
#   Processing batch 39/375 (10 records)... ✅ 10 OK
#   Processing batch 40/375 (10 records)... ✅ 10 OK
#   Processing batch 41/375 (10 records)... ✅ 10 OK
#   Processing batch 42/375 (10 records)... ✅ 10 OK
#   Processing batch 43/375 (10 records)... ✅ 10 OK
#   Processing batch 44/375 (10 records)... ✅ 10 OK
#   Processing batch 45/375 (10 records)... ✅ 10 OK
#   Processing batch 46/375 (10 records)... ✅ 10 OK
#   Processing batch 47/375 (10 records)... ✅ 10 OK
#   Processing batch 48/375 (10 records)... ✅ 10 OK
#   Processing batch 49/375 (10 records)... ✅ 10 OK
#   Processing batch 50/375 (10 records)... ✅ 10 OK
#   Processing batch 51/375 (10 records)... ✅ 10 OK
#   Processing batch 52/375 (10 records)... ✅ 10 OK
#   Processing batch 53/375 (10 records)... ✅ 10 OK
#   Processing batch 54/375 (10 records)... ✅ 10 OK
#   Processing batch 55/375 (10 records)... ✅ 10 OK
#   Processing batch 56/375 (10 records)... ✅ 10 OK
#   Processing batch 57/375 (10 records)... ✅ 10 OK
#   Processing batch 58/375 (10 records)... ✅ 10 OK
#   Processing batch 59/375 (10 records)... ✅ 10 OK
#   Processing batch 60/375 (10 records)... ✅ 10 OK
#   Processing batch 61/375 (10 records)... ✅ 10 OK
#   Processing batch 62/375 (10 records)... ✅ 10 OK
#   Processing batch 63/375 (10 records)... ✅ 10 OK
#   Processing batch 64/375 (10 records)... ✅ 10 OK
#   Processing batch 65/375 (10 records)... ✅ 10 OK
#   Processing batch 66/375 (10 records)... ✅ 10 OK
#   Processing batch 67/375 (10 records)... ✅ 10 OK
#   Processing batch 68/375 (10 records)... ✅ 10 OK
#   Processing batch 69/375 (10 records)... ✅ 10 OK
#   Processing batch 70/375 (10 records)... ✅ 10 OK
#   Processing batch 71/375 (10 records)... ✅ 10 OK
#   Processing batch 72/375 (10 records)... ✅ 10 OK
#   Processing batch 73/375 (10 records)... ✅ 10 OK
#   Processing batch 74/375 (10 records)... ✅ 10 OK
#   Processing batch 75/375 (10 records)... ✅ 10 OK
#   Processing batch 76/375 (10 records)... ✅ 10 OK
#   Processing batch 77/375 (10 records)... ✅ 10 OK
#   Processing batch 78/375 (10 records)... ✅ 10 OK
#   Processing batch 79/375 (10 records)... ✅ 10 OK
#   Processing batch 80/375 (10 records)... ✅ 10 OK
#   Processing batch 81/375 (10 records)... ✅ 10 OK
#   Processing batch 82/375 (10 records)... ✅ 10 OK
#   Processing batch 83/375 (10 records)... ✅ 10 OK
#   Processing batch 84/375 (10 records)... ✅ 10 OK
#   Processing batch 85/375 (10 records)... ✅ 10 OK
#   Processing batch 86/375 (10 records)... ✅ 10 OK
#   Processing batch 87/375 (10 records)... ✅ 10 OK
#   Processing batch 88/375 (10 records)... ✅ 10 OK
#   Processing batch 89/375 (10 records)... ✅ 10 OK
#   Processing batch 90/375 (10 records)... ✅ 10 OK
#   Processing batch 91/375 (10 records)... ✅ 10 OK
#   Processing batch 92/375 (10 records)... ✅ 10 OK
#   Processing batch 93/375 (10 records)... ✅ 10 OK
#   Processing batch 94/375 (10 records)... ✅ 10 OK
#   Processing batch 95/375 (10 records)... ✅ 10 OK
#   Processing batch 96/375 (10 records)... ✅ 10 OK
#   Processing batch 97/375 (10 records)... ✅ 10 OK
#   Processing batch 98/375 (10 records)... ✅ 10 OK
#   Processing batch 99/375 (10 records)... ✅ 10 OK
#   Processing batch 100/375 (10 records)... ✅ 10 OK
#   Processing batch 101/375 (10 records)... ✅ 10 OK
#   Processing batch 102/375 (10 records)... ✅ 10 OK
#   Processing batch 103/375 (10 records)... ✅ 10 OK
#   Processing batch 104/375 (10 records)... ✅ 10 OK
#   Processing batch 105/375 (10 records)... ✅ 10 OK
#   Processing batch 106/375 (10 records)... ✅ 10 OK
#   Processing batch 107/375 (10 records)... ✅ 10 OK
#   Processing batch 108/375 (10 records)... ✅ 10 OK
#   Processing batch 109/375 (10 records)... ✅ 10 OK
#   Processing batch 110/375 (10 records)... ✅ 10 OK
#   Processing batch 111/375 (10 records)... ✅ 10 OK
#   Processing batch 112/375 (10 records)... ✅ 10 OK
#   Processing batch 113/375 (10 records)... ✅ 10 OK
#   Processing batch 114/375 (10 records)... ✅ 10 OK
#   Processing batch 115/375 (10 records)... ✅ 10 OK
#   Processing batch 116/375 (10 records)... ✅ 10 OK
#   Processing batch 117/375 (10 records)... ✅ 10 OK
#   Processing batch 118/375 (10 records)... ✅ 10 OK
#   Processing batch 119/375 (10 records)... ✅ 10 OK
#   Processing batch 120/375 (10 records)... ✅ 10 OK
#   Processing batch 121/375 (10 records)... ✅ 10 OK
#   Processing batch 122/375 (10 records)... ✅ 10 OK
#   Processing batch 123/375 (10 records)... ✅ 10 OK
#   Processing batch 124/375 (10 records)... ✅ 10 OK
#   Processing batch 125/375 (10 records)... ✅ 10 OK
#   Processing batch 126/375 (10 records)... ✅ 10 OK
#   Processing batch 127/375 (10 records)... ✅ 10 OK
#   Processing batch 128/375 (10 records)... ✅ 10 OK
#   Processing batch 129/375 (10 records)... ✅ 10 OK
#   Processing batch 130/375 (10 records)... ✅ 10 OK
#   Processing batch 131/375 (10 records)... ✅ 10 OK
#   Processing batch 132/375 (10 records)... ✅ 10 OK
#   Processing batch 133/375 (10 records)... ✅ 10 OK
#   Processing batch 134/375 (10 records)... ✅ 10 OK
#   Processing batch 135/375 (10 records)... ✅ 10 OK
#   Processing batch 136/375 (10 records)... ✅ 10 OK
#   Processing batch 137/375 (10 records)... ✅ 10 OK
#   Processing batch 138/375 (10 records)... ✅ 10 OK
#   Processing batch 139/375 (10 records)... ✅ 10 OK
#   Processing batch 140/375 (10 records)... ✅ 10 OK
#   Processing batch 141/375 (10 records)... ✅ 10 OK
#   Processing batch 142/375 (10 records)... ✅ 10 OK
#   Processing batch 143/375 (10 records)... ✅ 10 OK
#   Processing batch 144/375 (10 records)... ✅ 10 OK
#   Processing batch 145/375 (10 records)... ✅ 10 OK
#   Processing batch 146/375 (10 records)... ✅ 10 OK
#   Processing batch 147/375 (10 records)... ✅ 10 OK
#   Processing batch 148/375 (10 records)... ✅ 10 OK
#   Processing batch 149/375 (10 records)... ✅ 10 OK
#   Processing batch 150/375 (10 records)... ✅ 10 OK
#   Processing batch 151/375 (10 records)... ✅ 10 OK
#   Processing batch 152/375 (10 records)... ✅ 10 OK
#   Processing batch 153/375 (10 records)... ✅ 10 OK
#   Processing batch 154/375 (10 records)... ✅ 10 OK
#   Processing batch 155/375 (10 records)... ✅ 10 OK
#   Processing batch 156/375 (10 records)... ✅ 10 OK
#   Processing batch 157/375 (10 records)... ✅ 10 OK
#   Processing batch 158/375 (10 records)... ✅ 10 OK
#   Processing batch 159/375 (10 records)... ✅ 10 OK
#   Processing batch 160/375 (10 records)... ✅ 10 OK
#   Processing batch 161/375 (10 records)... ✅ 10 OK
#   Processing batch 162/375 (10 records)... ✅ 10 OK
#   Processing batch 163/375 (10 records)... ✅ 10 OK
#   Processing batch 164/375 (10 records)... ✅ 10 OK
#   Processing batch 165/375 (10 records)... ✅ 10 OK
#   Processing batch 166/375 (10 records)... ✅ 10 OK
#   Processing batch 167/375 (10 records)... ✅ 10 OK
#   Processing batch 168/375 (10 records)... ✅ 10 OK
#   Processing batch 169/375 (10 records)... ✅ 10 OK
#   Processing batch 170/375 (10 records)... ✅ 10 OK
#   Processing batch 171/375 (10 records)... ✅ 10 OK
#   Processing batch 172/375 (10 records)... ✅ 10 OK
#   Processing batch 173/375 (10 records)... ✅ 10 OK
#   Processing batch 174/375 (10 records)... ✅ 10 OK
#   Processing batch 175/375 (10 records)... ✅ 10 OK
#   Processing batch 176/375 (10 records)... ✅ 10 OK
#   Processing batch 177/375 (10 records)... ✅ 10 OK
#   Processing batch 178/375 (10 records)... ✅ 10 OK
#   Processing batch 179/375 (10 records)... ✅ 10 OK
#   Processing batch 180/375 (10 records)... ✅ 10 OK
#   Processing batch 181/375 (10 records)... ✅ 10 OK
#   Processing batch 182/375 (10 records)... ✅ 10 OK
#   Processing batch 183/375 (10 records)... ✅ 10 OK
#   Processing batch 184/375 (10 records)... ✅ 10 OK
#   Processing batch 185/375 (10 records)... ✅ 10 OK
#   Processing batch 186/375 (10 records)... ✅ 10 OK
#   Processing batch 187/375 (10 records)... ✅ 10 OK
#   Processing batch 188/375 (10 records)... ✅ 10 OK
#   Processing batch 189/375 (10 records)... ✅ 10 OK
#   Processing batch 190/375 (10 records)... ✅ 10 OK
#   Processing batch 191/375 (10 records)... ✅ 10 OK
#   Processing batch 192/375 (10 records)... ✅ 10 OK
#   Processing batch 193/375 (10 records)... ✅ 10 OK
#   Processing batch 194/375 (10 records)... ✅ 10 OK
#   Processing batch 195/375 (10 records)... ✅ 10 OK
#   Processing batch 196/375 (10 records)... ✅ 10 OK
#   Processing batch 197/375 (10 records)... ✅ 10 OK
#   Processing batch 198/375 (10 records)... ✅ 10 OK
#   Processing batch 199/375 (10 records)... ✅ 10 OK
#   Processing batch 200/375 (10 records)... ✅ 10 OK
#   Processing batch 201/375 (10 records)... ✅ 10 OK
#   Processing batch 202/375 (10 records)... ✅ 10 OK
#   Processing batch 203/375 (10 records)... ✅ 10 OK
#   Processing batch 204/375 (10 records)... ✅ 10 OK
#   Processing batch 205/375 (10 records)... ✅ 10 OK
#   Processing batch 206/375 (10 records)... ✅ 10 OK
#   Processing batch 207/375 (10 records)... ✅ 10 OK
#   Processing batch 208/375 (10 records)... ✅ 10 OK
#   Processing batch 209/375 (10 records)... ✅ 10 OK
#   Processing batch 210/375 (10 records)... ✅ 10 OK
#   Processing batch 211/375 (10 records)... ✅ 10 OK
#   Processing batch 212/375 (10 records)... ✅ 10 OK
#   Processing batch 213/375 (10 records)... ✅ 10 OK
#   Processing batch 214/375 (10 records)... ✅ 10 OK
#   Processing batch 215/375 (10 records)... ✅ 10 OK
#   Processing batch 216/375 (10 records)... ✅ 10 OK
#   Processing batch 217/375 (10 records)... ✅ 10 OK
#   Processing batch 218/375 (10 records)... ✅ 10 OK
#   Processing batch 219/375 (10 records)... ✅ 10 OK
#   Processing batch 220/375 (10 records)... ✅ 10 OK
#   Processing batch 221/375 (10 records)... ✅ 10 OK
#   Processing batch 222/375 (10 records)... ✅ 10 OK
#   Processing batch 223/375 (10 records)... ✅ 10 OK
#   Processing batch 224/375 (10 records)... ✅ 10 OK
#   Processing batch 225/375 (10 records)... ✅ 10 OK
#   Processing batch 226/375 (10 records)... ✅ 10 OK
#   Processing batch 227/375 (10 records)... ✅ 10 OK
#   Processing batch 228/375 (10 records)... ✅ 10 OK
#   Processing batch 229/375 (10 records)... ✅ 10 OK
#   Processing batch 230/375 (10 records)... ✅ 10 OK
#   Processing batch 231/375 (10 records)... ✅ 10 OK
#   Processing batch 232/375 (10 records)... ✅ 10 OK
#   Processing batch 233/375 (10 records)... ✅ 10 OK
#   Processing batch 234/375 (10 records)... ✅ 10 OK
#   Processing batch 235/375 (10 records)... ✅ 10 OK
#   Processing batch 236/375 (10 records)... ✅ 10 OK
#   Processing batch 237/375 (10 records)... ✅ 10 OK
#   Processing batch 238/375 (10 records)... ✅ 10 OK
#   Processing batch 239/375 (10 records)... ✅ 10 OK
#   Processing batch 240/375 (10 records)... ✅ 10 OK
#   Processing batch 241/375 (10 records)... ✅ 10 OK
#   Processing batch 242/375 (10 records)... ✅ 10 OK
#   Processing batch 243/375 (10 records)... ✅ 10 OK
#   Processing batch 244/375 (10 records)... ✅ 10 OK
#   Processing batch 245/375 (10 records)... ✅ 10 OK
#   Processing batch 246/375 (10 records)... ✅ 10 OK
#   Processing batch 247/375 (10 records)... ✅ 10 OK
#   Processing batch 248/375 (10 records)... ✅ 10 OK
#   Processing batch 249/375 (10 records)... ✅ 10 OK
#   Processing batch 250/375 (10 records)... ✅ 10 OK
#   Processing batch 251/375 (10 records)... ✅ 10 OK
#   Processing batch 252/375 (10 records)... ✅ 10 OK
#   Processing batch 253/375 (10 records)... ✅ 10 OK
#   Processing batch 254/375 (10 records)... ✅ 10 OK
#   Processing batch 255/375 (10 records)... ✅ 10 OK
#   Processing batch 256/375 (10 records)... ✅ 10 OK
#   Processing batch 257/375 (10 records)... ✅ 10 OK
#   Processing batch 258/375 (10 records)... ✅ 10 OK
#   Processing batch 259/375 (10 records)... ✅ 10 OK
#   Processing batch 260/375 (10 records)... ✅ 10 OK
#   Processing batch 261/375 (10 records)... ✅ 10 OK
#   Processing batch 262/375 (10 records)... ✅ 10 OK
#   Processing batch 263/375 (10 records)... ✅ 10 OK
#   Processing batch 264/375 (10 records)... ✅ 10 OK
#   Processing batch 265/375 (10 records)... ✅ 10 OK
#   Processing batch 266/375 (10 records)... ✅ 10 OK
#   Processing batch 267/375 (10 records)... ✅ 10 OK
#   Processing batch 268/375 (10 records)... ✅ 10 OK
#   Processing batch 269/375 (10 records)... ✅ 10 OK
#   Processing batch 270/375 (10 records)... ✅ 10 OK
#   Processing batch 271/375 (10 records)... ✅ 10 OK
#   Processing batch 272/375 (10 records)... ✅ 10 OK
#   Processing batch 273/375 (10 records)... ✅ 10 OK
#   Processing batch 274/375 (10 records)... ✅ 10 OK
#   Processing batch 275/375 (10 records)... ✅ 10 OK
#   Processing batch 276/375 (10 records)... ✅ 10 OK
#   Processing batch 277/375 (10 records)... ✅ 10 OK
#   Processing batch 278/375 (10 records)... ✅ 10 OK
#   Processing batch 279/375 (10 records)... ✅ 10 OK
#   Processing batch 280/375 (10 records)... ✅ 10 OK
#   Processing batch 281/375 (10 records)... ✅ 10 OK
#   Processing batch 282/375 (10 records)... ✅ 10 OK
#   Processing batch 283/375 (10 records)... ✅ 10 OK
#   Processing batch 284/375 (10 records)... ✅ 10 OK
#   Processing batch 285/375 (10 records)... ✅ 10 OK
#   Processing batch 286/375 (10 records)... ✅ 10 OK
#   Processing batch 287/375 (10 records)... ✅ 10 OK
#   Processing batch 288/375 (10 records)... ✅ 10 OK
#   Processing batch 289/375 (10 records)... ✅ 10 OK
#   Processing batch 290/375 (10 records)... ✅ 10 OK
#   Processing batch 291/375 (10 records)... ✅ 10 OK
#   Processing batch 292/375 (10 records)... ✅ 10 OK
#   Processing batch 293/375 (10 records)... ✅ 10 OK
#   Processing batch 294/375 (10 records)... ✅ 10 OK
#   Processing batch 295/375 (10 records)... ✅ 10 OK
#   Processing batch 296/375 (10 records)... ✅ 10 OK
#   Processing batch 297/375 (10 records)... ✅ 10 OK
#   Processing batch 298/375 (10 records)... ✅ 10 OK
#   Processing batch 299/375 (10 records)... ✅ 10 OK
#   Processing batch 300/375 (10 records)... ✅ 10 OK
#   Processing batch 301/375 (10 records)... ✅ 10 OK
#   Processing batch 302/375 (10 records)... ✅ 10 OK
#   Processing batch 303/375 (10 records)... ✅ 10 OK
#   Processing batch 304/375 (10 records)... ✅ 10 OK
#   Processing batch 305/375 (10 records)... ✅ 10 OK
#   Processing batch 306/375 (10 records)... ✅ 10 OK
#   Processing batch 307/375 (10 records)... ✅ 10 OK
#   Processing batch 308/375 (10 records)... ✅ 10 OK
#   Processing batch 309/375 (10 records)... ✅ 10 OK
#   Processing batch 310/375 (10 records)... ✅ 10 OK
#   Processing batch 311/375 (10 records)... ✅ 10 OK
#   Processing batch 312/375 (10 records)... ✅ 10 OK
#   Processing batch 313/375 (10 records)... ✅ 10 OK
#   Processing batch 314/375 (10 records)... ✅ 10 OK
#   Processing batch 315/375 (10 records)... ✅ 10 OK
#   Processing batch 316/375 (10 records)... ✅ 10 OK
#   Processing batch 317/375 (10 records)... ✅ 10 OK
#   Processing batch 318/375 (10 records)... ✅ 10 OK
#   Processing batch 319/375 (10 records)... ✅ 10 OK
#   Processing batch 320/375 (10 records)... ✅ 10 OK
#   Processing batch 321/375 (10 records)... ✅ 10 OK
#   Processing batch 322/375 (10 records)... ✅ 10 OK
#   Processing batch 323/375 (10 records)... ✅ 10 OK
#   Processing batch 324/375 (10 records)... ✅ 10 OK
#   Processing batch 325/375 (10 records)... ✅ 10 OK
#   Processing batch 326/375 (10 records)... ✅ 10 OK
#   Processing batch 327/375 (10 records)... ✅ 10 OK
#   Processing batch 328/375 (10 records)... ✅ 10 OK
#   Processing batch 329/375 (10 records)... ✅ 10 OK
#   Processing batch 330/375 (10 records)... ✅ 10 OK
#   Processing batch 331/375 (10 records)... ✅ 10 OK
#   Processing batch 332/375 (10 records)... ✅ 10 OK
#   Processing batch 333/375 (10 records)... ✅ 10 OK
#   Processing batch 334/375 (10 records)... ✅ 10 OK
#   Processing batch 335/375 (10 records)... ✅ 10 OK
#   Processing batch 336/375 (10 records)... ✅ 10 OK
#   Processing batch 337/375 (10 records)... ✅ 10 OK
#   Processing batch 338/375 (10 records)... ✅ 10 OK
#   Processing batch 339/375 (10 records)... ✅ 10 OK
#   Processing batch 340/375 (10 records)... ✅ 10 OK
#   Processing batch 341/375 (10 records)... ✅ 10 OK
#   Processing batch 342/375 (10 records)... ✅ 10 OK
#   Processing batch 343/375 (10 records)... ✅ 10 OK
#   Processing batch 344/375 (10 records)... ✅ 10 OK
#   Processing batch 345/375 (10 records)... ✅ 10 OK
#   Processing batch 346/375 (10 records)... ✅ 10 OK
#   Processing batch 347/375 (10 records)... ✅ 10 OK
#   Processing batch 348/375 (10 records)... ✅ 10 OK
#   Processing batch 349/375 (10 records)... ✅ 10 OK
#   Processing batch 350/375 (10 records)... ✅ 10 OK
#   Processing batch 351/375 (10 records)... ✅ 10 OK
#   Processing batch 352/375 (10 records)... ✅ 10 OK
#   Processing batch 353/375 (10 records)... ✅ 10 OK
#   Processing batch 354/375 (10 records)... ✅ 10 OK
#   Processing batch 355/375 (10 records)... ✅ 10 OK
#   Processing batch 356/375 (10 records)... ✅ 10 OK
#   Processing batch 357/375 (10 records)... ✅ 10 OK
#   Processing batch 358/375 (10 records)... ✅ 10 OK
#   Processing batch 359/375 (10 records)... ✅ 10 OK
#   Processing batch 360/375 (10 records)... ✅ 10 OK
#   Processing batch 361/375 (10 records)... ✅ 10 OK
#   Processing batch 362/375 (10 records)... ✅ 10 OK
#   Processing batch 363/375 (10 records)... ✅ 10 OK
#   Processing batch 364/375 (10 records)... ✅ 10 OK
#   Processing batch 365/375 (10 records)... ✅ 10 OK
#   Processing batch 366/375 (10 records)... ✅ 10 OK
#   Processing batch 367/375 (10 records)... ✅ 10 OK
#   Processing batch 368/375 (10 records)... ✅ 10 OK
#   Processing batch 369/375 (10 records)... ✅ 10 OK
#   Processing batch 370/375 (10 records)... ✅ 10 OK
#   Processing batch 371/375 (10 records)... ✅ 10 OK
#   Processing batch 372/375 (10 records)... ✅ 10 OK
#   Processing batch 373/375 (10 records)... ✅ 10 OK
#   Processing batch 374/375 (10 records)... ✅ 10 OK
#   Processing batch 375/375 (6 records)... ✅ 6 OK
#
# ✅ Successfully updated: 3746 ES accounts
#
# 🔄 Bidirectional tracking complete:
#    BBF → ES_Legacy_ID__c (original ES ID)
#    ES → BBF_New_Id__c (new BBF ID)

# %%
# === VERIFY MIGRATION ===

print("\n" + "=" * 80)
print("VERIFYING MIGRATION")
print("=" * 80)

if len(successful_inserts) == 0:
    print("⚠️  No accounts to verify")
else:
    # Query BBF for sample of inserted accounts
    sample_ids = [item["bbf_id"] for item in successful_inserts[:10]]
    id_list = "','".join(sample_ids)

    verify_query = (
        f"SELECT Id, Name, ES_Legacy_ID__c FROM Account WHERE Id IN ('{id_list}')"
    )

    try:
        result = bbf_sf.query_all(verify_query)
        bbf_verify = result["records"]

        print(f"✅ Verified {len(bbf_verify)} accounts in BBF")
        print("\nSample verified accounts (first 3):")
        for account in bbf_verify[:3]:
            print(f"  - {account['Name']}")
            print(f"    BBF ID: {account['Id']}")
            print(f"    ES ID:  {account.get('ES_Legacy_ID__c', 'N/A')}")

    except Exception as e:
        print(f"⚠️  Could not verify: {e}")
# Out:
# ================================================================================
# VERIFYING MIGRATION
# ================================================================================
# ✅ Verified 10 accounts in BBF
#
# Sample verified accounts (first 3):
#   - Vista Springs Quail Highlands
#     BBF ID: 001Ea00001IaGKyIAN
#     ES ID:  0010B00001jOjnlQAC
#   - GTT
#     BBF ID: 001Ea00001IaGKzIAN
#     ES ID:  0010B00001jOrP8QAK
#   - Physicians Ambulance Service Inc.
#     BBF ID: 001Ea00001IaGL0IAN
#     ES ID:  0010B00001jOxkjQAC

# %%
# === CREATE EXCEL OUTPUT ===

print("\n" + "=" * 80)
print("CREATING EXCEL OUTPUT")
print("=" * 80)

# Combine all results
all_results = []

for item in successful_inserts:
    all_results.append(
        {
            "ES_Account_Id": item["es_id"],
            "BBF_Account_Id": item["bbf_id"],
            "Account_Name": item["name"],
            "Status": "SUCCESS",
            "Error": "",
        }
    )

for item in failed_inserts:
    all_results.append(
        {
            "ES_Account_Id": item["es_id"],
            "BBF_Account_Id": "",
            "Account_Name": item["name"],
            "Status": "FAILED",
            "Error": str(item["errors"]),
        }
    )

# Identify name collisions
name_collisions = []
for item in failed_inserts:
    error_str = str(item["errors"])
    if "DUPLICATE_VALUE" in error_str and "Name" in error_str:
        name_collisions.append(
            {
                "ES_Account_Id": item["es_id"],
                "Account_Name": item["name"],
                "Error_Details": error_str,
            }
        )

print(f"Identified {len(name_collisions)} name collision errors")

# Create Excel workbook
wb = Workbook()
wb.remove(wb.active)

# Styles
header_font = Font(bold=True, size=12, color="FFFFFF")
header_fill = PatternFill(start_color="4472C4", end_color="4472C4", fill_type="solid")
header_alignment = Alignment(horizontal="center", vertical="center")
thin_border = Border(
    left=Side(style="thin"),
    right=Side(style="thin"),
    top=Side(style="thin"),
    bottom=Side(style="thin"),
)

status_colors = {"SUCCESS": "00C851", "FAILED": "FF4444"}

# --- SHEET 1: Migration Results ---
ws1 = wb.create_sheet("Migration Results")
headers1 = ["ES Account ID", "BBF Account ID", "Account Name", "Status", "Error"]
ws1.append(headers1)

for col, header in enumerate(headers1, 1):
    cell = ws1.cell(row=1, column=col)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment

for row_idx, r in enumerate(all_results, 2):
    ws1.append(
        [
            r["ES_Account_Id"],
            r["BBF_Account_Id"],
            r["Account_Name"],
            r["Status"],
            r["Error"],
        ]
    )
    fill_color = status_colors.get(r["Status"], "FFFFFF")
    for col in range(1, len(headers1) + 1):
        cell = ws1.cell(row=row_idx, column=col)
        cell.fill = PatternFill("solid", fgColor=fill_color)
        cell.border = thin_border

for col in ws1.columns:
    max_length = max(len(str(cell.value)) for cell in col)
    ws1.column_dimensions[col[0].column_letter].width = min(max_length + 2, 60)

ws1.freeze_panes = "A2"

# --- SHEET 2: Summary ---
ws2 = wb.create_sheet("Summary")
ws2.append(["ES → BBF Account Migration Summary"])
ws2["A1"].font = Font(bold=True, size=14)
ws2.append([])
ws2.append(["Run Type:", "TEST MODE" if TEST_MODE else "FULL MIGRATION"])
ws2.append(["Timestamp:", datetime.now().strftime("%Y-%m-%d %H:%M:%S")])
ws2.append(["Owner ID:", OWNER_ID])
ws2.append([])
ws2.append(["Metric", "Count"])
ws2["A7"].font = Font(bold=True)
ws2["B7"].font = Font(bold=True)
ws2.append(["Total Accounts Processed", len(all_results)])
ws2.append(["Successful Inserts", len(successful_inserts)])
ws2.append(["Failed Inserts", len(failed_inserts)])
ws2.append(["Name Collisions", len(name_collisions)])
ws2.append(
    [
        "Success Rate",
        (
            f"{len(successful_inserts)/len(all_results)*100:.1f}%"
            if len(all_results) > 0
            else "0%"
        ),
    ]
)

# --- SHEET 3: ID Mapping ---
ws3 = wb.create_sheet("ID Mapping")
headers3 = ["ES Account ID", "BBF Account ID", "Account Name"]
ws3.append(headers3)

for col, header in enumerate(headers3, 1):
    cell = ws3.cell(row=1, column=col)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment

for item in successful_inserts:
    ws3.append([item["es_id"], item["bbf_id"], item["name"]])

for col in ws3.columns:
    max_length = max(len(str(cell.value)) for cell in col)
    ws3.column_dimensions[col[0].column_letter].width = min(max_length + 2, 50)

ws3.freeze_panes = "A2"

# --- SHEET 4: Name Collisions ---
ws4 = wb.create_sheet("Name Collisions")
headers4 = ["ES Account ID", "Account Name (Duplicate)", "Error Details"]
ws4.append(headers4)

for col, header in enumerate(headers4, 1):
    cell = ws4.cell(row=1, column=col)
    cell.font = Font(bold=True, size=12, color="FFFFFF")
    cell.fill = PatternFill(start_color="FF4444", end_color="FF4444", fill_type="solid")
    cell.alignment = header_alignment

for collision in name_collisions:
    ws4.append(
        [
            collision["ES_Account_Id"],
            collision["Account_Name"],
            collision["Error_Details"],
        ]
    )

for col in ws4.columns:
    max_length = max(len(str(cell.value)) for cell in col) if list(col) else 10
    ws4.column_dimensions[col[0].column_letter].width = min(max_length + 2, 70)

ws4.freeze_panes = "A2"

# Save workbook
wb.save(output_file)
print(f"\n✅ Excel output saved to: {output_file}")
print(f"   📊 Sheet 1: Migration Results ({len(all_results)} accounts, color-coded)")
print(f"   📈 Sheet 2: Summary (metrics and stats)")
print(f"   🔗 Sheet 3: ID Mapping ({len(successful_inserts)} successful mappings)")
print(f"   ⚠️  Sheet 4: Name Collisions ({len(name_collisions)} duplicate name errors)")
# Out:
# ================================================================================
# CREATING EXCEL OUTPUT
# ================================================================================
# Identified 0 name collision errors
#
# ✅ Excel output saved to: es_bbf_account_migration_20251210_185012.xlsx
#    📊 Sheet 1: Migration Results (4013 accounts, color-coded)
#    📈 Sheet 2: Summary (metrics and stats)
#    🔗 Sheet 3: ID Mapping (3746 successful mappings)
#    ⚠️  Sheet 4: Name Collisions (0 duplicate name errors)

# %%
# === FINAL SUMMARY ===

print("\n" + "=" * 80)
print("MIGRATION COMPLETE")
print("=" * 80)
print(f"ES Accounts queried: {len(es_accounts)}")
print(f"BBF Accounts inserted: {len(successful_inserts)}")
print(
    f"Success rate: {len(successful_inserts)/len(es_accounts)*100:.1f}%"
    if len(es_accounts) > 0
    else "0%"
)
print(f"\nExcel output: {output_file}")

if TEST_MODE:
    print("\n🔄 TEST MODE complete. Only migrated " + str(TEST_LIMIT) + " accounts.")
    print("   To migrate ALL accounts, set TEST_MODE = False in Cell 2 and re-run.")
else:
    print("\n✅ FULL MIGRATION complete!")
    print("   Ready for child object migrations.")
    print("   Next: Migrate Contacts, BANs, Opportunities using ID Mapping sheet")

if len(name_collisions) > 0:
    print(f"\n⚠️  {len(name_collisions)} accounts failed due to duplicate names")
    print("   Check 'Name Collisions' sheet in Excel")
    print("   Rename in ES and re-run (already-migrated accounts will be skipped)")
# Out:
# ================================================================================
# MIGRATION COMPLETE
# ================================================================================
# ES Accounts queried: 4013
# BBF Accounts inserted: 3746
# Success rate: 93.3%
#
# Excel output: es_bbf_account_migration_20251210_185012.xlsx
#
# ✅ FULL MIGRATION complete!
#    Ready for child object migrations.
#    Next: Migrate Contacts, BANs, Opportunities using ID Mapping sheet

# %% [markdown]
# ---
# ## Next Steps: Child Object Migration
#
# After Account migration is complete, use the **ID Mapping sheet** from the Excel output to migrate child objects:
#
# 1. **Contact** (needs Account ID)
# 2. **BAN__c** (needs Account ID)
# 3. **BAN_Contact__c** (needs BAN + Contact IDs)
# 4. **Opportunity** (needs Account + Contact IDs)
# 5. **Opportunity_Site__c** (needs Opportunity ID)
#
# See `migration_script_template.py` for child object migration examples.

# %% [markdown]
# ---
# ## Package Installation
#
# If you need to install packages, run this cell:

# %%
# Install required packages
# !pip install simple-salesforce pandas openpyxl

# %% [markdown]
# ## Delete Migrated Accounts from BBF
#
# List<Account>a = [SELECT Id, Name FROM Account WHERE Owner.Name = 'Everstream Legacy'];
# System.debug(a);
# delete a;
#
# ## remove BBF_New_Id__c for moved orders
# List<Account> accountIds = [SELECT Id, BBF_New_Id__c FROM Account WHERE BBF_New_Id__c != NULL OR BBF_New_Id__c !=''];
# System.debug(accountIds);
# for (Account a : accountIds){
#     a.BBF_New_Id__c = NULL;
# }
# update accountIds;
