# %% [markdown]
# # ES → BBF Salesforce Off-Net Migration
#
# This notebook migrates Off_Net__c records from ES Salesforce to BBF Salesforce.
#
# ## Prerequisites
# - **Service__c migration must be completed first** (Orders have BBF_New_Id__c populated)
# - **Location__c migration must be completed first** (Address__c has BBF_New_Id__c populated)
# - ES Off_Net__c records must have BBF_New_Id__c field created
#
# ## Object Mapping
# - **ES Source:** Off_Net__c (Custom Object)
# - **BBF Target:** Off_Net__c (Custom Object)
#
# ## Process Overview
# 1. Connect to both ES (source) and BBF (target) Salesforce orgs
# 2. Query Off_Net__c from ES where:
#    - Related Service (via Order lookup in ES) has BBF_New_Id__c populated (Service already migrated)
#    - Off_Net__c does NOT have BBF_New_Id__c populated (not yet migrated)
# 3. Transform ES Off_Net__c for BBF Off_Net__c schema:
#    - Map Service lookup → BBF Service ID via ES Order relationship
#    - Map Location lookups → BBF Location IDs via ES Address relationship
#    - Add ES_Legacy_ID__c = ES Off_Net.Id (for tracking)
# 4. Insert Off_Net__c to BBF Salesforce
# 5. Update ES Off_Net__c with BBF_New_Id__c = BBF Off_Net.Id
# 6. Create ID mapping: ES Off_Net ID → BBF Off_Net ID
# 7. Output results to Excel with color-coded status
#
# ## Field Tracking Strategy
# **In BBF Off_Net__c:** `ES_Legacy_ID__c` stores original ES Off_Net ID
# - Text(18), External ID, Unique
#
# **In ES Off_Net__c:**
# - `BBF_New_Id__c` stores new BBF Off_Net ID after migration (Text 18)
#
# ## Safety
# - `TEST_MODE = True` by default (limits to 10 Off-Net records)
# - Only migrates Off_Net__c where related Service is already migrated
# - Skips Off_Net__c already migrated (BBF_New_Id__c populated)
# - Skips Off_Net__c with missing required parent lookups

# %%
# === SETUP & IMPORTS ===

import sys
import pandas as pd
from simple_salesforce import Salesforce
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
from datetime import datetime
import os

print(f"Python: {sys.executable}")
print(f"Pandas: {pd.__version__}")
print("✅ Set-up successful")

# %%
# === CONFIGURATION ===

# ES UAT Credentials
ES_USERNAME = "sfdcapi@everstream.net.uat"
ES_PASSWORD = "ZXasqw1234!@#$"
ES_TOKEN = "X0ation2CNmK5C0pV94M6vFYS"
ES_DOMAIN = "test"

# # ES (Source) Credentials - Production
# ES_USERNAME = "sfdcapi@everstream.net"
# ES_PASSWORD = "pV4CAxns8DQtJsBq!"
# ES_TOKEN = "r1uoYiusK19RbrflARydi86TA"
# ES_DOMAIN = "login"  # or 'test' for sandbox

# BBF (Target) Credentials
BBF_USERNAME = "vlettau@everstream.net"
BBF_PASSWORD = "MNlkpo0987)(*&"
BBF_TOKEN = "I4xmQLmm03cXl1O9qI2Z3XAAX"
BBF_DOMAIN = "test"  # or 'login' for production

# Migration Options
TEST_MODE = False  # ⚠️ Set to False to migrate ALL Off-Net records
TEST_LIMIT = 10  # Only used when TEST_MODE = True

# 👤 Off-Net Owner - Set all migrated Off-Net records to this user
OWNER_ID = "005Ea00000ZOGFZIA5"  # Same as other migrations

# Output Configuration
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_file = f"es_bbf_offnet_migration_{timestamp}.xlsx"

print("📋 Configuration loaded")
print(f"   TEST_MODE: {TEST_MODE}")
print(f"   Owner ID: {OWNER_ID}")
print(f"   Output: {output_file}")
print("\n⚠️  Note: Bulk API automatically handles batching (200 records/batch)")

# %%
# === CONNECT TO SALESFORCE ORGS ===

print("=" * 80)
print("CONNECTING TO SALESFORCE ORGS")
print("=" * 80)

# Connect to ES (source)
print("\n📌 Connecting to ES (source)...")
es_sf = Salesforce(
    username=ES_USERNAME,
    password=ES_PASSWORD,
    security_token=ES_TOKEN,
    domain=ES_DOMAIN,
)
print(f"✅ Connected to ES: {es_sf.sf_instance}")

# Connect to BBF (target)
print("\n📌 Connecting to BBF (target)...")
bbf_sf = Salesforce(
    username=BBF_USERNAME,
    password=BBF_PASSWORD,
    security_token=BBF_TOKEN,
    domain=BBF_DOMAIN,
)
print(f"✅ Connected to BBF: {bbf_sf.sf_instance}")

# %%
# === QUERY ES OFF_NET__C ===
# Only Off_Net__c where:
# 1. Related to an Order (via Implementation__c → Order lookup or other relationships)
# 2. That Order has BBF_New_Id__c populated (Service already migrated)
# 3. Off_Net__c does NOT have BBF_New_Id__c populated (not yet migrated)
#
# NOTE: ES Off_Net__c has Implementation__c (reference to Order) which we'll use
# to find the BBF Service ID

print("\n" + "=" * 80)
print("QUERYING ES OFF_NET__C")
print("=" * 80)

# Query Off_Net__c records related to migrated Services
# ES Off_Net__c.Implementation__c → Order (ES)
# We need Orders that have BBF_New_Id__c to link to BBF Service__c
query = """
    SELECT Id, Name,
           Implementation__c, Implementation__r.BBF_New_Id__c, Implementation__r.Name,
           Ban_Id__c, Circuit_Service_Id__c,
           Cost_MRC__c, Cost_NRC__c,
           Demarc_Loaction__c, Disconnect_Date__c,
           Entity__c, Facility_ID__c,
           Order_Charge__c, Order_Id__c,
           Order_circuit_type__c, Ordering_CLLI__c,
           PM_Order_Completed__c, Product_Summary__c,
           Project_Manager__c, Reason_For_Escalation__c,
           Service__c, Solution_ID__c,
           Third_Party_Cost_MRC__c, Third_Party_Cost_NRC__c,
           Third_Party_Provider_1__c, Third_Party_Provider_2__c,
           Location_1__c, Location_1__r.BBF_New_Id__c, Location_1__r.Name,
           Location_2__c, Location_2__r.BBF_New_Id__c, Location_2__r.Name,
           Off_Net_Vendor__c, Vendor_Name__c,
           Vendor_circuit_Id__c, Internal_Circuit_Id__c,
           Invoice_MRC__c, LEC_Order_Status__c,
           Off_Net_Type__c, Bandwidth__c,
           Circuit_Type__c, Term__c,
           Term_Agreement_Start_Date__c, Term_Agreement_End_Date__c,
           Vendor_Bill_Start_Date__c, Vendor_Bill_Stop_Date__c,
           OwnerId
    FROM Off_Net__c
    WHERE Implementation__r.BBF_New_Id__c != null
      AND Implementation__r.BBF_New_Id__c != ''
      AND (BBF_New_Id__c = null OR BBF_New_Id__c = '')
"""

# Add limit for test mode
if TEST_MODE:
    query += f" LIMIT {TEST_LIMIT}"

print(f"Query: {query[:500]}...")
print("\nExecuting query...")

result = es_sf.query_all(query)
es_offnets = result["records"]

print(f"✅ Found {len(es_offnets)} Off_Net__c records to migrate")

if len(es_offnets) > 0:
    sample = es_offnets[0]
    print(f"\nSample Off_Net__c:")
    print(f"  ID:                {sample['Id']}")
    print(f"  Name:              {sample.get('Name', 'N/A')}")
    print(f"  Circuit/Service:   {sample.get('Circuit_Service_Id__c', 'N/A')}")
    print(f"  ES Order:          {sample.get('Implementation__c', 'N/A')}")
    print(
        f"  BBF Service (target): {sample.get('Implementation__r', {}).get('BBF_New_Id__c', 'N/A')}"
    )
    print(f"  ES Location 1:     {sample.get('Location_1__c', 'N/A')}")
    print(
        f"  BBF Location 1 (target): {sample.get('Location_1__r', {}).get('BBF_New_Id__c', 'N/A')}"
    )
elif TEST_MODE:
    print("\n⚠️  No unmigrated Off_Net__c records found in test set")
    print("   Check: Are there ES Off_Net__c with parent Services migrated?")
else:
    print(
        "\n✅ All Off_Net__c records have been migrated (or no eligible records found)!"
    )

# %%
# === TRANSFORM FOR BBF OFF_NET__C ===
# Day 1 Migration: REQUIRED FIELDS ONLY (no booleans - they default to False)

print("\n" + "=" * 80)
print("TRANSFORMING OFF_NET__C FOR BBF (REQUIRED FIELDS ONLY)")
print("=" * 80)

bbf_offnets = []
skipped_no_bbf_service = []

for es_offnet in es_offnets:
    # Get the BBF Service ID from the parent Order (Implementation__c)
    # Note: Service__c is OPTIONAL in BBF but we include it if available
    bbf_service_id = None
    if es_offnet.get("Implementation__r") and es_offnet["Implementation__r"].get(
        "BBF_New_Id__c"
    ):
        bbf_service_id = es_offnet["Implementation__r"]["BBF_New_Id__c"]

    # Build Off-Net name
    offnet_name = (
        es_offnet.get("Circuit_Service_Id__c")
        or es_offnet.get("Name")
        or "Unknown Off-Net"
    )

    # =========================================================================
    # BBF Off_Net__c - REQUIRED FIELDS ONLY (Day 1 Migration)
    # Only Name and OwnerId are required
    # =========================================================================
    bbf_offnet = {
        # 🔴 REQUIRED: Name (max 80 chars)
        "Name": offnet_name[:80],
        
        # 🔴 REQUIRED: OwnerId
        "OwnerId": OWNER_ID,
        
        # 🔗 Tracking field
        "ES_Legacy_ID__c": es_offnet["Id"],
    }
    
    # Add Service lookup if available (optional)
    if bbf_service_id:
        bbf_offnet["Service__c"] = bbf_service_id

    bbf_offnets.append(bbf_offnet)

print(f"✅ Transformed {len(bbf_offnets)} Off-Net records")
print(f"\n   REQUIRED FIELDS ONLY:")
print(f"   - Name (from Circuit_Service_Id__c/Name)")
print(f"   - OwnerId = {OWNER_ID}")
print(f"   - ES_Legacy_ID__c (tracking)")
print(f"   - Service__c (optional, included if available)")

# %%
# === INSERT TO BBF ===

print("\n" + "=" * 80)
print("INSERTING OFF-NET RECORDS TO BBF")
print("=" * 80)

if len(bbf_offnets) == 0:
    print("⚠️  No Off-Net records to insert")
    successful_inserts = []
    failed_inserts = []
else:
    print(f"Inserting {len(bbf_offnets)} Off-Net records using bulk API...")
    print("(Bulk API automatically batches in 200-record chunks)\n")

    try:
        results = bbf_sf.bulk.Off_Net__c.insert(bbf_offnets)

        successful_inserts = []
        failed_inserts = []

        for i, result in enumerate(results):
            if result["success"]:
                successful_inserts.append(
                    {
                        "es_id": bbf_offnets[i]["ES_Legacy_ID__c"],
                        "bbf_id": result["id"],
                        "name": bbf_offnets[i].get("Name", "N/A"),
                        "bbf_service_id": bbf_offnets[i]["Service__c"],
                    }
                )
            else:
                failed_inserts.append(
                    {
                        "es_id": bbf_offnets[i]["ES_Legacy_ID__c"],
                        "name": bbf_offnets[i].get("Name", "N/A"),
                        "errors": result["errors"],
                        "bbf_service_id": bbf_offnets[i]["Service__c"],
                    }
                )

        print(f"✅ Successfully inserted: {len(successful_inserts)} Off-Net records")
        print(f"❌ Failed to insert: {len(failed_inserts)} Off-Net records")

        if len(failed_inserts) > 0:
            print(f"\nFailed Off-Net records (first 5):")
            for item in failed_inserts[:5]:
                print(f"  - {item['name']} (ES ID: {item['es_id']})")
                print(f"    Errors: {item['errors']}")

        if len(successful_inserts) > 0:
            print(f"\nSample successful insert:")
            sample = successful_inserts[0]
            print(f"  ES Off_Net ID:   {sample['es_id']}")
            print(f"  BBF Off_Net ID:  {sample['bbf_id']}")
            print(f"  Name:            {sample['name']}")
            print(f"  BBF Service ID:  {sample['bbf_service_id']}")

    except Exception as e:
        print(f"❌ Error during bulk insert: {e}")
        successful_inserts = []
        failed_inserts = []

# %%
# === UPDATE ES WITH BBF IDS ===

print("\n" + "=" * 80)
print("UPDATING ES WITH BBF IDS")
print("=" * 80)

if len(successful_inserts) == 0:
    print("⚠️  No Off-Net records to update in ES")
    es_update_results = []
else:
    # Build update records for ES - set BBF_New_Id__c only
    es_updates = [
        {"Id": item["es_id"], "BBF_New_Id__c": item["bbf_id"]}
        for item in successful_inserts
    ]

    print(f"Updating {len(es_updates)} Off_Net__c records in ES...")
    print("   - Setting BBF_New_Id__c = BBF Off_Net ID")

    try:
        es_update_results = es_sf.bulk.Off_Net__c.update(es_updates)

        success_count = sum(1 for r in es_update_results if r["success"])
        error_count = sum(1 for r in es_update_results if not r["success"])

        print(f"\n✅ Successfully updated: {success_count} Off_Net__c records in ES")
        print(f"❌ Failed to update: {error_count} Off_Net__c records in ES")

        if error_count > 0:
            print("\nFirst 10 update failures:")
            fail_count = 0
            for i, r in enumerate(es_update_results):
                if not r["success"] and fail_count < 10:
                    print(f"  - {es_updates[i]['Id']}: {r['errors']}")
                    fail_count += 1

    except Exception as e:
        print(f"❌ Error during ES update: {e}")
        es_update_results = []

# %%
# === CREATE EXCEL OUTPUT ===

print("\n" + "=" * 80)
print("CREATING EXCEL OUTPUT")
print("=" * 80)

wb = Workbook()
ws1 = wb.active
ws1.title = "Migration Results"

# Styles
header_font = Font(bold=True, size=12, color="FFFFFF")
header_fill = PatternFill(start_color="4472C4", end_color="4472C4", fill_type="solid")
header_alignment = Alignment(horizontal="center", vertical="center")
thin_border = Border(
    left=Side(style="thin"),
    right=Side(style="thin"),
    top=Side(style="thin"),
    bottom=Side(style="thin"),
)

# Status colors
status_colors = {
    "Success": "C6EFCE",  # Green
    "Failed": "FFC7CE",  # Red
    "Skipped": "FFEB9C",  # Yellow
}

# --- SHEET 1: Migration Results ---
headers1 = [
    "ES Off_Net ID",
    "BBF Off_Net ID",
    "Off-Net Name",
    "BBF Service ID",
    "Status",
    "Error",
]
ws1.append(headers1)

for col, header in enumerate(headers1, 1):
    cell = ws1.cell(row=1, column=col)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment
    cell.border = thin_border

# Combine all results
all_results = []
for item in successful_inserts:
    all_results.append(
        {
            "ES_ID": item["es_id"],
            "BBF_ID": item["bbf_id"],
            "Name": item["name"],
            "BBF_Service_ID": item["bbf_service_id"],
            "Status": "Success",
            "Error": "",
        }
    )
for item in failed_inserts:
    all_results.append(
        {
            "ES_ID": item["es_id"],
            "BBF_ID": "",
            "Name": item["name"],
            "BBF_Service_ID": item["bbf_service_id"],
            "Status": "Failed",
            "Error": str(item["errors"]),
        }
    )
for item in skipped_no_bbf_service:
    all_results.append(
        {
            "ES_ID": item["es_id"],
            "BBF_ID": "",
            "Name": item["name"],
            "BBF_Service_ID": "",
            "Status": "Skipped",
            "Error": "No BBF Service ID found",
        }
    )

for row_idx, r in enumerate(all_results, 2):
    ws1.append(
        [
            r["ES_ID"],
            r["BBF_ID"],
            r["Name"],
            r["BBF_Service_ID"],
            r["Status"],
            r["Error"],
        ]
    )
    fill_color = status_colors.get(r["Status"], "FFFFFF")
    for col in range(1, len(headers1) + 1):
        cell = ws1.cell(row=row_idx, column=col)
        cell.fill = PatternFill("solid", fgColor=fill_color)
        cell.border = thin_border

for col in ws1.columns:
    max_length = max(len(str(cell.value)) for cell in col)
    ws1.column_dimensions[col[0].column_letter].width = min(max_length + 2, 60)

ws1.freeze_panes = "A2"

# --- SHEET 2: Summary ---
ws2 = wb.create_sheet("Summary")
ws2.append(["ES → BBF Off-Net Migration Summary"])
ws2["A1"].font = Font(bold=True, size=14)
ws2.append([])
ws2.append(["Run Type:", "TEST MODE" if TEST_MODE else "FULL MIGRATION"])
ws2.append(["Timestamp:", datetime.now().strftime("%Y-%m-%d %H:%M:%S")])
ws2.append(["Owner ID:", OWNER_ID])
ws2.append([])
ws2.append(["Metric", "Count"])
ws2["A7"].font = Font(bold=True)
ws2["B7"].font = Font(bold=True)
ws2.append(["Total Off-Net Records Processed", len(all_results)])
ws2.append(["Successful Inserts", len(successful_inserts)])
ws2.append(["Failed Inserts", len(failed_inserts)])
ws2.append(["Skipped (No BBF Service)", len(skipped_no_bbf_service)])
ws2.append(
    [
        "Success Rate",
        (
            f"{len(successful_inserts)/len(all_results)*100:.1f}%"
            if len(all_results) > 0
            else "0%"
        ),
    ]
)

# --- SHEET 3: ID Mapping ---
ws3 = wb.create_sheet("ID Mapping")
headers3 = [
    "ES Off_Net ID",
    "BBF Off_Net ID",
    "BBF Service ID",
    "Off-Net Name",
]
ws3.append(headers3)

for col, header in enumerate(headers3, 1):
    cell = ws3.cell(row=1, column=col)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment

for item in successful_inserts:
    ws3.append(
        [
            item["es_id"],
            item["bbf_id"],
            item["bbf_service_id"],
            item["name"],
        ]
    )

for col in ws3.columns:
    max_length = max(len(str(cell.value)) for cell in col)
    ws3.column_dimensions[col[0].column_letter].width = min(max_length + 2, 50)

ws3.freeze_panes = "A2"

# --- SHEET 4: Failed Inserts ---
ws4 = wb.create_sheet("Failed Inserts")
headers4 = ["ES Off_Net ID", "Off-Net Name", "BBF Service ID", "Error Details"]
ws4.append(headers4)

for col, header in enumerate(headers4, 1):
    cell = ws4.cell(row=1, column=col)
    cell.font = Font(bold=True, size=12, color="FFFFFF")
    cell.fill = PatternFill(start_color="FF4444", end_color="FF4444", fill_type="solid")
    cell.alignment = header_alignment

for item in failed_inserts:
    ws4.append(
        [
            item["es_id"],
            item["name"],
            item["bbf_service_id"],
            str(item["errors"]),
        ]
    )

# Also add skipped records to failed inserts for tracking
for item in skipped_no_bbf_service:
    ws4.append(
        [
            item["es_id"],
            item["name"],
            "",
            "Skipped: No BBF Service ID found",
        ]
    )

for col in ws4.columns:
    col_cells = list(col)
    max_length = max(len(str(cell.value)) for cell in col_cells) if col_cells else 10
    ws4.column_dimensions[col[0].column_letter].width = min(max_length + 2, 70)

ws4.freeze_panes = "A2"

# Save workbook
wb.save(output_file)
print(f"\n✅ Excel output saved to: {output_file}")
print(
    f"   📊 Sheet 1: Migration Results ({len(all_results)} Off-Net records, color-coded)"
)
print(f"   📈 Sheet 2: Summary (metrics and stats)")
print(f"   🔗 Sheet 3: ID Mapping ({len(successful_inserts)} successful mappings)")
print(
    f"   ⚠️  Sheet 4: Failed Inserts ({len(failed_inserts) + len(skipped_no_bbf_service)} failures)"
)

# %%
# === FINAL SUMMARY ===

print("\n" + "=" * 80)
print("MIGRATION COMPLETE")
print("=" * 80)
print(f"ES Off_Net__c queried: {len(es_offnets)}")
print(f"BBF Off_Net__c inserted: {len(successful_inserts)}")
print(
    f"Success rate: {len(successful_inserts)/len(es_offnets)*100:.1f}%"
    if len(es_offnets) > 0
    else "N/A - No Off-Net records processed"
)
print(f"\nExcel output: {output_file}")

if TEST_MODE:
    print(f"\n🔄 TEST MODE complete. Only migrated {TEST_LIMIT} Off-Net records.")
    print(
        "   To migrate ALL Off-Net records, set TEST_MODE = False in Cell 2 and re-run."
    )
else:
    print("\n✅ FULL MIGRATION complete!")
    print("   Off-Net migration finished.")
    print("   All Day 1 migrations are now complete!")

if len(failed_inserts) > 0:
    print(f"\n⚠️  {len(failed_inserts)} Off-Net records failed to insert")
    print("   Check 'Failed Inserts' sheet in Excel for details")

if len(skipped_no_bbf_service) > 0:
    print(
        f"\n⚠️  {len(skipped_no_bbf_service)} Off-Net records skipped (no BBF Service ID)"
    )
    print("   These Off-Net records must have their parent Service migrated first")

# %% [markdown]
# ---
# ## Migration Complete: All Day 1 Objects Migrated
#
# With Off_Net__c migration complete, all Day 1 objects have been migrated:
#
# ### Day 1 Migration Status
# | Order | Object | Status | Notes |
# |-------|--------|--------|-------|
# | 1 | Location__c | ✅ Complete | 01_location_migration.ipynb |
# | 2 | Account | ✅ Complete | 02_account_migration.ipynb |
# | 3 | Contact | ✅ Complete | 03_contact_migration.ipynb |
# | 4 | BAN__c | ✅ Complete | 04_ban_migration.ipynb |
# | 5 | Service__c | ✅ Complete | 05_service_migration.ipynb |
# | 6 | Service_Charge__c | ⏳ Pending | 06_service_charge_migration.ipynb |
# | 7 | Off_Net__c | 🔄 This notebook | 07_offnet_migration.ipynb |
#
# ### Post Day 1 Tasks
# - BAN_Contact__c (BBF internal junction object)
# - BAN_Team__c (BBF internal)
# - Node__c enrichment (research A_Node__c / Z_Node__c)
# - Second pass field enrichment
#
# ## Field Mapping Reference
#
# ### ES Off_Net__c → BBF Off_Net__c Field Mapping (Day 1 Minimum)
#
# | ES Field | BBF Field | Notes |
# |----------|-----------|-------|
# | Id | ES_Legacy_ID__c | Tracking |
# | Circuit_Service_Id__c / Name | Name | Off-Net identifier |
# | Implementation__r.BBF_New_Id__c | Service__c | Lookup to Service (REQUIRED) |
# | Location_1__r.BBF_New_Id__c | AA_Location__c | Lookup to Location (A side) |
# | Location_2__r.BBF_New_Id__c | ZZ_Location__c | Lookup to Location (Z side) |
# | Vendor_circuit_Id__c / Internal_Circuit_Id__c | Off_Net_Circuit_ID__c | Circuit identifier |
# | Circuit_Service_Id__c | BBF_Circuit_ID__c | BBF circuit reference |
# | Cost_MRC__c / Third_Party_Cost_MRC__c | COGS_MRC__c | Monthly cost |
# | Cost_NRC__c / Third_Party_Cost_NRC__c | COGS_NRC__c | One-time cost |
# | Ban_Id__c | Vendor_BAN__c | Vendor billing account |
# | Vendor_Bill_Start_Date__c | Off_Net_Start_Date__c | Service start date |
# | Disconnect_Date__c | Disconnect_Date__c | Disconnect date |
# | Term_Agreement_End_Date__c | Off_Net_Expiration_Date__c | Expiration date |
# | PM_Order_Completed__c | Disconnect_Submitted_Date__c | Disconnect submitted |
# | Demarc_Loaction__c | Demarc_Location__c | Demarcation location |
# | Product_Summary__c | Additional_Information__c | Additional details |
# | Term__c | Term__c | Contract term (picklist) |
# | LEC_Order_Status__c | Off_Net_Service_Status__c | Status (picklist) |
# | Order_Id__c | Order_Number__c | Order number |
#
# ## Cleanup Apex (if needed)
#
# ### Delete Migrated Off-Net from BBF
# ```apex
# List<Off_Net__c> offnets = [SELECT Id, Name FROM Off_Net__c WHERE ES_Legacy_ID__c != null];
# System.debug('Found ' + offnets.size() + ' migrated Off-Net records');
# delete offnets;
# ```
#
# ### Remove BBF_New_Id__c from ES (to re-run migration)
# ```apex
# List<Off_Net__c> offnets = [SELECT Id, BBF_New_Id__c
#                              FROM Off_Net__c
#                              WHERE BBF_New_Id__c != NULL];
# System.debug('Found ' + offnets.size() + ' records to reset');
# for (Off_Net__c offnet : offnets) {
#     offnet.BBF_New_Id__c = NULL;
# }
# update offnets;
# ```
