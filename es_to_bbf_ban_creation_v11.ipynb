# %% [markdown]
# # ES to BBF BAN Creation (v11)
#
# Creates new BBF billing accounts for ES BANs that have orders moving to BBF.
#
# ## v11 Changes from v10
# - **BUGFIX:** Fixed idempotency check - pd.read_sql_query() was incompatible with psycopg2, filling columns with column names instead of data. Now uses cursor.fetchall() pattern.
#
# ## v10 Changes from v9
# - **Reconnection logic:** Auto-reconnects if database connection drops mid-run
# - **Better summary:** Shows actual CREATED/ERROR counts during live runs
# - **Idempotency:** Skips BANs that already have -BBF counterpart (can resume after crash)
# - **Customer link fix:** Option to update OSS `customers.customers.salesforce_id` when missing
#
# ## Process Overview
# 1. Query all `billing_invoice__c` with active orders
# 2. Check if -BBF BAN already exists for each (skip if yes)
# 3. Classify orders as WD or BBF
# 4. Optionally fix missing OSS customer salesforce_id links
# 5. Create -BBF accounts for BANs that need them
#
# ## Safety
# - `DRY_RUN = True` by default
# - `FIX_MISSING_CUSTOMER_LINKS = False` by default

# %%
# === SETUP ===
import psycopg2
from psycopg2.extras import RealDictCursor
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
from datetime import datetime
from collections import defaultdict
import time
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Entity mapping
entity_map = {
    "Everstream Ohio": "EVO",
    "Everstream Michigan": "EVM",
    "OneCommunity": "EVO",
    "Medina County Fiber Network Services": "OCO",
    "Everstream Lynx": "EVL",
    "Michigan-LB": "EVB",
    "Michigan-RF": "EVR",
    "Everstream PA": "EVP",
}

# PA Markets
PA_MARKETS = ["Pittsburgh", "Harrisburg", "Philadelphia", "Scranton", "Uniti-PA"]

# WD Classification
WD_PROJECT_GROUP = "PA MARKET DECOM"

# Active statuses
ACTIVE_STATUSES = ["Activated", "Suspended (Late Payment)", "Disconnect in Progress"]

# Connection credentials
heroku_conn_kwargs = {
    "dbname": "d88otjf7uhv9pr",
    "user": "ucn7cbk14sd6h",
    "password": "pf27d102f95e996e621e02523d035a1bff27590c8e6a13f5b180703a6631320c5",
    "host": "ec2-54-86-217-174.compute-1.amazonaws.com",
    "port": "5432",
    "connect_timeout": 10,
}

oss_conn_kwargs = {
    "dbname": "GLC",
    "user": "oss_server",
    "password": "3wU3uB28X?!r2?@ebrUg",
    "host": "pg01.comlink.net",
    "port": "5432",
    "connect_timeout": 10,
}

# Global connection variables
conn = None
oconn = None


def connect_heroku():
    """Connect or reconnect to Heroku."""
    global conn
    try:
        if conn is not None:
            try:
                conn.close()
            except:
                pass
        conn = psycopg2.connect(**heroku_conn_kwargs, cursor_factory=RealDictCursor)
        print("✅ Connected to Heroku")
        return True
    except Exception as e:
        print(f"❌ Failed to connect to Heroku: {e}")
        return False


def connect_oss():
    """Connect or reconnect to OSS."""
    global oconn
    try:
        if oconn is not None:
            try:
                oconn.close()
            except:
                pass
        oconn = psycopg2.connect(**oss_conn_kwargs, cursor_factory=RealDictCursor)
        print("✅ Connected to OSS")
        return True
    except Exception as e:
        print(f"❌ Failed to connect to OSS: {e}")
        return False


def ensure_connections():
    """Ensure both connections are alive, reconnect if needed."""
    global conn, oconn

    # Check Heroku
    try:
        with conn.cursor() as cur:
            cur.execute("SELECT 1")
    except:
        print("🔄 Heroku connection lost, reconnecting...")
        connect_heroku()

    # Check OSS
    try:
        with oconn.cursor() as cur:
            cur.execute("SELECT 1")
    except:
        print("🔄 OSS connection lost, reconnecting...")
        connect_oss()


# Initial connections
print("Connecting to databases...")
connect_heroku()
connect_oss()
# Out:
# Connecting to databases...
# ✅ Connected to Heroku
# ✅ Connected to OSS
# True

# %%
# === CONFIGURATION ===
DRY_RUN = True  # Set to False to actually create accounts
FIX_MISSING_CUSTOMER_LINKS = True  # Set to True to update missing salesforce_id in OSS
OUTPUT_DIR = "."

# Output filename with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_type = "dry_run" if DRY_RUN else "live_run"
output_file = f"{OUTPUT_DIR}/es_to_bbf_ban_creation_v11_{run_type}_{timestamp}.xlsx"

print(f"DRY_RUN: {DRY_RUN}")
print(f"FIX_MISSING_CUSTOMER_LINKS: {FIX_MISSING_CUSTOMER_LINKS}")
print(f"Output file: {output_file}")

if not DRY_RUN:
    print("\n⚠️  WARNING: LIVE RUN - Accounts will be created!")
# Out:
# DRY_RUN: True
# FIX_MISSING_CUSTOMER_LINKS: True
# Output file: ./es_to_bbf_ban_creation_v11_dry_run_20260107_074214.xlsx

# %%
# === STEP 1: Check for existing -BBF BANs (idempotency) ===
# v11 FIX: Use cursor.fetchall() instead of pd.read_sql_query() which has
# incompatibility with psycopg2 (fills columns with column names instead of data)

existing_bbf_bans_sql = """
SELECT 
    legacy_es_id__c,
    sfid,
    name,
    account_number__c
FROM sfprod.billing_invoice__c
WHERE legacy_es_id__c IS NOT NULL
  AND bbf_ban__c = true
"""

print("Checking for existing -BBF BANs...")
with conn.cursor() as cur:
    cur.execute(existing_bbf_bans_sql)
    existing_bbf_rows = cur.fetchall()

existing_bbf_df = pd.DataFrame(existing_bbf_rows)

if len(existing_bbf_df) > 0:
    existing_bbf_old_sfids = set(existing_bbf_df["legacy_es_id__c"].tolist())
else:
    existing_bbf_old_sfids = set()

print(f"✅ Found {len(existing_bbf_df)} existing -BBF BANs (will skip these)")
print(f"   Unique legacy_es_id__c values: {len(existing_bbf_old_sfids)}")
# Out:
# Checking for existing -BBF BANs...
# ✅ Found 2503 existing -BBF BANs (will skip these)
#    Unique legacy_es_id__c values: 2503

# %%
# === STEP 2: Get all billing_invoice__c with active services and order classification ===

pa_markets_str = "','".join(PA_MARKETS)
status_str = "','".join(ACTIVE_STATUSES)

active_billing_accounts_sql = f"""
SELECT 
    bi.account_number__c AS old_account_id,
    bi.sfid AS old_billing_invoice_sfid,
    bi.account__c AS customer_sfid,
    bi.name AS old_ban_name,
    bi.account_name__c,
    bi.billing_address_1__c,
    bi.billing_city__c,
    bi.billing_state__c,
    bi.billing_zip__c,
    bi.billing_e_mail__c,
    bi.late_fee_percentage__c,
    bi.disable_late_fees__c,
    bi.payment_terms__c,
    bi.invoice_delivery_preference__c,
    COUNT(DISTINCT o.sfid) AS total_active_orders,
    COUNT(DISTINCT CASE 
        WHEN o.dimension_4_market__c IN ('{pa_markets_str}') 
             AND o.project_group__c LIKE '%{WD_PROJECT_GROUP}%'
        THEN o.sfid 
    END) AS wd_order_count,
    COUNT(DISTINCT CASE 
        WHEN NOT (
            o.dimension_4_market__c IN ('{pa_markets_str}') 
            AND o.project_group__c LIKE '%{WD_PROJECT_GROUP}%'
        )
        THEN o.sfid 
    END) AS bbf_order_count
FROM sfprod.billing_invoice__c bi
JOIN sfprod."order" o ON o.billing_invoice__c = bi.sfid
WHERE 
    o.status IN ('{status_str}')
    AND bi.disabled__c = false
    AND bi.account_number__c IS NOT NULL
GROUP BY 
    bi.account_number__c, bi.sfid, bi.account__c, bi.name, bi.account_name__c,
    bi.billing_address_1__c, bi.billing_city__c, bi.billing_state__c, 
    bi.billing_zip__c, bi.billing_e_mail__c, bi.late_fee_percentage__c, 
    bi.disable_late_fees__c, bi.payment_terms__c, bi.invoice_delivery_preference__c
ORDER BY bi.account_number__c;
"""

print("Executing query (this may take a moment)...")
with conn.cursor(cursor_factory=RealDictCursor) as cur:
    cur.execute(active_billing_accounts_sql)
    active_billing_accounts = cur.fetchall()

print(
    f"\nFound {len(active_billing_accounts)} ES billing accounts with active services"
)
# Out:
# Executing query (this may take a moment)...
#
# Found 2522 ES billing accounts with active services

# %%
# === STEP 3: Filter out BANs that already have -BBF counterpart ===

already_has_bbf = []
needs_processing = []

for ba in active_billing_accounts:
    if ba["old_billing_invoice_sfid"] in existing_bbf_old_sfids:
        already_has_bbf.append(ba)
    else:
        needs_processing.append(ba)

print(f"\n=== Idempotency Check ===")
print(f"  Already has -BBF BAN (skip): {len(already_has_bbf)}")
print(f"  Needs processing: {len(needs_processing)}")
# Out:
# === Idempotency Check ===
#   Already has -BBF BAN (skip): 2503
#   Needs processing: 19

# %%
# === STEP 4: Categorize BANs that need processing ===

wd_only = [
    ba
    for ba in needs_processing
    if ba["wd_order_count"] > 0 and ba["bbf_order_count"] == 0
]
bbf_only = [
    ba
    for ba in needs_processing
    if ba["bbf_order_count"] > 0 and ba["wd_order_count"] == 0
]
mixed = [
    ba
    for ba in needs_processing
    if ba["wd_order_count"] > 0 and ba["bbf_order_count"] > 0
]

bans_needing_bbf_account = bbf_only + mixed

print(f"\n=== BAN Classification (excluding already processed) ===")
print(f"  WD-only (PA MARKET DECOM): {len(wd_only)} → SKIP")
print(f"  BBF-only: {len(bbf_only)} → Create -BBF account")
print(f"  Mixed: {len(mixed)} → Create -BBF account")
print(f"\n✅ Total -BBF accounts to create: {len(bans_needing_bbf_account)}")
print(f"⏭️  Skipping {len(wd_only)} WD-only BANs")
print(f"⏭️  Skipping {len(already_has_bbf)} BANs that already have -BBF")
# Out:
# === BAN Classification (excluding already processed) ===
#   WD-only (PA MARKET DECOM): 17 → SKIP
#   BBF-only: 0 → Create -BBF account
#   Mixed: 0 → Create -BBF account
#
# ✅ Total -BBF accounts to create: 0
# ⏭️  Skipping 17 WD-only BANs
# ⏭️  Skipping 2503 BANs that already have -BBF

# %%
# === STEP 5: Get SF Account data ===

customer_sfids = list(
    set([ba["customer_sfid"] for ba in bans_needing_bbf_account if ba["customer_sfid"]])
)
customer_sfids_str = "','".join(customer_sfids)

sf_accounts_sql = f"""
SELECT 
    sfid,
    name,
    billingstreet,
    billingcity,
    billingstate,
    billingpostalcode,
    email_address__c,
    onecommunity_entity__c,
    business_sector__c,
    send_consolidated_invoice__c
FROM sfprod.account
WHERE sfid IN ('{customer_sfids_str}')
"""

with conn.cursor(cursor_factory=RealDictCursor) as cur:
    cur.execute(sf_accounts_sql)
    sf_accounts = {row["sfid"]: row for row in cur.fetchall()}

print(f"Retrieved {len(sf_accounts)} SF Account records.")
# Out:
# Retrieved 0 SF Account records.

# %%
# === STEP 6: Get OSS Customer records (by salesforce_id) ===

oss_customers_sql = f"""
SELECT 
    customer_id,
    customer_nm,
    salesforce_id
FROM customers.customers
WHERE salesforce_id IN ('{customer_sfids_str}')
  AND disabled >= now()
"""

with oconn.cursor(cursor_factory=RealDictCursor) as ocur:
    ocur.execute(oss_customers_sql)
    oss_customers = {row["salesforce_id"]: row for row in ocur.fetchall()}

print(f"Retrieved {len(oss_customers)} OSS Customer records (by salesforce_id).")

missing_customer_sfids = [sfid for sfid in customer_sfids if sfid not in oss_customers]
if missing_customer_sfids:
    print(
        f"⚠️ Warning: {len(missing_customer_sfids)} SF Accounts have no OSS Customer record (by salesforce_id)"
    )
else:
    print("✅ All SF Accounts have matching OSS Customer records!")
# Out:
# Retrieved 1504 OSS Customer records (by salesforce_id).
# ✅ All SF Accounts have matching OSS Customer records!

# %%
# === STEP 7: Try to find missing customers via account_id chain ===

customer_link_fixes = []

if missing_customer_sfids:
    print(f"\n=== Attempting to find missing customers via account_id chain ===")

    bans_with_missing_customers = [
        ba
        for ba in bans_needing_bbf_account
        if ba["customer_sfid"] in missing_customer_sfids
    ]

    print(f"  BANs affected: {len(bans_with_missing_customers)}")

    for ba in bans_with_missing_customers:
        old_account_id = ba["old_account_id"]
        customer_sfid = ba["customer_sfid"]

        with oconn.cursor(cursor_factory=RealDictCursor) as ocur:
            ocur.execute(
                """
                SELECT a.account_id, a.customer_id, c.customer_nm, c.salesforce_id
                FROM customers.accounts a
                JOIN customers.customers c ON a.customer_id = c.customer_id
                WHERE a.account_id = %s
                  AND c.disabled >= now()
            """,
                (old_account_id,),
            )
            result = ocur.fetchone()

        if result:
            print(f"\n  Found via account_id chain:")
            print(f"    BAN account_number__c: {old_account_id}")
            print(f"    OSS customer_id: {result['customer_id']}")
            print(f"    OSS customer_nm: {result['customer_nm']}")
            print(f"    Current salesforce_id: {result['salesforce_id']}")
            print(f"    SF Account SFID to set: {customer_sfid}")

            if result["salesforce_id"] is None or result["salesforce_id"] == "":
                customer_link_fixes.append(
                    {
                        "customer_id": result["customer_id"],
                        "customer_nm": result["customer_nm"],
                        "old_account_id": old_account_id,
                        "sf_account_sfid": customer_sfid,
                        "current_salesforce_id": result["salesforce_id"],
                        "status": "NEEDS_FIX",
                    }
                )

                oss_customers[customer_sfid] = {
                    "customer_id": result["customer_id"],
                    "customer_nm": result["customer_nm"],
                    "salesforce_id": customer_sfid,
                }
            else:
                print(
                    f"    ⚠️ salesforce_id already set to different value: {result['salesforce_id']}"
                )
        else:
            print(
                f"\n  ❌ Could not find OSS customer for account_id: {old_account_id}"
            )

    print(f"\n=== Customer Link Fixes Needed: {len(customer_link_fixes)} ===")

# %%
# === STEP 8: Apply customer link fixes (if enabled) ===

if customer_link_fixes:
    print(f"\n=== Customer Link Fixes ===")
    print(f"FIX_MISSING_CUSTOMER_LINKS: {FIX_MISSING_CUSTOMER_LINKS}")

    for fix in customer_link_fixes:
        if DRY_RUN or not FIX_MISSING_CUSTOMER_LINKS:
            fix["status"] = "WOULD_FIX" if FIX_MISSING_CUSTOMER_LINKS else "NEEDS_FIX"
            print(
                f"  [{fix['status']}] customer_id {fix['customer_id']} ({fix['customer_nm']}) → salesforce_id = {fix['sf_account_sfid']}"
            )
        else:
            try:
                with oconn.cursor() as ocur:
                    ocur.execute(
                        """
                        UPDATE customers.customers
                        SET salesforce_id = %s
                        WHERE customer_id = %s
                    """,
                        (fix["sf_account_sfid"], fix["customer_id"]),
                    )
                oconn.commit()
                fix["status"] = "FIXED"
                print(
                    f"  [FIXED] customer_id {fix['customer_id']} ({fix['customer_nm']}) → salesforce_id = {fix['sf_account_sfid']}"
                )
            except Exception as e:
                oconn.rollback()
                fix["status"] = "ERROR"
                fix["error"] = str(e)
                print(f"  [ERROR] customer_id {fix['customer_id']}: {e}")
else:
    print("\nNo customer link fixes needed.")
# Out:
# No customer link fixes needed.

# %%
# === HELPER FUNCTIONS ===


def create_oss_account(sf_account_info, customer_id, ocur):
    """Creates a new OSS billing account using SF Account data."""
    billing_zip = sf_account_info.get("billingpostalcode") or ""
    if "-" in billing_zip:
        zip_cd, zip4 = billing_zip.split("-", 1)
    else:
        zip_cd = billing_zip
        zip4 = None

    entity = sf_account_info.get("onecommunity_entity__c")
    if entity not in entity_map:
        return None, f"Unknown entity: {entity}"
    company_cd = entity_map[entity]

    business_sector = sf_account_info.get("business_sector__c") or ""
    customer_type_cd = "W" if business_sector == "Wholesale" else "R"

    ocur.execute(
        """
        INSERT INTO customers.accounts (
            account_nm, customer_id, company_cd, address1, city, state_cd,
            zip, zip4, billing_email, created_by_id, late_fee_percentage,
            customer_type_cd, bbf_ban
        ) VALUES (
            # %s, %s, %s, %s, %s, %s, %s, %s, %s, 0, %s, %s, %s
        ) RETURNING *
    """,
        (
            sf_account_info["name"],
            customer_id,
            company_cd,
            sf_account_info.get("billingstreet"),
            sf_account_info.get("billingcity"),
            sf_account_info.get("billingstate"),
            zip_cd,
            zip4,
            sf_account_info.get("email_address__c"),
            0.015,
            customer_type_cd,
            True,
        ),
    )

    return ocur.fetchone(), None


def create_sf_billing_account(
    oss_account_info, customer_sfid, legacy_billing_sfid, cur
):
    """Creates a new SF Billing Invoice record in Heroku."""
    new_ban_name = f"A{oss_account_info['account_id']}-BBF"

    paperless = oss_account_info.get("paperless", False)
    email_non_paperless = oss_account_info.get("email_non_paperless", False)

    if paperless:
        delivery_pref = "E-mail"
    elif not paperless and email_non_paperless:
        delivery_pref = "E-mail & Paper"
    else:
        delivery_pref = "Paper"

    cur.execute(
        """
        INSERT INTO sfprod.billing_invoice__c (
            billing_city__c, billing_address_1__c, account__c, account_number__c,
            name, late_fee_percentage__c, billing_zip__c, billing_state__c,
            account_name__c, billing_address_2__c, disable_late_fees__c,
            suppress_invoice_generation__c, payment_terms__c,
            suppress_past_due_notifications__c, invoice_delivery_preference__c,
            billing_e_mail__c, bbf_ban__c, legacy_es_id__c
        ) VALUES (
            %(city)s, %(address1)s, %(customer_sfid)s, %(account_id)s,
            %(ban_name)s, %(late_fee_percentage)s, %(zip)s, %(state_cd)s,
            %(account_nm)s, %(address2)s, %(disable_late_fees)s, false,
            %(due_date_frequency_cd)s, %(no_past_due_notice)s, %(delivery_pref)s,
            %(billing_email)s, true, %(legacy_billing_sfid)s
        )
        ON CONFLICT (account_number__c) DO NOTHING
    """,
        {
            "city": oss_account_info.get("city"),
            "address1": oss_account_info.get("address1"),
            "customer_sfid": customer_sfid,
            "account_id": str(oss_account_info["account_id"]),
            "ban_name": new_ban_name,
            "late_fee_percentage": oss_account_info.get("late_fee_percentage", 0.015),
            "zip": oss_account_info.get("zip"),
            "state_cd": oss_account_info.get("state_cd"),
            "account_nm": oss_account_info.get("account_nm"),
            "address2": oss_account_info.get("address2"),
            "disable_late_fees": oss_account_info.get("disable_late_fees", False),
            "due_date_frequency_cd": oss_account_info.get(
                "due_date_frequency_cd", "NET30"
            ),
            "no_past_due_notice": oss_account_info.get("no_past_due_notice", False),
            "delivery_pref": delivery_pref,
            "billing_email": oss_account_info.get("billing_email"),
            "legacy_billing_sfid": legacy_billing_sfid,
        },
    )


def poll_for_sfid(account_id, customer_sfid, max_retries=5, sleep_seconds=5):
    """Polls Heroku waiting for Salesforce to assign an SFID."""
    global conn

    for retry in range(max_retries):
        try:
            ensure_connections()
            with conn.cursor(cursor_factory=RealDictCursor) as cur:
                cur.execute(
                    """
                    SELECT sfid, account__c, account_number__c, name
                    FROM sfprod.billing_invoice__c
                    WHERE account__c = %s
                      AND account_number__c = %s
                """,
                    (customer_sfid, str(account_id)),
                )

                billing_acct = cur.fetchone()
                if billing_acct and billing_acct.get("sfid"):
                    return billing_acct
        except Exception as e:
            print(f"    ⚠️ Poll attempt {retry+1} failed: {e}")
            ensure_connections()

        time.sleep(sleep_seconds)

    return None

# %%
# === STEP 9: Process each billing account ===

results = []
skipped_wd_only = []
skipped_already_has_bbf = []

# Record skipped WD-only BANs
for ba in wd_only:
    skipped_wd_only.append(
        {
            "old_account_id": ba["old_account_id"],
            "old_billing_invoice_sfid": ba["old_billing_invoice_sfid"],
            "account_name": ba["account_name__c"],
            "old_ban_name": ba["old_ban_name"],
            "wd_order_count": ba["wd_order_count"],
            "bbf_order_count": ba["bbf_order_count"],
            "reason": "WD-only: All orders are PA MARKET DECOM",
        }
    )

# Record skipped already-has-BBF BANs
for ba in already_has_bbf:
    # Find the matching existing BBF record
    existing_match = existing_bbf_df[
        existing_bbf_df["legacy_es_id__c"] == ba["old_billing_invoice_sfid"]
    ]
    if len(existing_match) > 0:
        existing = existing_match.iloc[0]
        skipped_already_has_bbf.append(
            {
                "old_account_id": ba["old_account_id"],
                "old_billing_invoice_sfid": ba["old_billing_invoice_sfid"],
                "account_name": ba["account_name__c"],
                "old_ban_name": ba["old_ban_name"],
                "existing_bbf_name": existing["name"],
                "existing_bbf_sfid": existing["sfid"],
                "reason": "Already has -BBF BAN",
            }
        )
    else:
        # Edge case: couldn't find match (shouldn't happen)
        skipped_already_has_bbf.append(
            {
                "old_account_id": ba["old_account_id"],
                "old_billing_invoice_sfid": ba["old_billing_invoice_sfid"],
                "account_name": ba["account_name__c"],
                "old_ban_name": ba["old_ban_name"],
                "existing_bbf_name": "UNKNOWN",
                "existing_bbf_sfid": "UNKNOWN",
                "reason": "Already has -BBF BAN (match not found in lookup)",
            }
        )

print(f"Recorded {len(skipped_wd_only)} WD-only BANs as skipped")
print(f"Recorded {len(skipped_already_has_bbf)} already-has-BBF BANs as skipped")

# Process BANs that need BBF accounts
total = len(bans_needing_bbf_account)

for idx, ba in enumerate(bans_needing_bbf_account, 1):
    old_account_id = ba["old_account_id"]
    customer_sfid = ba["customer_sfid"]
    old_billing_sfid = ba["old_billing_invoice_sfid"]
    wd_count = ba["wd_order_count"]
    bbf_count = ba["bbf_order_count"]

    market_type = "BBF_ONLY" if bbf_count > 0 and wd_count == 0 else "MIXED"

    # Get SF Account
    sf_account = sf_accounts.get(customer_sfid)
    if not sf_account:
        results.append(
            {
                "old_account_id": old_account_id,
                "old_billing_invoice_sfid": old_billing_sfid,
                "account_name": ba["account_name__c"],
                "old_ban_name": ba["old_ban_name"],
                "market_type": market_type,
                "wd_order_count": wd_count,
                "bbf_order_count": bbf_count,
                "new_account_id": None,
                "new_ban_name": None,
                "new_billing_invoice_sfid": None,
                "status": "SKIPPED",
                "error": "SF Account not found",
            }
        )
        continue

    # Get OSS Customer
    oss_customer = oss_customers.get(customer_sfid)
    if not oss_customer:
        results.append(
            {
                "old_account_id": old_account_id,
                "old_billing_invoice_sfid": old_billing_sfid,
                "account_name": ba["account_name__c"],
                "old_ban_name": ba["old_ban_name"],
                "market_type": market_type,
                "wd_order_count": wd_count,
                "bbf_order_count": bbf_count,
                "new_account_id": None,
                "new_ban_name": None,
                "new_billing_invoice_sfid": None,
                "status": "SKIPPED",
                "error": "OSS Customer not found",
            }
        )
        continue

    customer_id = oss_customer["customer_id"]

    result = {
        "old_account_id": old_account_id,
        "old_billing_invoice_sfid": old_billing_sfid,
        "account_name": ba["account_name__c"],
        "old_ban_name": ba["old_ban_name"],
        "market_type": market_type,
        "wd_order_count": wd_count,
        "bbf_order_count": bbf_count,
        "new_account_id": None,
        "new_ban_name": None,
        "new_billing_invoice_sfid": None,
        "status": None,
        "error": None,
    }

    # === DRY RUN ===
    if DRY_RUN:
        entity = sf_account.get("onecommunity_entity__c")
        if entity not in entity_map:
            result["status"] = "WOULD_SKIP"
            result["error"] = f"Unknown entity: {entity}"
        else:
            result["new_account_id"] = "(pending)"
            result["new_ban_name"] = "A(pending)-BBF"
            result["new_billing_invoice_sfid"] = "(pending)"
            result["status"] = "WOULD_CREATE"

        results.append(result)
        continue

    # === LIVE RUN ===
    try:
        # Ensure connections before each record
        ensure_connections()

        print(
            f"[{idx}/{total}] Creating -BBF account for {ba['account_name__c']} (old: {old_account_id})"
        )

        # Step 1: Create OSS Account
        with oconn.cursor(cursor_factory=RealDictCursor) as ocur:
            new_oss_account, error = create_oss_account(sf_account, customer_id, ocur)

            if error:
                result["status"] = "SKIPPED"
                result["error"] = error
                results.append(result)
                oconn.rollback()
                continue

            new_account_id = new_oss_account["account_id"]
            result["new_account_id"] = new_account_id
            result["new_ban_name"] = f"A{new_account_id}-BBF"

            oconn.commit()
            print(f"  ✅ Created OSS account: {new_account_id}")

        # Step 2: Create SF Billing Invoice in Heroku
        ensure_connections()
        with conn.cursor(cursor_factory=RealDictCursor) as cur:
            create_sf_billing_account(
                new_oss_account, customer_sfid, old_billing_sfid, cur
            )
            conn.commit()
            print(f"  ✅ Created SF Billing Invoice: A{new_account_id}-BBF")

        # Step 3: Poll for SFID
        new_billing_acct = poll_for_sfid(new_account_id, customer_sfid)

        if new_billing_acct and new_billing_acct.get("sfid"):
            result["new_billing_invoice_sfid"] = new_billing_acct["sfid"]
            result["status"] = "CREATED"
            print(f"  ✅ Got SFID: {new_billing_acct['sfid']}")
        else:
            result["status"] = "CREATED_NO_SFID"
            result["error"] = "Timed out waiting for SFID"
            print(f"  ⚠️ Created but no SFID yet")

    except Exception as e:
        result["status"] = "ERROR"
        result["error"] = str(e)
        print(f"  ❌ Error: {e}")
        try:
            oconn.rollback()
        except:
            pass
        try:
            conn.rollback()
        except:
            pass

    results.append(result)

    if idx % 100 == 0:
        print(f"\nProcessed {idx}/{total} billing accounts...\n")

# Summary
print("\n" + "=" * 60)
print("PROCESSING COMPLETE")
print("=" * 60)
# Out:
# Recorded 17 WD-only BANs as skipped
# Recorded 884 already-has-BBF BANs as skipped
# [1/1619] Creating -BBF account for Packerland Broadband dba CHARTER COMMUNICATIONS (old: 101404)
#   ✅ Created OSS account: 118186
#   ✅ Created SF Billing Invoice: A118186-BBF
#   ✅ Got SFID: aA3Qp000000AQ1FKAW
# [2/1619] Creating -BBF account for Venture Logistics (old: 111442)
#   ✅ Created OSS account: 118187
#   ✅ Created SF Billing Invoice: A118187-BBF
#   ✅ Got SFID: aA3Qp000000AQ2rKAG
# [3/1619] Creating -BBF account for Easton/Cliffs (old: 111445)
#   ✅ Created OSS account: 118188
#   ✅ Created SF Billing Invoice: A118188-BBF
#   ✅ Got SFID: aA3Qp000000AQ4TKAW
# [4/1619] Creating -BBF account for PPG Industries Inc (old: 111447)
#   ✅ Created OSS account: 118189
#   ✅ Created SF Billing Invoice: A118189-BBF
#   ✅ Got SFID: aA3Qp000000AQ65KAG
# [5/1619] Creating -BBF account for Enterprise Community Partners (old: 111449)
#   ✅ Created OSS account: 118190
#   ✅ Created SF Billing Invoice: A118190-BBF
#   ✅ Got SFID: aA3Qp000000AQ7hKAG
# [6/1619] Creating -BBF account for Molded Fiber Glass Companies (old: 111451)
#   ✅ Created OSS account: 118191
#   ✅ Created SF Billing Invoice: A118191-BBF
#   ✅ Got SFID: aA3Qp000000AQ9JKAW
# [7/1619] Creating -BBF account for Corrigan Krause CPA's (old: 111453)
#   ✅ Created OSS account: 118192
#   ✅ Created SF Billing Invoice: A118192-BBF
#   ✅ Got SFID: aA3Qp000000AQAvKAO
# [8/1619] Creating -BBF account for Snip Internet, Ilc (old: 111459)
#   ✅ Created OSS account: 118193
#   ✅ Created SF Billing Invoice: A118193-BBF
#   ✅ Got SFID: aA3Qp000000AQCXKA4
# [9/1619] Creating -BBF account for T-Mobile Small Cell Milwaukee 500 (old: 111463)
#   ✅ Created OSS account: 118194
#   ✅ Created SF Billing Invoice: A118194-BBF
#   ✅ Got SFID: aA3Qp000000AQE9KAO
# [10/1619] Creating -BBF account for Datatility (old: 111475)
#   ✅ Created OSS account: 118195
#   ✅ Created SF Billing Invoice: A118195-BBF
#   ✅ Got SFID: aA3Qp000000AQFlKAO
# [11/1619] Creating -BBF account for The Goodwill Industries of Akron, Ohio, Inc. (old: 111487)
#   ✅ Created OSS account: 118196
#   ✅ Created SF Billing Invoice: A118196-BBF
#   ✅ Got SFID: aA3Qp000000AQHNKA4
# [12/1619] Creating -BBF account for Harbor (old: 111493)
#   ✅ Created OSS account: 118197
#   ✅ Created SF Billing Invoice: A118197-BBF
#   ✅ Got SFID: aA3Qp000000AQIzKAO
# [13/1619] Creating -BBF account for Firelands Enterprise, LLC (old: 111495)
#   ✅ Created OSS account: 118198
#   ✅ Created SF Billing Invoice: A118198-BBF
#   ✅ Got SFID: aA3Qp000000AQKbKAO
# [14/1619] Creating -BBF account for Impact Communications (old: 111497)
#   ✅ Created OSS account: 118199
#   ✅ Created SF Billing Invoice: A118199-BBF
#   ✅ Got SFID: aA3Qp000000AQMDKA4
# [15/1619] Creating -BBF account for Grosse Pointe Public School System (old: 111500)
#   ✅ Created OSS account: 118200
#   ✅ Created SF Billing Invoice: A118200-BBF
#   ✅ Got SFID: aA3Qp000000AQNpKAO
# [16/1619] Creating -BBF account for APXnet (old: 111507)
#   ✅ Created OSS account: 118201
#   ✅ Created SF Billing Invoice: A118201-BBF
#   ✅ Got SFID: aA3Qp000000AQPRKA4
# [17/1619] Creating -BBF account for EDEN, Inc. (old: 111508)
#   ✅ Created OSS account: 118202
#   ✅ Created SF Billing Invoice: A118202-BBF
#   ✅ Got SFID: aA3Qp000000AQR3KAO
# [18/1619] Creating -BBF account for Jack D. Butler Financial Agency, Inc. (old: 111513)
#   ✅ Created OSS account: 118203
#   ✅ Created SF Billing Invoice: A118203-BBF
#   ✅ Got SFID: aA3Qp000000AQSfKAO
# [19/1619] Creating -BBF account for McGhee's Heating and Air Conditioning (old: 111524)
#   ✅ Created OSS account: 118204
#   ✅ Created SF Billing Invoice: A118204-BBF
#   ✅ Got SFID: aA3Qp000000AQUHKA4
# [20/1619] Creating -BBF account for 1938 Franklin Holdings (old: 112039)
#   ✅ Created OSS account: 118205
#   ✅ Created SF Billing Invoice: A118205-BBF
#   ✅ Got SFID: aA3Qp000000AKAMKA4
# [21/1619] Creating -BBF account for 1st City, LLC (old: 112040)
#   ✅ Created OSS account: 118206
#   ✅ Created SF Billing Invoice: A118206-BBF
#   ✅ Got SFID: aA3Qp000000AQVtKAO
# [22/1619] Creating -BBF account for 230 E Grand River LLC (old: 112042)
#   ✅ Created OSS account: 118207
#   ✅ Created SF Billing Invoice: A118207-BBF
#   ✅ Got SFID: aA3Qp000000AQXVKA4
# [23/1619] Creating -BBF account for 438 Selden Ferlito (old: 112046)
#   ✅ Created OSS account: 118208
#   ✅ Created SF Billing Invoice: A118208-BBF
#   ✅ Got SFID: aA3Qp000000AQZ7KAO
# [24/1619] Creating -BBF account for 6 Salon (old: 112050)
#   ✅ Created OSS account: 118209
#   ✅ Created SF Billing Invoice: A118209-BBF
#   ✅ Got SFID: aA3Qp000000AQajKAG
# [25/1619] Creating -BBF account for ACLU of Michigan (old: 112052)
#   ✅ Created OSS account: 118210
#   ✅ Created SF Billing Invoice: A118210-BBF
#   ✅ Got SFID: aA3Qp000000AQcLKAW
# [26/1619] Creating -BBF account for Advance Plumbing Supply (old: 112054)
#   ✅ Created OSS account: 118211
#   ✅ Created SF Billing Invoice: A118211-BBF
#   ✅ Got SFID: aA3Qp000000AQdxKAG
# [27/1619] Creating -BBF account for Allied Eagle Supply (old: 112060)
#   ✅ Created OSS account: 118212
#   ✅ Created SF Billing Invoice: A118212-BBF
#   ✅ Got SFID: aA3Qp000000AQfZKAW
# [28/1619] Creating -BBF account for Ally Financial Inc (old: 112061)
#   ✅ Created OSS account: 118213
#   ✅ Created SF Billing Invoice: A118213-BBF
#   ✅ Got SFID: aA3Qp000000AQhBKAW
# [29/1619] Creating -BBF account for Ash New York City (old: 112068)
#   ✅ Created OSS account: 118214
#   ✅ Created SF Billing Invoice: A118214-BBF
#   ✅ Got SFID: aA3Qp000000AQinKAG
# [30/1619] Creating -BBF account for Authority Health (old: 112071)
#   ✅ Created OSS account: 118215
#   ✅ Created SF Billing Invoice: A118215-BBF
#   ✅ Got SFID: aA3Qp000000AQkPKAW
# [31/1619] Creating -BBF account for Autobooks (old: 112072)
#   ✅ Created OSS account: 118216
#   ✅ Created SF Billing Invoice: A118216-BBF
#   ✅ Got SFID: aA3Qp000000AQm1KAG
# [32/1619] Creating -BBF account for Autohahn Network (old: 112073)
#   ✅ Created OSS account: 118217
#   ✅ Created SF Billing Invoice: A118217-BBF
#   ✅ Got SFID: aA3Qp000000AQndKAG
# [33/1619] Creating -BBF account for Avalon Cafe and Bakery (old: 112075)
#   ✅ Created OSS account: 118218
#   ✅ Created SF Billing Invoice: A118218-BBF
#   ✅ Got SFID: aA3Qp000000AQpFKAW
# [34/1619] Creating -BBF account for AWAKE Cafe (old: 112078)
#   ✅ Created OSS account: 118219
#   ✅ Created SF Billing Invoice: A118219-BBF
#   ✅ Got SFID: aA3Qp000000AQqrKAG
# [35/1619] Creating -BBF account for Ballet Real Estate (old: 112079)
#   ✅ Created OSS account: 118220
#   ✅ Created SF Billing Invoice: A118220-BBF
#   ✅ Got SFID: aA3Qp000000AQsTKAW
# [36/1619] Creating -BBF account for Bamboo Detroit (old: 112080)
#   ✅ Created OSS account: 118221
#   ✅ Created SF Billing Invoice: A118221-BBF
#   ✅ Got SFID: aA3Qp000000AQu5KAG
# [37/1619] Creating -BBF account for Barton Malow (old: 112083)
#   ✅ Created OSS account: 118222
#   ✅ Created SF Billing Invoice: A118222-BBF
#   ✅ Got SFID: aA3Qp000000AQvhKAG
# [38/1619] Creating -BBF account for Barton Malow: 1401 Farmer (old: 112084)
#   ✅ Created OSS account: 118223
#   ✅ Created SF Billing Invoice: A118223-BBF
#   ✅ Got SFID: aA3Qp000000AQxJKAW
# [39/1619] Creating -BBF account for Basco of Michigan (old: 112086)
#   ✅ Created OSS account: 118224
#   ✅ Created SF Billing Invoice: A118224-BBF
#   ✅ Got SFID: aA3Qp000000AQyvKAG
# [40/1619] Creating -BBF account for Bassett & Bassett (old: 112088)
#   ✅ Created OSS account: 118225
#   ✅ Created SF Billing Invoice: A118225-BBF
#   ✅ Got SFID: aA3Qp000000AR0XKAW
# [41/1619] Creating -BBF account for Batch Brewing Corktown (old: 112089)
#   ✅ Created OSS account: 118226
#   ✅ Created SF Billing Invoice: A118226-BBF
#   ✅ Got SFID: aA3Qp000000AR29KAG
# [42/1619] Creating -BBF account for Baymont Inn & Suites Detroit (old: 112090)
#   ✅ Created OSS account: 118227
#   ✅ Created SF Billing Invoice: A118227-BBF
#   ✅ Got SFID: aA3Qp000000AR5NKAW
# [43/1619] Creating -BBF account for Benzinga (old: 112091)
#   ✅ Created OSS account: 118228
#   ✅ Created SF Billing Invoice: A118228-BBF
#   ✅ Got SFID: aA3Qp000000AR6zKAG
# [44/1619] Creating -BBF account for BESA (old: 112092)
#   ✅ Created OSS account: 118229
#   ✅ Created SF Billing Invoice: A118229-BBF
#   ✅ Got SFID: aA3Qp000000AR8bKAG
# [45/1619] Creating -BBF account for Bonobos (old: 112098)
#   ✅ Created OSS account: 118230
#   ✅ Created SF Billing Invoice: A118230-BBF
#   ✅ Got SFID: aA3Qp000000ARADKA4
# [46/1619] Creating -BBF account for BOYD (old: 112100)
#   ✅ Created OSS account: 118231
#   ✅ Created SF Billing Invoice: A118231-BBF
#   ✅ Got SFID: aA3Qp000000ARBpKAO
# [47/1619] Creating -BBF account for Broder & Sachse- The Scott (old: 112104)
#   ✅ Created OSS account: 118232
#   ✅ Created SF Billing Invoice: A118232-BBF
#   ✅ Got SFID: aA3Qp000000AQdyKAG
# [48/1619] Creating -BBF account for Brooklyn Street Local (old: 112107)
#   ✅ Created OSS account: 118233
#   ✅ Created SF Billing Invoice: A118233-BBF
#   ✅ Got SFID: aA3Qp000000ARDRKA4
# [49/1619] Creating -BBF account for Cannelle Patisserie (old: 112111)
#   ✅ Created OSS account: 118234
#   ✅ Created SF Billing Invoice: A118234-BBF
#   ✅ Got SFID: aA3Qp000000ARF3KAO
# [50/1619] Creating -BBF account for Capital Impact Partners (old: 112112)
#   ✅ Created OSS account: 118235
#   ✅ Created SF Billing Invoice: A118235-BBF
#   ✅ Got SFID: aA3Qp000000ARGfKAO
# [51/1619] Creating -BBF account for Carlton Condo Association (old: 112113)
#   ✅ Created OSS account: 118236
#   ✅ Created SF Billing Invoice: A118236-BBF
#   ✅ Got SFID: aA3Qp000000ARIHKA4
# [52/1619] Creating -BBF account for Carter Snell Skin Center (old: 112114)
#   ✅ Created OSS account: 118237
#   ✅ Created SF Billing Invoice: A118237-BBF
#   ✅ Got SFID: aA3Qp000000ARJtKAO
# [53/1619] Creating -BBF account for Center For Non-Profit Support (old: 112117)
#   ✅ Created OSS account: 118238
#   ✅ Created SF Billing Invoice: A118238-BBF
#   ✅ Got SFID: aA3Qp000000ARLVKA4
# [54/1619] Creating -BBF account for Central Kitchen + Bar (old: 112118)
#   ✅ Created OSS account: 118239
#   ✅ Created SF Billing Invoice: A118239-BBF
#   ✅ Got SFID: aA3Qp000000ARN7KAO
# [55/1619] Creating -BBF account for Chapter 13 Standing Trustees (old: 112120)
#   ✅ Created OSS account: 118240
#   ✅ Created SF Billing Invoice: A118240-BBF
#   ✅ Got SFID: aA3Qp000000AROjKAO
# [56/1619] Creating -BBF account for Chapter 13 Trustees (old: 112121)
#   ✅ Created OSS account: 118241
#   ✅ Created SF Billing Invoice: A118241-BBF
#   ✅ Got SFID: aA3Qp000000ARQLKA4
# [57/1619] Creating -BBF account for Christman Co. (old: 112122)
#   ✅ Created OSS account: 118242
#   ✅ Created SF Billing Invoice: A118242-BBF
#   ✅ Got SFID: aA3Qp000000ARRxKAO
# [58/1619] Creating -BBF account for City of Detroit - AFT Michigan: 0020320 (old: 112127)
#   ✅ Created OSS account: 118243
#   ✅ Created SF Billing Invoice: A118243-BBF
#   ✅ Got SFID: aA3Qp000000ARTZKA4
# [59/1619] Creating -BBF account for Cohen CPA (old: 112133)
#   ✅ Created OSS account: 118244
#   ✅ Created SF Billing Invoice: A118244-BBF
#   ✅ Got SFID: aA3Qp000000AQneKAG
# [60/1619] Creating -BBF account for Comau (old: 112136)
#   ✅ Created OSS account: 118245
#   ✅ Created SF Billing Invoice: A118245-BBF
#   ✅ Got SFID: aA3Qp000000ARVBKA4
# [61/1619] Creating -BBF account for Comfort Inn (old: 112137)
#   ✅ Created OSS account: 118246
#   ✅ Created SF Billing Invoice: A118246-BBF
#   ✅ Got SFID: aA3Qp000000ARWnKAO
# [62/1619] Creating -BBF account for Commercial Contracting Group (old: 112138)
#   ✅ Created OSS account: 118247
#   ✅ Created SF Billing Invoice: A118247-BBF
#   ✅ Got SFID: aA3Qp000000ARYPKA4
# [63/1619] Creating -BBF account for Community Care Associates (old: 112140)
#   ✅ Created OSS account: 118248
#   ✅ Created SF Billing Invoice: A118248-BBF
#   ✅ Got SFID: aA3Qp000000ARa1KAG
# [64/1619] Creating -BBF account for Community Foundation of Southeast Michigan (old: 112141)
#   ✅ Created OSS account: 118249
#   ✅ Created SF Billing Invoice: A118249-BBF
#   ✅ Got SFID: aA3Qp000000ARbdKAG
# [65/1619] Creating -BBF account for Coyote Logistics (old: 112148)
#   ✅ Created OSS account: 118250
#   ✅ Created SF Billing Invoice: A118250-BBF
#   ✅ Got SFID: aA3Qp000000ARdFKAW
# [66/1619] Creating -BBF account for Crain Communications Detroit (old: 112149)
#   ✅ Created OSS account: 118251
#   ✅ Created SF Billing Invoice: A118251-BBF
#   ✅ Got SFID: aA3Qp000000ARerKAG
# [67/1619] Creating -BBF account for Cronus Communications (old: 112150)
#   ✅ Created OSS account: 118252
#   ✅ Created SF Billing Invoice: A118252-BBF
#   ✅ Got SFID: aA3Qp000000ARgTKAW
# [68/1619] Creating -BBF account for Dalton and Tomich, PLC (old: 112152)
#   ✅ Created OSS account: 118253
#   ✅ Created SF Billing Invoice: A118253-BBF
#   ✅ Got SFID: aA3Qp000000ARi5KAG
# [69/1619] Creating -BBF account for Deluxx Fluxx (old: 112154)
#   ✅ Created OSS account: 118254
#   ✅ Created SF Billing Invoice: A118254-BBF
#   ✅ Got SFID: aA3Qp000000ARjhKAG
# [70/1619] Creating -BBF account for Dessert Oasis Coffee (old: 112156)
#   ✅ Created OSS account: 118255
#   ✅ Created SF Billing Invoice: A118255-BBF
#   ✅ Got SFID: aA3Qp000000ARlJKAW
# [71/1619] Creating -BBF account for Detroit Academy of Arts and Sciences (old: 112157)
#   ✅ Created OSS account: 118256
#   ✅ Created SF Billing Invoice: A118256-BBF
#   ✅ Got SFID: aA3Qp000000AOXKKA4
# [72/1619] Creating -BBF account for Detroit Central City CMH (old: 112158)
#   ✅ Created OSS account: 118257
#   ✅ Created SF Billing Invoice: A118257-BBF
#   ✅ Got SFID: aA3Qp000000ARmvKAG
# [73/1619] Creating -BBF account for Detroit City Distillery (old: 112159)
#   ✅ Created OSS account: 118258
#   ✅ Created SF Billing Invoice: A118258-BBF
#   ✅ Got SFID: aA3Qp000000AQNqKAO
# [74/1619] Creating -BBF account for Detroit Employment Solutions Corporation (old: 112160)
#   ✅ Created OSS account: 118259
#   ✅ Created SF Billing Invoice: A118259-BBF
#   ✅ Got SFID: aA3Qp000000AQm2KAG
# [75/1619] Creating -BBF account for Detroit Manufacturing Systems (old: 112171)
#   ✅ Created OSS account: 118260
#   ✅ Created SF Billing Invoice: A118260-BBF
#   ✅ Got SFID: aA3Qp000000ARoXKAW
# [76/1619] Creating -BBF account for Detroit Medical Center (old: 112172)
#   ✅ Created OSS account: 118261
#   ✅ Created SF Billing Invoice: A118261-BBF
#   ✅ Got SFID: aA3Qp000000ARq9KAG
# [77/1619] Creating -BBF account for Detroit Metro Convention & Visitors Bureau (old: 112173)
#   ✅ Created OSS account: 118262
#   ✅ Created SF Billing Invoice: A118262-BBF
#   ✅ Got SFID: aA3Qp000000ARrlKAG
# [78/1619] Creating -BBF account for Detroit Regional Chamber (old: 112175)
#   ✅ Created OSS account: 118263
#   ✅ Created SF Billing Invoice: A118263-BBF
#   ✅ Got SFID: aA3Qp000000ARtNKAW
# [79/1619] Creating -BBF account for Detroit Symphony Orchestra (old: 112177)
#   ✅ Created OSS account: 118264
#   ✅ Created SF Billing Invoice: A118264-BBF
#   ✅ Got SFID: aA3Qp000000ARuzKAG
# [80/1619] Creating -BBF account for Doner Agency (old: 112186)
#   ✅ Created OSS account: 118265
#   ✅ Created SF Billing Invoice: A118265-BBF
#   ✅ Got SFID: aA3Qp000000ARwbKAG
# [81/1619] Creating -BBF account for Dow Jones (old: 112187)
#   ✅ Created OSS account: 118266
#   ✅ Created SF Billing Invoice: A118266-BBF
#   ✅ Got SFID: aA3Qp000000ARyDKAW
# [82/1619] Creating -BBF account for Duravent (old: 112194)
#   ✅ Created OSS account: 118267
#   ✅ Created SF Billing Invoice: A118267-BBF
#   ✅ Got SFID: aA3Qp000000AQ9KKAW
# [83/1619] Creating -BBF account for Dynatrace (old: 112195)
#   ✅ Created OSS account: 118268
#   ✅ Created SF Billing Invoice: A118268-BBF
#   ✅ Got SFID: aA3Qp000000ARzpKAG
# [84/1619] Creating -BBF account for Eastern Market Brewing Co. (old: 112196)
#   ✅ Created OSS account: 118269
#   ✅ Created SF Billing Invoice: A118269-BBF
#   ✅ Got SFID: aA3Qp000000AS1RKAW
# [85/1619] Creating -BBF account for Eastern Market Corporation (old: 112197)
#   ✅ Created OSS account: 118270
#   ✅ Created SF Billing Invoice: A118270-BBF
#   ✅ Got SFID: aA3Qp000000AS33KAG
# [86/1619] Creating -BBF account for Eat Dime Store (old: 112198)
#   ✅ Created OSS account: 118271
#   ✅ Created SF Billing Invoice: A118271-BBF
#   ✅ Got SFID: aA3Qp000000AQqsKAG
# [87/1619] Creating -BBF account for Eatori Market (old: 112199)
#   ✅ Created OSS account: 118272
#   ✅ Created SF Billing Invoice: A118272-BBF
#   ✅ Got SFID: aA3Qp000000AS4fKAG
# [88/1619] Creating -BBF account for Elia and Ponto PLLC (old: 112202)
#   ✅ Created OSS account: 118273
#   ✅ Created SF Billing Invoice: A118273-BBF
#   ✅ Got SFID: aA3Qp000000AS6HKAW
# [89/1619] Creating -BBF account for FIRM Detroit (old: 112211)
#   ✅ Created OSS account: 118274
#   ✅ Created SF Billing Invoice: A118274-BBF
#   ✅ Got SFID: aA3Qp000000AS7tKAG
# [90/1619] Creating -BBF account for First Fight (old: 112212)
#   ✅ Created OSS account: 118275
#   ✅ Created SF Billing Invoice: A118275-BBF
#   ✅ Got SFID: aA3Qp000000AS9VKAW
# [91/1619] Creating -BBF account for Fisher 2015 Acquisition, LLC 4th Floor Creative (old: 112213)
#   ✅ Created OSS account: 118276
#   ✅ Created SF Billing Invoice: A118276-BBF
#   ✅ Got SFID: aA3Qp000000ASB7KAO
# [92/1619] Creating -BBF account for Fisher 2015 Acquisition, LLC  - Main Lobby (old: 112214)
#   ✅ Created OSS account: 118277
#   ✅ Created SF Billing Invoice: A118277-BBF
#   ✅ Got SFID: aA3Qp000000ASCjKAO
# [93/1619] Creating -BBF account for Five Guys Burgers and Fries (old: 112215)
#   ✅ Created OSS account: 118278
#   ✅ Created SF Billing Invoice: A118278-BBF
#   ✅ Got SFID: aA3Qp000000ASELKA4
# [94/1619] Creating -BBF account for Fontinalis (old: 112218)
#   ✅ Created OSS account: 118279
#   ✅ Created SF Billing Invoice: A118279-BBF
#   ✅ Got SFID: aA3Qp000000ASFxKAO
# [95/1619] Creating -BBF account for Forbes Management - Woodward (old: 112219)
#   ✅ Created OSS account: 118280
#   ✅ Created SF Billing Invoice: A118280-BBF
#   ✅ Got SFID: aA3Qp000000ASHZKA4
# [96/1619] Creating -BBF account for Fort Street Presbyterian (old: 112223)
#   ✅ Created OSS account: 118281
#   ✅ Created SF Billing Invoice: A118281-BBF
#   ✅ Got SFID: aA3Qp000000ASJBKA4
# [97/1619] Creating -BBF account for Frederic M Rosen PC (old: 112227)
#   ✅ Created OSS account: 118282
#   ✅ Created SF Billing Invoice: A118282-BBF
#   ✅ Got SFID: aA3Qp000000ASKnKAO
# [98/1619] Creating -BBF account for Endava Solutions, LLC (old: 112228)
#   ✅ Created OSS account: 118283
#   ✅ Created SF Billing Invoice: A118283-BBF
#   ✅ Got SFID: aA3Qp000000ASMPKA4
# [99/1619] Creating -BBF account for Garan, Lucow, Miller PC (old: 112229)
#   ✅ Created OSS account: 118284
#   ✅ Created SF Billing Invoice: A118284-BBF
#   ✅ Got SFID: aA3Qp000000ASO1KAO
# [100/1619] Creating -BBF account for Gem Theatre (old: 112230)
#   ✅ Created OSS account: 118285
#   ✅ Created SF Billing Invoice: A118285-BBF
#   ✅ Got SFID: aA3Qp000000ASPdKAO
#
# Processed 100/1619 billing accounts...
#
# [101/1619] Creating -BBF account for George Johnson & Company (old: 112231)
#   ✅ Created OSS account: 118286
#   ✅ Created SF Billing Invoice: A118286-BBF
#   ✅ Got SFID: aA3Qp000000ASRFKA4
# [102/1619] Creating -BBF account for Go Sy Thai (old: 112233)
#   ✅ Created OSS account: 118287
#   ✅ Created SF Billing Invoice: A118287-BBF
#   ✅ Got SFID: aA3Qp000000ASSrKAO
# [103/1619] Creating -BBF account for Great Expressions Dental Centers Ren Cen (old: 112235)
#   ✅ Created OSS account: 118288
#   ✅ Created SF Billing Invoice: A118288-BBF
#   ✅ Got SFID: aA3Qp000000ASUTKA4
# [104/1619] Creating -BBF account for Greektown Casino-Hotel LLC E Lafayette (old: 112239)
#   ✅ Created OSS account: 118289
#   ✅ Created SF Billing Invoice: A118289-BBF
#   ✅ Got SFID: aA3Qp000000ASW5KAO
# [105/1619] Creating -BBF account for Green Garage Detroit (old: 112240)
#   ✅ Created OSS account: 118290
#   ✅ Created SF Billing Invoice: A118290-BBF
#   ✅ Got SFID: aA3Qp000000ASXhKAO
# [106/1619] Creating -BBF account for Grey Ghost (old: 112243)
#   ✅ Created OSS account: 118291
#   ✅ Created SF Billing Invoice: A118291-BBF
#   ✅ Got SFID: aA3Qp000000APupKAG
# [107/1619] Creating -BBF account for GSTV (old: 112248)
#   ✅ Created OSS account: 118292
#   ✅ Created SF Billing Invoice: A118292-BBF
#   ✅ Got SFID: aA3Qp000000ASZJKA4
# [108/1619] Creating -BBF account for Hamilton Anderson (old: 112250)
#   ✅ Created OSS account: 118293
#   ✅ Created SF Billing Invoice: A118293-BBF
#   ✅ Got SFID: aA3Qp000000ASavKAG
# [109/1619] Creating -BBF account for Hamilton Development Corporation (old: 112251)
#   ✅ Created OSS account: 118294
#   ✅ Created SF Billing Invoice: A118294-BBF
#   ✅ Got SFID: aA3Qp000000AScXKAW
# [110/1619] Creating -BBF account for Health Centers Detroit Foundation, Inc. (old: 112255)
#   ✅ Created OSS account: 118295
#   ✅ Created SF Billing Invoice: A118295-BBF
#   ✅ Got SFID: aA3Qp000000ASe9KAG
# [111/1619] Creating -BBF account for Health Management Systems of America (old: 112256)
#   ✅ Created OSS account: 118296
#   ✅ Created SF Billing Invoice: A118296-BBF
#   ✅ Got SFID: aA3Qp000000ASflKAG
# [112/1619] Creating -BBF account for Hello Innovation (old: 112258)
#   ✅ Created OSS account: 118297
#   ✅ Created SF Billing Invoice: A118297-BBF
#   ✅ Got SFID: aA3Qp000000AShNKAW
# [113/1619] Creating -BBF account for Henry Ford Health System (old: 112259)
#   ✅ Created OSS account: 118298
#   ✅ Created SF Billing Invoice: A118298-BBF
#   ✅ Got SFID: aA3Qp000000ASizKAG
# [114/1619] Creating -BBF account for Heritage Vision Plans (old: 112260)
#   ✅ Created OSS account: 118299
#   ✅ Created SF Billing Invoice: A118299-BBF
#   ✅ Got SFID: aA3Qp000000ASkbKAG
# [115/1619] Creating -BBF account for Hickey Hauck Bishoff and Jeffers (old: 112261)
#   ✅ Created OSS account: 118300
#   ✅ Created SF Billing Invoice: A118300-BBF
#   ✅ Got SFID: aA3Qp000000ASmDKAW
# [116/1619] Creating -BBF account for H&M (old: 112262)
#   ✅ Created OSS account: 118301
#   ✅ Created SF Billing Invoice: A118301-BBF
#   ✅ Got SFID: aA3Qp000000ASnpKAG
# [117/1619] Creating -BBF account for Honigman (old: 112263)
#   ✅ Created OSS account: 118302
#   ✅ Created SF Billing Invoice: A118302-BBF
#   ✅ Got SFID: aA3Qp000000ASr3KAG
# [118/1619] Creating -BBF account for Hudson Cafe (old: 112267)
#   ✅ Created OSS account: 118303
#   ✅ Created SF Billing Invoice: A118303-BBF
#   ✅ Got SFID: aA3Qp000000ASsfKAG
# [119/1619] Creating -BBF account for Hudson Edit (old: 112268)
#   ✅ Created OSS account: 118304
#   ✅ Created SF Billing Invoice: A118304-BBF
#   ✅ Got SFID: aA3Qp000000ARWoKAO
# [120/1619] Creating -BBF account for IBEW Local 58 (old: 112269)
#   ✅ Created OSS account: 118305
#   ✅ Created SF Billing Invoice: A118305-BBF
#   ✅ Got SFID: aA3Qp000000ASuHKAW
# [121/1619] Creating -BBF account for Ima (old: 112271)
#   ✅ Created OSS account: 118306
#   ✅ Created SF Billing Invoice: A118306-BBF
#   ✅ Got SFID: aA3Qp000000ASvtKAG
# [122/1619] Creating -BBF account for Isaac Agree Downtown Synagogue (old: 112280)
#   ✅ Created OSS account: 118307
#   ✅ Created SF Billing Invoice: A118307-BBF
#   ✅ Got SFID: aA3Qp000000ASxVKAW
# [123/1619] Creating -BBF account for Jaffe Raitt Heuer & Weiss (old: 112285)
#   ✅ Created OSS account: 118308
#   ✅ Created SF Billing Invoice: A118308-BBF
#   ✅ Got SFID: aA3Qp000000ASz7KAG
# [124/1619] Creating -BBF account for James Martin Chevrolet (old: 112286)
#   ✅ Created OSS account: 118309
#   ✅ Created SF Billing Invoice: A118309-BBF
#   ✅ Got SFID: aA3Qp000000AT0jKAG
# [125/1619] Creating -BBF account for JATO Dynamics (old: 112287)
#   ✅ Created OSS account: 118310
#   ✅ Created SF Billing Invoice: A118310-BBF
#   ✅ Got SFID: aA3Qp000000AT2LKAW
# [126/1619] Creating -BBF account for Kirby Holdings, LLC (old: 112296)
#   ✅ Created OSS account: 118311
#   ✅ Created SF Billing Invoice: A118311-BBF
#   ✅ Got SFID: aA3Qp000000AT3xKAG
# [127/1619] Creating -BBF account for La Casa Cigars and Lounge (old: 112298)
#   ✅ Created OSS account: 118312
#   ✅ Created SF Billing Invoice: A118312-BBF
#   ✅ Got SFID: aA3Qp000000AT5ZKAW
# [128/1619] Creating -BBF account for La Feria (old: 112299)
#   ✅ Created OSS account: 118313
#   ✅ Created SF Billing Invoice: A118313-BBF
#   ✅ Got SFID: aA3Qp000000AT7BKAW
# [129/1619] Creating -BBF account for Lampkin Condominium Association (old: 112302)
#   ✅ Created OSS account: 118314
#   ✅ Created SF Billing Invoice: A118314-BBF
#   ✅ Got SFID: aA3Qp000000ASJCKA4
# [130/1619] Creating -BBF account for Laz Parking Ltd (old: 112306)
#   ✅ Created OSS account: 118315
#   ✅ Created SF Billing Invoice: A118315-BBF
#   ✅ Got SFID: aA3Qp000000AT8nKAG
# [131/1619] Creating -BBF account for Lift Technology (old: 112315)
#   ✅ Created OSS account: 118316
#   ✅ Created SF Billing Invoice: A118316-BBF
#   ✅ Got SFID: aA3Qp000000ATAPKA4
# [132/1619] Creating -BBF account for Limbach: 0019486 (old: 112316)
#   ✅ Created OSS account: 118317
#   ✅ Created SF Billing Invoice: A118317-BBF
#   ✅ Got SFID: aA3Qp000000ATC1KAO
# [133/1619] Creating -BBF account for Live Nation (old: 112318)
#   ✅ Created OSS account: 118318
#   ✅ Created SF Billing Invoice: A118318-BBF
#   ✅ Got SFID: aA3Qp000000ASW6KAO
# [134/1619] Creating -BBF account for Lovasco Group (old: 112321)
#   ✅ Created OSS account: 118319
#   ✅ Created SF Billing Invoice: A118319-BBF
#   ✅ Got SFID: aA3Qp000000ATDdKAO
# [135/1619] Creating -BBF account for Lovers Only (old: 112323)
#   ✅ Created OSS account: 118320
#   ✅ Created SF Billing Invoice: A118320-BBF
#   ✅ Got SFID: aA3Qp000000ATFFKA4
# [136/1619] Creating -BBF account for lululemon - Detroit (old: 112324)
#   ✅ Created OSS account: 118321
#   ✅ Created SF Billing Invoice: A118321-BBF
#   ✅ Got SFID: aA3Qp000000ATGrKAO
# [137/1619] Creating -BBF account for Madcap Coffee (old: 112327)
#   ✅ Created OSS account: 118322
#   ✅ Created SF Billing Invoice: A118322-BBF
#   ✅ Got SFID: aA3Qp000000ATITKA4
# [138/1619] Creating -BBF account for Majestic Theater (old: 112329)
#   ✅ Created OSS account: 118323
#   ✅ Created SF Billing Invoice: A118323-BBF
#   ✅ Got SFID: aA3Qp000000ATDeKAO
# [139/1619] Creating -BBF account for Marcus Market (old: 112330)
#   ✅ Created OSS account: 118324
#   ✅ Created SF Billing Invoice: A118324-BBF
#   ✅ Got SFID: aA3Qp000000ASxWKAW
# [140/1619] Creating -BBF account for Metropolitan Detroit Area Hospital Services, (old: 112338)
#   ✅ Created OSS account: 118325
#   ✅ Created SF Billing Invoice: A118325-BBF
#   ✅ Got SFID: aA3Qp000000ATK5KAO
# [141/1619] Creating -BBF account for Metropolitan Hotel Partners (old: 112339)
#   ✅ Created OSS account: 118326
#   ✅ Created SF Billing Invoice: A118326-BBF
#   ✅ Got SFID: aA3Qp000000ATLhKAO
# [142/1619] Creating -BBF account for Michigan Lottery (old: 112343)
#   ✅ Created OSS account: 118327
#   ✅ Created SF Billing Invoice: A118327-BBF
#   ✅ Got SFID: aA3Qp000000ATNJKA4
# [143/1619] Creating -BBF account for Michigan & Trumbull (old: 112345)
#   ✅ Created OSS account: 118328
#   ✅ Created SF Billing Invoice: A118328-BBF
#   ✅ Got SFID: aA3Qp000000ATOvKAO
# [144/1619] Creating -BBF account for Midtown Detroit Inc (old: 112346)
#   ✅ Created OSS account: 118329
#   ✅ Created SF Billing Invoice: A118329-BBF
#   ✅ Got SFID: aA3Qp000000ATQXKA4
# [145/1619] Creating -BBF account for Midtown Inc (old: 112347)
#   ✅ Created OSS account: 118330
#   ✅ Created SF Billing Invoice: A118330-BBF
#   ✅ Got SFID: aA3Qp000000AS7uKAG
# [146/1619] Creating -BBF account for MOCAD (old: 112349)
#   ✅ Created OSS account: 118331
#   ✅ Created SF Billing Invoice: A118331-BBF
#   ✅ Got SFID: aA3Qp000000ATS9KAO
# [147/1619] Creating -BBF account for Mootz Pizzeria and Bar (old: 112351)
#   ✅ Created OSS account: 118332
#   ✅ Created SF Billing Invoice: A118332-BBF
#   ✅ Got SFID: aA3Qp000000ATTlKAO
# [148/1619] Creating -BBF account for Most Holy Trinity Parish (old: 112354)
#   ✅ Created OSS account: 118333
#   ✅ Created SF Billing Invoice: A118333-BBF
#   ✅ Got SFID: aA3Qp000000ATVNKA4
# [149/1619] Creating -BBF account for Motor City Electric Co. (old: 112355)
#   ✅ Created OSS account: 118334
#   ✅ Created SF Billing Invoice: A118334-BBF
#   ✅ Got SFID: aA3Qp000000AP6oKAG
# [150/1619] Creating -BBF account for Mr Kabob (old: 112359)
#   ✅ Created OSS account: 118335
#   ✅ Created SF Billing Invoice: A118335-BBF
#   ✅ Got SFID: aA3Qp000000ATWzKAO
# [151/1619] Creating -BBF account for Mudgies (old: 112360)
#   ✅ Created OSS account: 118336
#   ✅ Created SF Billing Invoice: A118336-BBF
#   ✅ Got SFID: aA3Qp000000ATYbKAO
# [152/1619] Creating -BBF account for MyLocker (old: 112362)
#   ✅ Created OSS account: 118337
#   ✅ Created SF Billing Invoice: A118337-BBF
#   ✅ Got SFID: aA3Qp000000ATaDKAW
# [153/1619] Creating -BBF account for Nike (old: 112367)
#   ✅ Created OSS account: 118338
#   ✅ Created SF Billing Invoice: A118338-BBF
#   ✅ Got SFID: aA3Qp000000AQXWKA4
# [154/1619] Creating -BBF account for Ottava Via (old: 112374)
#   ✅ Created OSS account: 118339
#   ✅ Created SF Billing Invoice: A118339-BBF
#   ✅ Got SFID: aA3Qp000000ATbpKAG
# [155/1619] Creating -BBF account for Paul Moskowitz, CPA, P.C. (old: 112381)
#   ✅ Created OSS account: 118340
#   ✅ Created SF Billing Invoice: A118340-BBF
#   ✅ Got SFID: aA3Qp000000ATdRKAW
# [156/1619] Creating -BBF account for Paxahau Events (old: 112382)
#   ✅ Created OSS account: 118341
#   ✅ Created SF Billing Invoice: A118341-BBF
#   ✅ Got SFID: aA3Qp000000ATf3KAG
# [157/1619] Creating -BBF account for Pentastar Aviation (old: 112383)
#   ✅ Created OSS account: 118342
#   ✅ Created SF Billing Invoice: A118342-BBF
#   ✅ Got SFID: aA3Qp000000ATgfKAG
# [158/1619] Creating -BBF account for Philips Houze (old: 112384)
#   ✅ Created OSS account: 118343
#   ✅ Created SF Billing Invoice: A118343-BBF
#   ✅ Got SFID: aA3Qp000000ATiHKAW
# [159/1619] Creating -BBF account for The Lager House (old: 112389)
#   ✅ Created OSS account: 118344
#   ✅ Created SF Billing Invoice: A118344-BBF
#   ✅ Got SFID: aA3Qp000000ARoYKAW
# [160/1619] Creating -BBF account for Plum Health (old: 112390)
#   ✅ Created OSS account: 118345
#   ✅ Created SF Billing Invoice: A118345-BBF
#   ✅ Got SFID: aA3Qp000000ATjtKAG
# [161/1619] Creating -BBF account for Premier Parking Services Inc (old: 112395)
#   ✅ Created OSS account: 118346
#   ✅ Created SF Billing Invoice: A118346-BBF
#   ✅ Got SFID: aA3Qp000000ATlVKAW
# [162/1619] Creating -BBF account for Premier Parking Services Inc: 0001045 (old: 112397)
#   ✅ Created OSS account: 118347
#   ✅ Created SF Billing Invoice: A118347-BBF
#   ✅ Got SFID: aA3Qp000000AQ9LKAW
# [163/1619] Creating -BBF account for Premier Parking Services Inc: 0024103 (old: 112400)
#   ✅ Created OSS account: 118348
#   ✅ Created SF Billing Invoice: A118348-BBF
#   ✅ Got SFID: aA3Qp000000ATn7KAG
# [164/1619] Creating -BBF account for Premise Health (old: 112401)
#   ✅ Created OSS account: 118349
#   ✅ Created SF Billing Invoice: A118349-BBF
#   ✅ Got SFID: aA3Qp000000AKGoKAO
# [165/1619] Creating -BBF account for Professional Engineering Associates (old: 112403)
#   ✅ Created OSS account: 118350
#   ✅ Created SF Billing Invoice: A118350-BBF
#   ✅ Got SFID: aA3Qp000000ATojKAG
# [166/1619] Creating -BBF account for Provisions Werner (old: 112405)
#   ✅ Created OSS account: 118351
#   ✅ Created SF Billing Invoice: A118351-BBF
#   ✅ Got SFID: aA3Qp000000ATqLKAW
# [167/1619] Creating -BBF account for Rocket Mortgage LLC (old: 112408)
#   ✅ Created OSS account: 118352
#   ✅ Created SF Billing Invoice: A118352-BBF
#   ✅ Got SFID: aA3Qp000000ATrxKAG
# [168/1619] Creating -BBF account for Racer Trust (old: 112410)
#   ✅ Created OSS account: 118353
#   ✅ Created SF Billing Invoice: A118353-BBF
#   ✅ Got SFID: aA3Qp000000ATtZKAW
# [169/1619] Creating -BBF account for Ralph C. Wilson Jr. Foundation (old: 112411)
#   ✅ Created OSS account: 118354
#   ✅ Created SF Billing Invoice: A118354-BBF
#   ✅ Got SFID: aA3Qp000000ATvBKAW
# [170/1619] Creating -BBF account for Ram Construction Services (old: 112412)
#   ✅ Created OSS account: 118355
#   ✅ Created SF Billing Invoice: A118355-BBF
#   ✅ Got SFID: aA3Qp000000ATwnKAG
# [171/1619] Creating -BBF account for Resurget Engineering PLC (old: 112419)
#   ✅ Created OSS account: 118356
#   ✅ Created SF Billing Invoice: A118356-BBF
#   ✅ Got SFID: aA3Qp000000ATyPKAW
# [172/1619] Creating -BBF account for R-Hirt Jr., Co (old: 112420)
#   ✅ Created OSS account: 118357
#   ✅ Created SF Billing Invoice: A118357-BBF
#   ✅ Got SFID: aA3Qp000000AU01KAG
# [173/1619] Creating -BBF account for Robert Birach Law Office (old: 112422)
#   ✅ Created OSS account: 118358
#   ✅ Created SF Billing Invoice: A118358-BBF
#   ✅ Got SFID: aA3Qp000000AU1dKAG
# [174/1619] Creating -BBF account for Rocco's Italian Deli (old: 112423)
#   ✅ Created OSS account: 118359
#   ✅ Created SF Billing Invoice: A118359-BBF
#   ✅ Got SFID: aA3Qp000000AU3FKAW
# [175/1619] Creating -BBF account for Ronnisch Construction Group (old: 112426)
#   ✅ Created OSS account: 118360
#   ✅ Created SF Billing Invoice: A118360-BBF
#   ✅ Got SFID: aA3Qp000000APzfKAG
# [176/1619] Creating -BBF account for Rossetti (old: 112427)
#   ✅ Created OSS account: 118361
#   ✅ Created SF Billing Invoice: A118361-BBF
#   ✅ Got SFID: aA3Qp000000AU4rKAG
# [177/1619] Creating -BBF account for Seasons Hospice (old: 112434)
#   ✅ Created OSS account: 118362
#   ✅ Created SF Billing Invoice: A118362-BBF
#   ✅ Got SFID: aA3Qp000000AU6TKAW
# [178/1619] Creating -BBF account for Second Best Bar (old: 112436)
#   ✅ Created OSS account: 118363
#   ✅ Created SF Billing Invoice: A118363-BBF
#   ✅ Got SFID: aA3Qp000000AU85KAG
# [179/1619] Creating -BBF account for Selden Standard (old: 112440)
#   ✅ Created OSS account: 118364
#   ✅ Created SF Billing Invoice: A118364-BBF
#   ✅ Got SFID: aA3Qp000000AS6IKAW
# [180/1619] Creating -BBF account for SEMCOG, Southeast Michigan Council of Governments (old: 112441)
#   ✅ Created OSS account: 118365
#   ✅ Created SF Billing Invoice: A118365-BBF
#   ✅ Got SFID: aA3Qp000000AU9hKAG
# [181/1619] Creating -BBF account for Shake Shack (old: 112442)
#   ✅ Created OSS account: 118366
#   ✅ Created SF Billing Invoice: A118366-BBF
#   ✅ Got SFID: aA3Qp000000AUBJKA4
# [182/1619] Creating -BBF account for SheWolf (old: 112443)
#   ✅ Created OSS account: 118367
#   ✅ Created SF Billing Invoice: A118367-BBF
#   ✅ Got SFID: aA3Qp000000AUCvKAO
# [183/1619] Creating -BBF account for Shinola Hotel (old: 112444)
#   ✅ Created OSS account: 118368
#   ✅ Created SF Billing Invoice: A118368-BBF
#   ✅ Got SFID: aA3Qp000000AUEXKA4
# [184/1619] Creating -BBF account for Shinola Hotel (old: 112445)
#   ✅ Created OSS account: 118369
#   ✅ Created SF Billing Invoice: A118369-BBF
#   ✅ Got SFID: aA3Qp000000AUG9KAO
# [185/1619] Creating -BBF account for Sid Gold's Request Room (old: 112447)
#   ✅ Created OSS account: 118370
#   ✅ Created SF Billing Invoice: A118370-BBF
#   ✅ Got SFID: aA3Qp000000AUHlKAO
# [186/1619] Creating -BBF account for Simon, Stella & Zingas (old: 112448)
#   ✅ Created OSS account: 118371
#   ✅ Created SF Billing Invoice: A118371-BBF
#   ✅ Got SFID: aA3Qp000000AUJNKA4
# [187/1619] Creating -BBF account for Somat Engineering (old: 112452)
#   ✅ Created OSS account: 118372
#   ✅ Created SF Billing Invoice: A118372-BBF
#   ✅ Got SFID: aA3Qp000000AUKzKAO
# [188/1619] Creating -BBF account for Somerset Collection Merchant's Association (old: 112453)
#   ✅ Created OSS account: 118373
#   ✅ Created SF Billing Invoice: A118373-BBF
#   ✅ Got SFID: aA3Qp000000AUMbKAO
# [189/1619] Creating -BBF account for Spectacles (old: 112454)
#   ✅ Created OSS account: 118374
#   ✅ Created SF Billing Invoice: A118374-BBF
#   ✅ Got SFID: aA3Qp000000AUODKA4
# [190/1619] Creating -BBF account for Square Knot, LLC (old: 112455)
#   ✅ Created OSS account: 118375
#   ✅ Created SF Billing Invoice: A118375-BBF
#   ✅ Got SFID: aA3Qp000000AUPpKAO
# [191/1619] Creating -BBF account for Standby (old: 112456)
#   ✅ Created OSS account: 118376
#   ✅ Created SF Billing Invoice: A118376-BBF
#   ✅ Got SFID: aA3Qp000000AURRKA4
# [192/1619] Creating -BBF account for Sterling Group (old: 112458)
#   ✅ Created OSS account: 118377
#   ✅ Created SF Billing Invoice: A118377-BBF
#   ✅ Got SFID: aA3Qp000000AUT3KAO
# [193/1619] Creating -BBF account for St. Frances Cabrini Clinic (old: 112459)
#   ✅ Created OSS account: 118378
#   ✅ Created SF Billing Invoice: A118378-BBF
#   ✅ Got SFID: aA3Qp000000AUUfKAO
# [194/1619] Creating -BBF account for Supino Pizzeria (old: 112466)
#   ✅ Created OSS account: 118379
#   ✅ Created SF Billing Invoice: A118379-BBF
#   ✅ Got SFID: aA3Qp000000AUWHKA4
# [195/1619] Creating -BBF account for Teen HYPE (old: 112469)
#   ✅ Created OSS account: 118380
#   ✅ Created SF Billing Invoice: A118380-BBF
#   ✅ Got SFID: aA3Qp000000ASSsKAO
# [196/1619] Creating -BBF account for The Albert Capitol Park (old: 112470)
#   ✅ Created OSS account: 118381
#   ✅ Created SF Billing Invoice: A118381-BBF
#   ✅ Got SFID: aA3Qp000000AUXtKAO
# [197/1619] Creating -BBF account for The Bad Luck Bar (old: 112471)
#   ✅ Created OSS account: 118382
#   ✅ Created SF Billing Invoice: A118382-BBF
#   ✅ Got SFID: aA3Qp000000AUZVKA4
# [198/1619] Creating -BBF account for The Carr Center (old: 112472)
#   ✅ Created OSS account: 118383
#   ✅ Created SF Billing Invoice: A118383-BBF
#   ✅ Got SFID: aA3Qp000000ARjiKAG
# [199/1619] Creating -BBF account for The Cathedral Church of St Paul (old: 112473)
#   ✅ Created OSS account: 118384
#   ✅ Created SF Billing Invoice: A118384-BBF
#   ✅ Got SFID: aA3Qp000000ATQYKA4
# [200/1619] Creating -BBF account for The Children's Center (old: 112474)
#   ✅ Created OSS account: 118385
#   ✅ Created SF Billing Invoice: A118385-BBF
#   ✅ Got SFID: aA3Qp000000AUb7KAG
#
# Processed 200/1619 billing accounts...
#
# [201/1619] Creating -BBF account for The Forbes Company (old: 112478)
#   ✅ Created OSS account: 118386
#   ✅ Created SF Billing Invoice: A118386-BBF
#   ✅ Got SFID: aA3Qp000000AUcjKAG
# [202/1619] Creating -BBF account for The Foundation Hotel (old: 112479)
#   ✅ Created OSS account: 118387
#   ✅ Created SF Billing Invoice: A118387-BBF
#   ✅ Got SFID: aA3Qp000000AUeLKAW
# [203/1619] Creating -BBF account for The Fourmidable Group (old: 112480)
#   ✅ Created OSS account: 118388
#   ✅ Created SF Billing Invoice: A118388-BBF
#   ✅ Got SFID: aA3Qp000000AUfxKAG
# [204/1619] Creating -BBF account for The Green Garage, LLC - El Moore (old: 112481)
#   ✅ Created OSS account: 118389
#   ✅ Created SF Billing Invoice: A118389-BBF
#   ✅ Got SFID: aA3Qp000000AUhZKAW
# [205/1619] Creating -BBF account for The Hub of Back Alley (old: 112482)
#   ✅ Created OSS account: 118390
#   ✅ Created SF Billing Invoice: A118390-BBF
#   ✅ Got SFID: aA3Qp000000AUjBKAW
# [206/1619] Creating -BBF account for The Peacock Room: (old: 112485)
#   ✅ Created OSS account: 118391
#   ✅ Created SF Billing Invoice: A118391-BBF
#   ✅ Got SFID: aA3Qp000000AUknKAG
# [207/1619] Creating -BBF account for The Peacock Room/ Frida (old: 112486)
#   ✅ Created OSS account: 118392
#   ✅ Created SF Billing Invoice: A118392-BBF
#   ✅ Got SFID: aA3Qp000000AUmPKAW
# [208/1619] Creating -BBF account for The Peacock Room: Yama (old: 112487)
#   ✅ Created OSS account: 118393
#   ✅ Created SF Billing Invoice: A118393-BBF
#   ✅ Got SFID: aA3Qp000000AUo1KAG
# [209/1619] Creating -BBF account for FKA The Platform, LLC (old: 112488)
#   ✅ Created OSS account: 118394
#   ✅ Created SF Billing Invoice: A118394-BBF
#   ✅ Got SFID: aA3Qp000000AUpdKAG
# [210/1619] Creating -BBF account for The Plaza: 0003722 (old: 112491)
#   ✅ Created OSS account: 118395
#   ✅ Created SF Billing Invoice: A118395-BBF
#   ✅ Got SFID: aA3Qp000000AUrFKAW
# [211/1619] Creating -BBF account for The Roxbury Group (old: 112493)
#   ✅ Created OSS account: 118396
#   ✅ Created SF Billing Invoice: A118396-BBF
#   ✅ Got SFID: aA3Qp000000AUsrKAG
# [212/1619] Creating -BBF account for The Scarab Club (old: 112495)
#   ✅ Created OSS account: 118397
#   ✅ Created SF Billing Invoice: A118397-BBF
#   ✅ Got SFID: aA3Qp000000AUuTKAW
# [213/1619] Creating -BBF account for The Skip (old: 112497)
#   ✅ Created OSS account: 118398
#   ✅ Created SF Billing Invoice: A118398-BBF
#   ✅ Got SFID: aA3Qp000000AUw5KAG
# [214/1619] Creating -BBF account for The Well Bar (old: 112499)
#   ✅ Created OSS account: 118399
#   ✅ Created SF Billing Invoice: A118399-BBF
#   ✅ Got SFID: aA3Qp000000AUxhKAG
# [215/1619] Creating -BBF account for Third Judicial Court of Michigan (old: 112500)
#   ✅ Created OSS account: 118400
#   ✅ Created SF Billing Invoice: A118400-BBF
#   ✅ Got SFID: aA3Qp000000AUzJKAW
# [216/1619] Creating -BBF account for Third Man Records (old: 112501)
#   ✅ Created OSS account: 118401
#   ✅ Created SF Billing Invoice: A118401-BBF
#   ✅ Got SFID: aA3Qp000000AV0vKAG
# [217/1619] Creating -BBF account for Tiger Stadium Partners, LLC (old: 112503)
#   ✅ Created OSS account: 118402
#   ✅ Created SF Billing Invoice: A118402-BBF
#   ✅ Got SFID: aA3Qp000000AV2XKAW
# [218/1619] Creating -BBF account for Traveler's Aid Society of Metro Detroit (old: 112510)
#   ✅ Created OSS account: 118403
#   ✅ Created SF Billing Invoice: A118403-BBF
#   ✅ Got SFID: aA3Qp000000AV49KAG
# [219/1619] Creating -BBF account for Trident Corktown (old: 112511)
#   ✅ Created OSS account: 118404
#   ✅ Created SF Billing Invoice: A118404-BBF
#   ✅ Got SFID: aA3Qp000000AV5lKAG
# [220/1619] Creating -BBF account for UFO Factory (old: 112517)
#   ✅ Created OSS account: 118405
#   ✅ Created SF Billing Invoice: A118405-BBF
#   ✅ Got SFID: aA3Qp000000AV7NKAW
# [221/1619] Creating -BBF account for UHY LLP (old: 112518)
#   ✅ Created OSS account: 118406
#   ✅ Created SF Billing Invoice: A118406-BBF
#   ✅ Got SFID: aA3Qp000000AV8zKAG
# [222/1619] Creating -BBF account for United Way of Detroit (old: 112520)
#   ✅ Created OSS account: 118407
#   ✅ Created SF Billing Invoice: A118407-BBF
#   ✅ Got SFID: aA3Qp000000AVAbKAO
# [223/1619] Creating -BBF account for Urban Bean Co (old: 112523)
#   ✅ Created OSS account: 118408
#   ✅ Created SF Billing Invoice: A118408-BBF
#   ✅ Got SFID: aA3Qp000000AR3nKAG
# [224/1619] Creating -BBF account for Walbridge Construction (old: 112534)
#   ✅ Created OSS account: 118409
#   ✅ Created SF Billing Invoice: A118409-BBF
#   ✅ Got SFID: aA3Qp000000AVCDKA4
# [225/1619] Creating -BBF account for Walker-Miller Energy Services (old: 112535)
#   ✅ Created OSS account: 118410
#   ✅ Created SF Billing Invoice: A118410-BBF
#   ✅ Got SFID: aA3Qp000000AUssKAG
# [226/1619] Creating -BBF account for Warby Parker (old: 112536)
#   ✅ Created OSS account: 118411
#   ✅ Created SF Billing Invoice: A118411-BBF
#   ✅ Got SFID: aA3Qp000000AVDpKAO
# [227/1619] Creating -BBF account for W.C. DuComb Co. (old: 112538)
#   ✅ Created OSS account: 118412
#   ✅ Created SF Billing Invoice: A118412-BBF
#   ✅ Got SFID: aA3Qp000000AVFRKA4
# [228/1619] Creating -BBF account for WDIV (old: 112539)
#   ✅ Created OSS account: 118413
#   ✅ Created SF Billing Invoice: A118413-BBF
#   ✅ Got SFID: aA3Qp000000AVH3KAO
# [229/1619] Creating -BBF account for Weitz & Luxenberg (old: 112540)
#   ✅ Created OSS account: 118414
#   ✅ Created SF Billing Invoice: A118414-BBF
#   ✅ Got SFID: aA3Qp000000AVIfKAO
# [230/1619] Creating -BBF account for Westin Book Cadillac (old: 112541)
#   ✅ Created OSS account: 118415
#   ✅ Created SF Billing Invoice: A118415-BBF
#   ✅ Got SFID: aA3Qp000000AVKHKA4
# [231/1619] Creating -BBF account for WeWork Detroit (old: 112542)
#   ✅ Created OSS account: 118416
#   ✅ Created SF Billing Invoice: A118416-BBF
#   ✅ Got SFID: aA3Qp000000AO7WKAW
# [232/1619] Creating -BBF account for Whiting-Turner (old: 112543)
#   ✅ Created OSS account: 118417
#   ✅ Created SF Billing Invoice: A118417-BBF
#   ✅ Got SFID: aA3Qp000000AVLtKAO
# [233/1619] Creating -BBF account for Willis Show Bar (old: 112544)
#   ✅ Created OSS account: 118418
#   ✅ Created SF Billing Invoice: A118418-BBF
#   ✅ Got SFID: aA3Qp000000AVNVKA4
# [234/1619] Creating -BBF account for Willys Overland Lofts Association c/o Grant & Main (old: 112545)
#   ✅ Created OSS account: 118419
#   ✅ Created SF Billing Invoice: A118419-BBF
#   ✅ Got SFID: aA3Qp000000AVP7KAO
# [235/1619] Creating -BBF account for W K Kellogg Foundation (old: 112546)
#   ✅ Created OSS account: 118420
#   ✅ Created SF Billing Invoice: A118420-BBF
#   ✅ Got SFID: aA3Qp000000AVQjKAO
# [236/1619] Creating -BBF account for Wolverine Packing Company (old: 112547)
#   ✅ Created OSS account: 118421
#   ✅ Created SF Billing Invoice: A118421-BBF
#   ✅ Got SFID: aA3Qp000000AVSLKA4
# [237/1619] Creating -BBF account for Wright and Company (old: 112549)
#   ✅ Created OSS account: 118422
#   ✅ Created SF Billing Invoice: A118422-BBF
#   ✅ Got SFID: aA3Qp000000AVTxKAO
# [238/1619] Creating -BBF account for Yum Village LLC (old: 112552)
#   ✅ Created OSS account: 118423
#   ✅ Created SF Billing Invoice: A118423-BBF
#   ✅ Got SFID: aA3Qp000000AVVZKA4
# [239/1619] Creating -BBF account for Tata Technologies (old: 112578)
#   ✅ Created OSS account: 118424
#   ✅ Created SF Billing Invoice: A118424-BBF
#   ✅ Got SFID: aA3Qp000000AVXBKA4
# [240/1619] Creating -BBF account for US Farathane (old: 112579)
#   ✅ Created OSS account: 118425
#   ✅ Created SF Billing Invoice: A118425-BBF
#   ✅ Got SFID: aA3Qp000000AVYnKAO
# [241/1619] Creating -BBF account for Lawrence Technological University (old: 112580)
#   ✅ Created OSS account: 118426
#   ✅ Created SF Billing Invoice: A118426-BBF
#   ✅ Got SFID: aA3Qp000000AVaPKAW
# [242/1619] Creating -BBF account for Chartreuse (old: 112581)
#   ✅ Created OSS account: 118427
#   ✅ Created SF Billing Invoice: A118427-BBF
#   ✅ Got SFID: aA3Qp000000AVc1KAG
# [243/1619] Creating -BBF account for Colasanti Construction (old: 112582)
#   ✅ Created OSS account: 118428
#   ✅ Created SF Billing Invoice: A118428-BBF
#   ✅ Got SFID: aA3Qp000000AVddKAG
# [244/1619] Creating -BBF account for Michigan Lottery (old: 112584)
#   ✅ Created OSS account: 118429
#   ✅ Created SF Billing Invoice: A118429-BBF
#   ✅ Got SFID: aA3Qp000000AVfFKAW
# [245/1619] Creating -BBF account for Detroit Labs (old: 112592)
#   ✅ Created OSS account: 118430
#   ✅ Created SF Billing Invoice: A118430-BBF
#   ✅ Got SFID: aA3Qp000000AVgrKAG
# [246/1619] Creating -BBF account for Detroit Land Bank Authority (old: 112593)
#   ✅ Created OSS account: 118431
#   ✅ Created SF Billing Invoice: A118431-BBF
#   ✅ Got SFID: aA3Qp000000AQPSKA4
# [247/1619] Creating -BBF account for Real Times Media (old: 112595)
#   ✅ Created OSS account: 118432
#   ✅ Created SF Billing Invoice: A118432-BBF
#   ✅ Got SFID: aA3Qp000000AViTKAW
# [248/1619] Creating -BBF account for Intoto Studio (old: 112596)
#   ✅ Created OSS account: 118433
#   ✅ Created SF Billing Invoice: A118433-BBF
#   ✅ Got SFID: aA3Qp000000AVk5KAG
# [249/1619] Creating -BBF account for Neumann/Smith Architecture (old: 112598)
#   ✅ Created OSS account: 118434
#   ✅ Created SF Billing Invoice: A118434-BBF
#   ✅ Got SFID: aA3Qp000000AVlhKAG
# [250/1619] Creating -BBF account for Rock Security (old: 112599)
#   ✅ Created OSS account: 118435
#   ✅ Created SF Billing Invoice: A118435-BBF
#   ✅ Got SFID: aA3Qp000000AV90KAG
# [251/1619] Creating -BBF account for Rocket Mortgage LLC (old: 112600)
#   ✅ Created OSS account: 118436
#   ✅ Created SF Billing Invoice: A118436-BBF
#   ✅ Got SFID: aA3Qp000000AVnJKAW
# [252/1619] Creating -BBF account for Custom Tool & Die (old: 112603)
#   ✅ Created OSS account: 118437
#   ✅ Created SF Billing Invoice: A118437-BBF
#   ✅ Got SFID: aA3Qp000000AVk6KAG
# [253/1619] Creating -BBF account for Accu Die & Mold Inc. (old: 112604)
#   ✅ Created OSS account: 118438
#   ✅ Created SF Billing Invoice: A118438-BBF
#   ✅ Got SFID: aA3Qp000000AVovKAG
# [254/1619] Creating -BBF account for AultCare (old: 112607)
#   ✅ Created OSS account: 118439
#   ✅ Created SF Billing Invoice: A118439-BBF
#   ✅ Got SFID: aA3Qp000000AU1eKAG
# [255/1619] Creating -BBF account for Notre Dame Cathedral Latin School (old: 112608)
#   ✅ Created OSS account: 118440
#   ✅ Created SF Billing Invoice: A118440-BBF
#   ✅ Got SFID: aA3Qp000000AVqXKAW
# [256/1619] Creating -BBF account for PPG Industries Inc (old: 112609)
#   ✅ Created OSS account: 118441
#   ✅ Created SF Billing Invoice: A118441-BBF
#   ✅ Got SFID: aA3Qp000000AVs9KAG
# [257/1619] Creating -BBF account for True Blue Financial (old: 112612)
#   ✅ Created OSS account: 118442
#   ✅ Created SF Billing Invoice: A118442-BBF
#   ✅ Got SFID: aA3Qp000000AVtlKAG
# [258/1619] Creating -BBF account for Carnegie Management Development Corporation (old: 112615)
#   ✅ Created OSS account: 118443
#   ✅ Created SF Billing Invoice: A118443-BBF
#   ✅ Got SFID: aA3Qp000000AVvNKAW
# [259/1619] Creating -BBF account for Component Repair Technologies (old: 112620)
#   ✅ Created OSS account: 118444
#   ✅ Created SF Billing Invoice: A118444-BBF
#   ✅ Got SFID: aA3Qp000000AVwzKAG
# [260/1619] Creating -BBF account for Mercy Health (former Catholic Health Partners) (old: 112621)
#   ✅ Created OSS account: 118445
#   ✅ Created SF Billing Invoice: A118445-BBF
#   ✅ Got SFID: aA3Qp000000AVybKAG
# [261/1619] Creating -BBF account for Laskey Costello (old: 112622)
#   ✅ Created OSS account: 118446
#   ✅ Created SF Billing Invoice: A118446-BBF
#   ✅ Got SFID: aA3Qp000000ATTmKAO
# [262/1619] Creating -BBF account for Rocket Mortgage LLC (old: 112676)
#   ✅ Created OSS account: 118447
#   ✅ Created SF Billing Invoice: A118447-BBF
#   ✅ Got SFID: aA3Qp000000AW0DKAW
# [263/1619] Creating -BBF account for StockX (old: 112687)
#   ✅ Created OSS account: 118448
#   ✅ Created SF Billing Invoice: A118448-BBF
#   ✅ Got SFID: aA3Qp000000AW1pKAG
# [264/1619] Creating -BBF account for Nemeth Law Firm (old: 112689)
#   ✅ Created OSS account: 118449
#   ✅ Created SF Billing Invoice: A118449-BBF
#   ✅ Got SFID: aA3Qp000000AW3RKAW
# [265/1619] Creating -BBF account for Friends Church (old: 112701)
#   ✅ Created OSS account: 118450
#   ✅ Created SF Billing Invoice: A118450-BBF
#   ✅ Got SFID: aA3Qp000000AW53KAG
# ...
#   ✅ Created OSS account: 119717
#   ✅ Created SF Billing Invoice: A119717-BBF
#   ✅ Got SFID: aA3Qp000000AveXKAS
# [1533/1619] Creating -BBF account for Hampton Inn & Suites Indianapolis/Fishers (old: 117207)
#   ✅ Created OSS account: 119718
#   ✅ Created SF Billing Invoice: A119718-BBF
#   ✅ Got SFID: aA3Qp000000AvBWKA0
# [1534/1619] Creating -BBF account for The Lincoln Center for Family and Youth (old: 117210)
#   ✅ Created OSS account: 119719
#   ✅ Created SF Billing Invoice: A119719-BBF
#   ✅ Got SFID: aA3Qp000000Avg9KAC
# [1535/1619] Creating -BBF account for Pharoplast (old: 117212)
#   ✅ Created OSS account: 119720
#   ✅ Created SF Billing Invoice: A119720-BBF
#   ✅ Got SFID: aA3Qp000000AvhlKAC
# [1536/1619] Creating -BBF account for Children's Hospital Medical Center of Akron (old: 117213)
#   ✅ Created OSS account: 119721
#   ✅ Created SF Billing Invoice: A119721-BBF
#   ✅ Got SFID: aA3Qp000000AvjNKAS
# [1537/1619] Creating -BBF account for Armstrong Corporation (old: 117215)
#   ✅ Created OSS account: 119722
#   ✅ Created SF Billing Invoice: A119722-BBF
#   ✅ Got SFID: aA3Qp000000AvkzKAC
# [1538/1619] Creating -BBF account for Diasome Pharmaceuticals Inc (old: 117218)
#   ✅ Created OSS account: 119723
#   ✅ Created SF Billing Invoice: A119723-BBF
#   ✅ Got SFID: aA3Qp000000AvmbKAC
# [1539/1619] Creating -BBF account for London Automation (old: 117225)
#   ✅ Created OSS account: 119724
#   ✅ Created SF Billing Invoice: A119724-BBF
#   ✅ Got SFID: aA3Qp000000AvoDKAS
# [1540/1619] Creating -BBF account for Gregory, Moore, Brooks, Clark & Helton PC (old: 117227)
#   ✅ Created OSS account: 119725
#   ✅ Created SF Billing Invoice: A119725-BBF
#   ✅ Got SFID: aA3Qp000000AvppKAC
# [1541/1619] Creating -BBF account for Merbeth Sheet Metal Products (old: 117229)
#   ✅ Created OSS account: 119726
#   ✅ Created SF Billing Invoice: A119726-BBF
#   ✅ Got SFID: aA3Qp000000AvrRKAS
# [1542/1619] Creating -BBF account for Skillman Foundation (old: 117231)
#   ✅ Created OSS account: 119727
#   ✅ Created SF Billing Invoice: A119727-BBF
#   ✅ Got SFID: aA3Qp000000Atw6KAC
# [1543/1619] Creating -BBF account for Plymouth United Church of Christ (old: 117242)
#   ✅ Created OSS account: 119728
#   ✅ Created SF Billing Invoice: A119728-BBF
#   ✅ Got SFID: aA3Qp000000Avt3KAC
# [1544/1619] Creating -BBF account for Ceranet (old: 117245)
#   ✅ Created OSS account: 119729
#   ✅ Created SF Billing Invoice: A119729-BBF
#   ✅ Got SFID: aA3Qp000000AthaKAC
# [1545/1619] Creating -BBF account for Amware Cotter (old: 117247)
#   ✅ Created OSS account: 119730
#   ✅ Created SF Billing Invoice: A119730-BBF
#   ✅ Got SFID: aA3Qp000000Av54KAC
# [1546/1619] Creating -BBF account for Junior Achievement of SE Michigan (old: 117249)
#   ✅ Created OSS account: 119731
#   ✅ Created SF Billing Invoice: A119731-BBF
#   ✅ Got SFID: aA3Qp000000AvufKAC
# [1547/1619] Creating -BBF account for Digital Room LLC (old: 117251)
#   ✅ Created OSS account: 119732
#   ✅ Created SF Billing Invoice: A119732-BBF
#   ✅ Got SFID: aA3Qp000000AvwHKAS
# [1548/1619] Creating -BBF account for Summit County Combined General Health District (old: 117253)
#   ✅ Created OSS account: 119733
#   ✅ Created SF Billing Invoice: A119733-BBF
#   ✅ Got SFID: aA3Qp000000AuTyKAK
# [1549/1619] Creating -BBF account for Sponsler CDJR (old: 117255)
#   ✅ Created OSS account: 119734
#   ✅ Created SF Billing Invoice: A119734-BBF
#   ✅ Got SFID: aA3Qp000000AvxtKAC
# [1550/1619] Creating -BBF account for Vantage Data Centers OH11, LLC (old: 117257)
#   ✅ Created OSS account: 119735
#   ✅ Created SF Billing Invoice: A119735-BBF
#   ✅ Got SFID: aA3Qp000000ArawKAC
# [1551/1619] Creating -BBF account for Xiber, LLC (old: 117259)
#   ✅ Created OSS account: 119736
#   ✅ Created SF Billing Invoice: A119736-BBF
#   ✅ Got SFID: aA3Qp000000AvjOKAS
# [1552/1619] Creating -BBF account for DriveChoice (old: 117261)
#   ✅ Created OSS account: 119737
#   ✅ Created SF Billing Invoice: A119737-BBF
#   ✅ Got SFID: aA3Qp000000AvzVKAS
# [1553/1619] Creating -BBF account for Sterilite Corporation (old: 117263)
#   ✅ Created OSS account: 119738
#   ✅ Created SF Billing Invoice: A119738-BBF
#   ✅ Got SFID: aA3Qp000000Aw17KAC
# [1554/1619] Creating -BBF account for Sentinel Construction (old: 117265)
#   ✅ Created OSS account: 119739
#   ✅ Created SF Billing Invoice: A119739-BBF
#   ✅ Got SFID: aA3Qp000000Aw2jKAC
# [1555/1619] Creating -BBF account for Limitless Male Medical Clinic (old: 117273)
#   ✅ Created OSS account: 119740
#   ✅ Created SF Billing Invoice: A119740-BBF
#   ✅ Got SFID: aA3Qp000000AnsIKAS
# [1556/1619] Creating -BBF account for UAkronPark, Inc. (old: 117275)
#   ✅ Created OSS account: 119741
#   ✅ Created SF Billing Invoice: A119741-BBF
#   ✅ Got SFID: aA3Qp000000Aw4LKAS
# [1557/1619] Creating -BBF account for TOF Manager LLC (old: 117277)
#   ✅ Created OSS account: 119742
#   ✅ Created SF Billing Invoice: A119742-BBF
#   ✅ Got SFID: aA3Qp000000Aw5xKAC
# [1558/1619] Creating -BBF account for 10X ADD-Vantage (old: 117279)
#   ✅ Created OSS account: 119743
#   ✅ Created SF Billing Invoice: A119743-BBF
#   ✅ Got SFID: aA3Qp000000AuYoKAK
# [1559/1619] Creating -BBF account for Karamu House (old: 117281)
#   ✅ Created OSS account: 119744
#   ✅ Created SF Billing Invoice: A119744-BBF
#   ✅ Got SFID: aA3Qp000000AozfKAC
# [1560/1619] Creating -BBF account for Joink LLC (old: 117283)
#   ✅ Created OSS account: 119745
#   ✅ Created SF Billing Invoice: A119745-BBF
#   ✅ Got SFID: aA3Qp000000AogIKAS
# [1561/1619] Creating -BBF account for MD9 Noblesville (old: 117284)
#   ✅ Created OSS account: 119746
#   ✅ Created SF Billing Invoice: A119746-BBF
#   ✅ Got SFID: aA3Qp000000AjWwKAK
# [1562/1619] Creating -BBF account for Crown Equipment (old: 117290)
#   ✅ Created OSS account: 119747
#   ✅ Created SF Billing Invoice: A119747-BBF
#   ✅ Got SFID: aA3Qp000000Aw7ZKAS
# [1563/1619] Creating -BBF account for Holz Motors (old: 117294)
#   ✅ Created OSS account: 119748
#   ✅ Created SF Billing Invoice: A119748-BBF
#   ✅ Got SFID: aA3Qp000000Aw9BKAS
# [1564/1619] Creating -BBF account for City Of Gahanna (old: 117330)
#   ✅ Created OSS account: 119749
#   ✅ Created SF Billing Invoice: A119749-BBF
#   ✅ Got SFID: aA3Qp000000AwAnKAK
# [1565/1619] Creating -BBF account for Google (old: 118)
#   ✅ Created OSS account: 119750
#   ✅ Created SF Billing Invoice: A119750-BBF
#   ✅ Got SFID: aA3Qp000000AwCPKA0
# [1566/1619] Creating -BBF account for Carr Communications (old: 124)
#   ✅ Created OSS account: 119751
#   ✅ Created SF Billing Invoice: A119751-BBF
#   ✅ Got SFID: aA3Qp000000AwE1KAK
# [1567/1619] Creating -BBF account for GTT (old: 134)
#   ✅ Created OSS account: 119752
#   ✅ Created SF Billing Invoice: A119752-BBF
#   ✅ Got SFID: aA3Qp000000AwFdKAK
# [1568/1619] Creating -BBF account for ACD (old: 135)
#   ✅ Created OSS account: 119753
#   ✅ Created SF Billing Invoice: A119753-BBF
#   ✅ Got SFID: aA3Qp000000AwHFKA0
# [1569/1619] Creating -BBF account for Ace Communications (old: 144)
#   ✅ Created OSS account: 119754
#   ✅ Created SF Billing Invoice: A119754-BBF
#   ✅ Got SFID: aA3Qp000000AwIrKAK
# [1570/1619] Creating -BBF account for Ligonier Telephone (old: 162)
#   ✅ Created OSS account: 119755
#   ✅ Created SF Billing Invoice: A119755-BBF
#   ✅ Got SFID: aA3Qp000000AvugKAC
# [1571/1619] Creating -BBF account for Indiana Fiber Networks (IFN) Zayo (old: 164)
#   ✅ Created OSS account: 119756
#   ✅ Created SF Billing Invoice: A119756-BBF
#   ✅ Got SFID: aA3Qp000000AwKTKA0
# [1572/1619] Creating -BBF account for 123Net (old: 18)
#   ✅ Created OSS account: 119757
#   ✅ Created SF Billing Invoice: A119757-BBF
#   ✅ Got SFID: aA3Qp000000AwM5KAK
# [1573/1619] Creating -BBF account for Springport Telephone Company (old: 23)
#   ✅ Created OSS account: 119758
#   ✅ Created SF Billing Invoice: A119758-BBF
#   ✅ Got SFID: aA3Qp000000AwNhKAK
# [1574/1619] Creating -BBF account for Van Buren/Cass District Health Department (old: 248)
#   ✅ Created OSS account: 119759
#   ✅ Created SF Billing Invoice: A119759-BBF
#   ✅ Got SFID: aA3Qp000000AwQvKAK
# [1575/1619] Creating -BBF account for Merit Network Inc. (old: 257)
#   ✅ Created OSS account: 119760
#   ✅ Created SF Billing Invoice: A119760-BBF
#   ✅ Got SFID: aA3Qp000000Au7OKAS
# [1576/1619] Creating -BBF account for Winn Telecom (old: 26)
#   ✅ Created OSS account: 119761
#   ✅ Created SF Billing Invoice: A119761-BBF
#   ✅ Got SFID: aA3Qp000000AwSXKA0
# [1577/1619] Creating -BBF account for Zayo (old: 262)
#   ✅ Created OSS account: 119762
#   ✅ Created SF Billing Invoice: A119762-BBF
#   ✅ Got SFID: aA3Qp000000AwU9KAK
# [1578/1619] Creating -BBF account for E.B. Ridge Dairy (old: 263)
#   ✅ Created OSS account: 119763
#   ✅ Created SF Billing Invoice: A119763-BBF
#   ✅ Got SFID: aA3Qp000000AwVlKAK
# [1579/1619] Creating -BBF account for Muskegon Family Care (old: 275)
#   ✅ Created OSS account: 119764
#   ✅ Created SF Billing Invoice: A119764-BBF
#   ✅ Got SFID: aA3Qp000000AwXNKA0
# [1580/1619] Creating -BBF account for AuSable Valley Community Mental Health (old: 278)
#   ✅ Created OSS account: 119765
#   ✅ Created SF Billing Invoice: A119765-BBF
#   ✅ Got SFID: aA3Qp000000AwYzKAK
# [1581/1619] Creating -BBF account for Bronson Nursing Commons (old: 288)
#   ✅ Created OSS account: 119766
#   ✅ Created SF Billing Invoice: A119766-BBF
#   ✅ Got SFID: aA3Qp000000Asn8KAC
# [1582/1619] Creating -BBF account for TDS (old: 37)
#   ✅ Created OSS account: 119767
#   ✅ Created SF Billing Invoice: A119767-BBF
#   ✅ Got SFID: aA3Qp000000AwabKAC
# [1583/1619] Creating -BBF account for Rehmann's (old: 434)
#   ✅ Created OSS account: 119768
#   ✅ Created SF Billing Invoice: A119768-BBF
#   ✅ Got SFID: aA3Qp000000AwcDKAS
# [1584/1619] Creating -BBF account for Charter Communications (old: 45)
#   ✅ Created OSS account: 119769
#   ✅ Created SF Billing Invoice: A119769-BBF
#   ✅ Got SFID: aA3Qp000000AwdpKAC
# [1585/1619] Creating -BBF account for Clinton County (old: 475)
#   ✅ Created OSS account: 119770
#   ✅ Created SF Billing Invoice: A119770-BBF
#   ✅ Got SFID: aA3Qp000000AwfRKAS
# [1586/1619] Creating -BBF account for Met-Tel (old: 483)
#   ✅ Created OSS account: 119771
#   ✅ Created SF Billing Invoice: A119771-BBF
#   ✅ Got SFID: aA3Qp000000Awh3KAC
# [1587/1619] Creating -BBF account for Air Advantage (old: 487)
#   ✅ Created OSS account: 119772
#   ✅ Created SF Billing Invoice: A119772-BBF
#   ✅ Got SFID: aA3Qp000000AwifKAC
# [1588/1619] Creating -BBF account for Grand Valley Medical Specialists (old: 491)
#   ✅ Created OSS account: 119773
#   ✅ Created SF Billing Invoice: A119773-BBF
#   ✅ Got SFID: aA3Qp000000AwkHKAS
# [1589/1619] Creating -BBF account for City of East Lansing (old: 493)
#   ✅ Created OSS account: 119774
#   ✅ Created SF Billing Invoice: A119774-BBF
#   ✅ Got SFID: aA3Qp000000As7CKAS
# [1590/1619] Creating -BBF account for GTT (old: 494)
#   ✅ Created OSS account: 119775
#   ✅ Created SF Billing Invoice: A119775-BBF
#   ✅ Got SFID: aA3Qp000000AwltKAC
# [1591/1619] Creating -BBF account for Bloomingdale (old: 5)
#   ✅ Created OSS account: 119776
#   ✅ Created SF Billing Invoice: A119776-BBF
#   ✅ Got SFID: aA3Qp000000AwnVKAS
# [1592/1619] Creating -BBF account for Dart Container (old: 502)
#   ✅ Created OSS account: 119777
#   ✅ Created SF Billing Invoice: A119777-BBF
#   ✅ Got SFID: aA3Qp000000Awp7KAC
# [1593/1619] Creating -BBF account for Mnemonix Information Technology Consulting (old: 503)
#   ✅ Created OSS account: 119778
#   ✅ Created SF Billing Invoice: A119778-BBF
#   ✅ Got SFID: aA3Qp000000AwHGKA0
# [1594/1619] Creating -BBF account for Safety Net, Inc. (old: 504)
#   ✅ Created OSS account: 119779
#   ✅ Created SF Billing Invoice: A119779-BBF
#   ✅ Got SFID: aA3Qp000000AwqjKAC
# [1595/1619] Creating -BBF account for Sprint (old: 51)
#   ✅ Created OSS account: 119780
#   ✅ Created SF Billing Invoice: A119780-BBF
#   ✅ Got SFID: aA3Qp000000AwsLKAS
# [1596/1619] Creating -BBF account for Peerless Networks (PEER) (old: 521)
#   ✅ Created OSS account: 119781
#   ✅ Created SF Billing Invoice: A119781-BBF
#   ✅ Got SFID: aA3Qp000000AwtxKAC
# [1597/1619] Creating -BBF account for Earthlink - Windstream (old: 524)
#   ✅ Created OSS account: 119782
#   ✅ Created SF Billing Invoice: A119782-BBF
#   ✅ Got SFID: aA3Qp000000AwvZKAS
# [1598/1619] Creating -BBF account for Michigan Laborers (old: 525)
#   ✅ Created OSS account: 119783
#   ✅ Created SF Billing Invoice: A119783-BBF
#   ✅ Got SFID: aA3Qp000000AoEsKAK
# [1599/1619] Creating -BBF account for Autumnwood of McBain Nursing Center, LLC (old: 526)
#   ✅ Created OSS account: 119784
#   ✅ Created SF Billing Invoice: A119784-BBF
#   ✅ Got SFID: aA3Qp000000AuTzKAK
# [1600/1619] Creating -BBF account for Liberty Center One (DR) (old: 533)
#   ✅ Created OSS account: 119785
#   ✅ Created SF Billing Invoice: A119785-BBF
#   ✅ Got SFID: aA3Qp000000AwxBKAS
#
# Processed 1600/1619 billing accounts...
#
# [1601/1619] Creating -BBF account for Ivy Rehab Network Inc. (old: 534)
#   ✅ Created OSS account: 119786
#   ✅ Created SF Billing Invoice: A119786-BBF
#   ✅ Got SFID: aA3Qp000000AwynKAC
# [1602/1619] Creating -BBF account for Midwest Fiber Networks (old: 61)
#   ✅ Created OSS account: 119787
#   ✅ Created SF Billing Invoice: A119787-BBF
#   ✅ Got SFID: aA3Qp000000Ax0PKAS
# [1603/1619] Creating -BBF account for Carr Communications (old: 7)
#   ✅ Created OSS account: 119788
#   ✅ Created SF Billing Invoice: A119788-BBF
#   ✅ Got SFID: aA3Qp000000Ax21KAC
# [1604/1619] Creating -BBF account for Consumers Energy (old: 79)
#   ✅ Created OSS account: 119789
#   ✅ Created SF Billing Invoice: A119789-BBF
#   ✅ Got SFID: aA3Qp000000Ax3dKAC
# [1605/1619] Creating -BBF account for Trivalent Group-Rehmann Technology Solutions (old: 89)
#   ✅ Created OSS account: 119790
#   ✅ Created SF Billing Invoice: A119790-BBF
#   ✅ Got SFID: aA3Qp000000Ax5FKAS
# [1606/1619] Creating -BBF account for Lennon Telephone (old: 95)
#   ✅ Created OSS account: 119791
#   ✅ Created SF Billing Invoice: A119791-BBF
#   ✅ Got SFID: aA3Qp000000Ax6rKAC
# [1607/1619] Creating -BBF account for SAGINAW 344 LATA (old: 100671)
#   ✅ Created OSS account: 119792
#   ✅ Created SF Billing Invoice: A119792-BBF
#   ✅ Got SFID: aA3Qp000000Ax8TKAS
# [1608/1619] Creating -BBF account for Buckeye Telesystem (old: 105913)
#   ✅ Created OSS account: 119793
#   ✅ Created SF Billing Invoice: A119793-BBF
#   ✅ Got SFID: aA3Qp000000AxA5KAK
# [1609/1619] Creating -BBF account for T-Mobile MSO 1 Ohio (old: 106869)
#   ✅ Created OSS account: 119794
#   ✅ Created SF Billing Invoice: A119794-BBF
#   ✅ Got SFID: aA3Qp000000AvBXKA0
# [1610/1619] Creating -BBF account for LAN WAN Solutions d/b/a Integrated Network Concepts (old: 106876)
#   ✅ Created OSS account: 119795
#   ✅ Created SF Billing Invoice: A119795-BBF
#   ✅ Got SFID: aA3Qp000000AqmwKAC
# [1611/1619] Creating -BBF account for T-Mobile MSO 1 AMD 9 (old: 107649)
#   ✅ Created OSS account: 119796
#   ✅ Created SF Billing Invoice: A119796-BBF
#   ✅ Got SFID: aA3Qp000000AxBhKAK
# [1612/1619] Creating -BBF account for DISH Wireless (old: 113535)
#   ✅ Created OSS account: 119797
#   ✅ Created SF Billing Invoice: A119797-BBF
#   ✅ Got SFID: aA3Qp000000AxDJKA0
# [1613/1619] Creating -BBF account for Sprint Spectrum (PEG) (old: 113736)
#   ✅ Created OSS account: 119798
#   ✅ Created SF Billing Invoice: A119798-BBF
#   ✅ Got SFID: aA3Qp000000AqesKAC
# [1614/1619] Creating -BBF account for AT&T Mobility (PEG) (old: 113745)
#   ✅ Created OSS account: 119799
#   ✅ Created SF Billing Invoice: A119799-BBF
#   ✅ Got SFID: aA3Qp000000AxEvKAK
# [1615/1619] Creating -BBF account for VZW Pennsylvania (PEG) (old: 113785)
#   ✅ Created OSS account: 119800
#   ✅ Created SF Billing Invoice: A119800-BBF
#   ✅ Got SFID: aA3Qp000000AxGXKA0
# [1616/1619] Creating -BBF account for DISH Wireless (old: 113823)
#   ✅ Created OSS account: 119801
#   ✅ Created SF Billing Invoice: A119801-BBF
#   ✅ Got SFID: aA3Qp000000AxI9KAK
# [1617/1619] Creating -BBF account for Zayo (old: 113998)
#   ✅ Created OSS account: 119802
#   ✅ Created SF Billing Invoice: A119802-BBF
#   ✅ Got SFID: aA3Qp000000AoWcKAK
# [1618/1619] Creating -BBF account for Verizon Wireless - Cellco Partnership (old: 114471)
#   ✅ Created OSS account: 119803
#   ✅ Created SF Billing Invoice: A119803-BBF
#   ✅ Got SFID: aA3Qp000000AtUgKAK
# [1619/1619] Creating -BBF account for AT&T Mobility (old: 117223)
#   ✅ Created OSS account: 119804
#   ✅ Created SF Billing Invoice: A119804-BBF
#   ✅ Got SFID: aA3Qp000000AxJlKAK
#
# ============================================================
# PROCESSING COMPLETE
# ============================================================

# %%
# === STEP 10: Calculate Summary Statistics ===

status_counts = defaultdict(int)
for r in results:
    status_counts[r["status"]] += 1

# Calculate actual counts
created_count = status_counts.get("CREATED", 0) + status_counts.get(
    "CREATED_NO_SFID", 0
)
would_create_count = status_counts.get("WOULD_CREATE", 0)
skipped_count = status_counts.get("SKIPPED", 0) + status_counts.get("WOULD_SKIP", 0)
error_count = status_counts.get("ERROR", 0)

print("\n" + "=" * 60)
print("SUMMARY")
print("=" * 60)

print(f"\n{'Run Type:':<40} {'DRY RUN' if DRY_RUN else 'LIVE RUN'}")
print(
    f"{'Fix Missing Customer Links:':<40} {'Yes' if FIX_MISSING_CUSTOMER_LINKS else 'No'}"
)

print(f"\n--- BAN Breakdown ---")
print(f"{'Already has -BBF (skipped):':<40} {len(skipped_already_has_bbf)}")
print(f"{'WD-only (skipped):':<40} {len(skipped_wd_only)}")
print(f"{'BBF-only:':<40} {len(bbf_only)}")
print(f"{'Mixed:':<40} {len(mixed)}")

print(f"\n--- Results ---")
if DRY_RUN:
    print(f"{'Would Create:':<40} {would_create_count}")
    print(f"{'Would Skip:':<40} {skipped_count}")
else:
    print(f"{'CREATED:':<40} {created_count}")
    print(f"{'  - With SFID:':<40} {status_counts.get('CREATED', 0)}")
    print(f"{'  - Pending SFID:':<40} {status_counts.get('CREATED_NO_SFID', 0)}")
    print(f"{'SKIPPED:':<40} {skipped_count}")
    print(f"{'ERROR:':<40} {error_count}")

print(f"\n--- Customer Link Fixes ---")
print(f"{'Fixes needed:':<40} {len(customer_link_fixes)}")

print(f"\n--- Status Detail ---")
for status, count in sorted(status_counts.items()):
    print(f"  {status}: {count}")
# Out:
# ============================================================
# SUMMARY
# ============================================================
#
# Run Type:                                LIVE RUN
# Fix Missing Customer Links:              Yes
#
# --- BAN Breakdown ---
# Already has -BBF (skipped):              884
# WD-only (skipped):                       17
# BBF-only:                                1606
# Mixed:                                   13
#
# --- Results ---
# CREATED:                                 1619
#   - With SFID:                           1616
#   - Pending SFID:                        3
# SKIPPED:                                 0
# ERROR:                                   0
#
# --- Customer Link Fixes ---
# Fixes needed:                            0
#
# --- Status Detail ---
#   CREATED: 1616
#   CREATED_NO_SFID: 3

# %%
# === STEP 11: Create output Excel file ===

wb = Workbook()

# Styling
header_font = Font(bold=True, color="FFFFFF")
header_fill = PatternFill("solid", fgColor="4472C4")
header_fill_green = PatternFill("solid", fgColor="70AD47")
header_fill_orange = PatternFill("solid", fgColor="ED7D31")
header_fill_red = PatternFill("solid", fgColor="C00000")
header_alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
thin_border = Border(
    left=Side(style="thin"),
    right=Side(style="thin"),
    top=Side(style="thin"),
    bottom=Side(style="thin"),
)


def style_header(ws, headers, fill_color):
    for col, header in enumerate(headers, 1):
        cell = ws.cell(row=1, column=col)
        cell.font = header_font
        cell.fill = fill_color
        cell.alignment = header_alignment
        cell.border = thin_border


def auto_width(ws):
    for col in ws.columns:
        max_length = 0
        column = col[0].column_letter
        for cell in col:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        ws.column_dimensions[column].width = min(max_length + 2, 40)


status_colors = {
    "WOULD_CREATE": "C6EFCE",
    "WOULD_SKIP": "FCE4D6",
    "CREATED": "C6EFCE",
    "CREATED_NO_SFID": "FFEB9C",
    "SKIPPED": "FFCCCC",
    "ERROR": "FF6666",
}

# === Sheet 1: Summary ===
ws1 = wb.active
ws1.title = "Summary"
ws1.append(["ES to BBF BAN Creation Summary (v11)"])
ws1["A1"].font = Font(bold=True, size=14)
ws1.append([])
ws1.append(["Run Type:", "DRY RUN" if DRY_RUN else "LIVE RUN"])
ws1.append(
    ["Fix Missing Customer Links:", "Yes" if FIX_MISSING_CUSTOMER_LINKS else "No"]
)
ws1.append(["Timestamp:", datetime.now().strftime("%Y-%m-%d %H:%M:%S")])
ws1.append([])
ws1.append(["BAN Breakdown:"])
ws1["A7"].font = Font(bold=True)
ws1.append(["  Already has -BBF (skipped):", len(skipped_already_has_bbf)])
ws1.append(["  WD-only (skipped):", len(skipped_wd_only)])
ws1.append(["  BBF-only:", len(bbf_only)])
ws1.append(["  Mixed:", len(mixed)])
ws1.append([])
ws1.append(["Results:"])
ws1["A13"].font = Font(bold=True)

if DRY_RUN:
    ws1.append(["  Would Create:", would_create_count])
    ws1.append(["  Would Skip:", skipped_count])
else:
    ws1.append(["  CREATED:", created_count])
    ws1.append(["    - With SFID:", status_counts.get("CREATED", 0)])
    ws1.append(["    - Pending SFID:", status_counts.get("CREATED_NO_SFID", 0)])
    ws1.append(["  SKIPPED:", skipped_count])
    ws1.append(["  ERROR:", error_count])

ws1.append([])
ws1.append(["Customer Link Fixes:"])
ws1.append(["  Fixes needed:", len(customer_link_fixes)])

# === Sheet 2: BBF Clone Results ===
ws2 = wb.create_sheet("BBF Clone Results")
headers2 = [
    "Old Account ID",
    "New Account ID",
    "Account Name",
    "Old BAN Name",
    "New BAN Name",
    "Market Type",
    "WD Orders (Stay)",
    "BBF Orders (Move)",
    "Old Billing SFID",
    "New Billing SFID",
    "Status",
    "Error",
]
ws2.append(headers2)
style_header(ws2, headers2, header_fill)

for row_idx, r in enumerate(results, 2):
    ws2.append(
        [
            r["old_account_id"],
            r["new_account_id"],
            r["account_name"],
            r["old_ban_name"],
            r["new_ban_name"],
            r["market_type"],
            r["wd_order_count"],
            r["bbf_order_count"],
            r["old_billing_invoice_sfid"],
            r["new_billing_invoice_sfid"],
            r["status"],
            r["error"],
        ]
    )
    fill_color = status_colors.get(r["status"], "FFFFFF")
    for col in range(1, len(headers2) + 1):
        ws2.cell(row=row_idx, column=col).fill = PatternFill(
            "solid", fgColor=fill_color
        )

ws2.freeze_panes = "A2"
auto_width(ws2)

# === Sheet 3: Skipped - Already Has BBF ===
ws3 = wb.create_sheet("Skipped - Already Has BBF")
headers3 = [
    "Old Account ID",
    "Account Name",
    "Old BAN Name",
    "Existing BBF Name",
    "Existing BBF SFID",
    "Reason",
]
ws3.append(headers3)
style_header(ws3, headers3, header_fill_green)

for r in skipped_already_has_bbf:
    ws3.append(
        [
            r["old_account_id"],
            r["account_name"],
            r["old_ban_name"],
            r["existing_bbf_name"],
            r["existing_bbf_sfid"],
            r["reason"],
        ]
    )

ws3.freeze_panes = "A2"
auto_width(ws3)

# === Sheet 4: Skipped - WD Only ===
ws4 = wb.create_sheet("Skipped - WD Only")
headers4 = [
    "Old Account ID",
    "Account Name",
    "Old BAN Name",
    "WD Orders",
    "BBF Orders",
    "Old Billing SFID",
    "Reason",
]
ws4.append(headers4)
style_header(ws4, headers4, header_fill_orange)

for r in skipped_wd_only:
    ws4.append(
        [
            r["old_account_id"],
            r["account_name"],
            r["old_ban_name"],
            r["wd_order_count"],
            r["bbf_order_count"],
            r["old_billing_invoice_sfid"],
            r["reason"],
        ]
    )

ws4.freeze_panes = "A2"
auto_width(ws4)

# === Sheet 5: Customer Link Fixes ===
ws5 = wb.create_sheet("Customer Link Fixes")
headers5 = [
    "Customer ID",
    "Customer Name",
    "Old Account ID",
    "SF Account SFID",
    "Current Salesforce ID",
    "Status",
]
ws5.append(headers5)
style_header(ws5, headers5, header_fill)

for r in customer_link_fixes:
    ws5.append(
        [
            r["customer_id"],
            r["customer_nm"],
            r["old_account_id"],
            r["sf_account_sfid"],
            r["current_salesforce_id"],
            r["status"],
        ]
    )

ws5.freeze_panes = "A2"
auto_width(ws5)

# === Sheet 6: Errors ===
ws6 = wb.create_sheet("Errors")
headers6 = ["Old Account ID", "Account Name", "Market Type", "Status", "Error"]
ws6.append(headers6)
style_header(ws6, headers6, header_fill_red)

for r in results:
    if r["status"] in ("SKIPPED", "WOULD_SKIP", "ERROR"):
        ws6.append(
            [
                r["old_account_id"],
                r["account_name"],
                r["market_type"],
                r["status"],
                r["error"],
            ]
        )

ws6.freeze_panes = "A2"
auto_width(ws6)

# Save
wb.save(output_file)
print(f"\n✅ Output saved to: {output_file}")
# Out:
# ✅ Output saved to: ./es_to_bbf_ban_creation_v11_live_run_20260106_132439.xlsx

# %%
# === Cleanup ===
try:
    conn.close()
except:
    pass
try:
    oconn.close()
except:
    pass
print("🔌 Database connections closed.")

if DRY_RUN:
    print("\n🔄 DRY RUN complete. No accounts were created.")
    print(f"Review the output file: {output_file}")
    print("\nTo run for real, set DRY_RUN = False and re-run the notebook.")
    if customer_link_fixes:
        print(f"\n⚠️ {len(customer_link_fixes)} customer link fixes needed.")
        print("   Set FIX_MISSING_CUSTOMER_LINKS = True to apply fixes.")
else:
    print(f"\n✅ LIVE RUN complete.")
    print(f"   CREATED: {created_count}")
    print(f"   SKIPPED: {skipped_count}")
    print(f"   ERROR: {error_count}")
    print(f"\nOutput saved to: {output_file}")
# Out:
# 🔌 Database connections closed.
#
# ✅ LIVE RUN complete.
#    CREATED: 1619
#    SKIPPED: 0
#    ERROR: 0
#
# Output saved to: ./es_to_bbf_ban_creation_v11_live_run_20260106_132439.xlsx
